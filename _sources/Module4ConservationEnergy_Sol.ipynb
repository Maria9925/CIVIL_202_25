# %% [markdown]
# # Module 4: Conservation of Mass and Energy

# %% [markdown]
# The exercises in this module range from lecture 14 to lecture 20.

# %%
# !pip install handcalcs -q
# !pip install Pillow -q

# %%
import handcalcs.render
from sympy import symbols, Eq, solve
from math import sqrt,pi, cos, sin, radians,asin,atan,degrees, tan, log10
from PIL import Image

# %% [markdown]
# Global variables:

# %%
# %%render param
# g=9.81 #m/s2
# rho_water=1000 #kg/m3
# rho_Hg=13600 #kg/m3
# p_atm=101325 #Pa
# Out:
# \[
# \begin{aligned}
# g &= 9.810 \; \;\textrm{(m/s2)}
#  &\rho_{water} &= 1000 \; \;\textrm{(kg/m3)}
#  &\rho_{Hg} &= 13600 \; \;\textrm{(kg/m3)}
# \\[10pt]
#  p_{atm} &= 101325 \; \;\textrm{(Pa)}
# \end{aligned}
# \]

# %% [markdown]
# ## Problems for Lecture 14: The Bernoulli Equation

# %% [markdown]
# ---
# #### Question 1 (*)

# %% [markdown]
# Name each of the terms in the Bernoulli equation (stated below), and describe their interaction in the work-energy interpretation of this equation.
#
# $$H=\frac{p}{\rho g}+\frac{v^2}{2 g}+z$$

# %% [markdown]
# **Solution**

# %% [markdown]
# ```{Dropdown} Show code cell outputs
# 𝐻 is the total head, or the total available energy within the system.
#
# $\frac{p}{\rho g}$ is the pressure head, representing buoyancy energy per unit weight.
#
# $\frac{v^2}{2 g}$ is the velocity head, representing the kinetic energy per unit weight.
#
# 𝑧 is the elevation head, representing the potential energy per unit weight of the fluid.
#
# Pressure and weight forces do work on a fluid to increase its kinetic energy.
#
# ```

# %% [markdown]
# ---
# #### Question 2 (*)[R]

# %% [markdown]
# Water flows within a horizontal pipe of diameter 0.1 m at a velocity of 0.2 m/s. The centreline of the pipe is located at the horizontal datum. If the pressure in the pipe is 120 kPa, calculate the pressure and velocity head within the pipe.

# %% [markdown]
# ```{dropdown} Answer
# $
#  12.232 \; m \; ; 0.002 \; m \;
# $
# ```

# %% [markdown]
# ```{Dropdown} Hint
#
# The pressure head can be calculated with the following equation:
#
# $$
# pressure_m = \frac{p}{\rho g}
# $$
#
# The velocity head can be calculated with the following equation:
#
# $$
# velocity_m = \frac{V^2}{2g}
# $$
#
# You can assume the density of water is 1000 kg/m<sup>3</sup>
#
# The “m” in pressure_m and velocity_m shows that these are head values expressed in meters.
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 3
# D= 0.1 #m
# V= 0.2 #m/s
# p= 120 #kPa
# pressure_m = (p*1000)/(rho_water*g) #m
# velocity_m = V**2/(2*g) #m
# Out:
# \[
# \begin{aligned}
# \mathrm{pressure}_{m} &= \frac{ p \cdot 1000 }{ \rho_{water} \cdot g } \\&= \frac{ 120 \cdot 1000 }{ 1000 \cdot 9.810 } \\&= 12.232 \; \;\textrm{(m)}\\[10pt]
# \\[10pt]
# \mathrm{velocity}_{m} &= \frac{ \left( V \right) ^{ 2 } }{ 2 \cdot g } \\&= \frac{ \left( 0.200 \right) ^{ 2 } }{ 2 \cdot 9.810 } \\&= 0.002 \; \;\textrm{(m)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 3 (**)[R]

# %% [markdown]
# For the pipe flow described in question 2, a section of the pipe was elevated by 6 m to avoid an obstruction. Calculate the change in pressure and velocity within the pipe, and justify your answer.

# %% [markdown]
# ```{dropdown} Answer
# $
#  \;61.14 \; kPa \; ; \; the \; velocity \; doesn't \; change
# $
# ```

# %% [markdown]
# ```{Dropdown} Hint
# Use both mass and energy conservation principles in your answer. Note that you can assume that the diameter of the pipe is unchanged in the elevated section.
# ```

# %% [markdown]
# **Solution**

# %% [markdown]
# ```{Dropdown} Show code cell outputs
# The velocity doesn’t change, as this would require a change in discharge and would violate
# the conservation of mass.
#
# The pressure will reduce due to the increase in elevation
#
# Considering that $z_A=0$ and solving for $p_B$:
#
# $$
# p_B=(\frac{p_A}{\rho g}+\frac{V_{A}^2}{2g}-\frac{V_{B}^2}{2g}-z_{B})\rho g
# $$
#
# ```

# %%
# %%render long 2
# pressure_m=12.232 #m
# z_B=6 #m
#
# p_B= (pressure_m-z_B)*rho_water*g #Pa
# p_B_= p_B/1000 #kPa
# Out:
# \[
# \begin{aligned}
# \mathrm{pressure}_{m} &= 12.23 \; \;\textrm{(m)}
# \\[10pt]
# z_{B} &= 6 \; \;\textrm{(m)}
# \\[10pt]
# p_{B} &= \left( \mathrm{pressure}_{m} - z_{B} \right) \cdot \rho_{water} \cdot g \\&= \left( 12.23 - 6 \right) \cdot 1000 \cdot 9.81 \\&= 61135.92 \; \;\textrm{(Pa)}\\[10pt]
# \\[10pt]
# p_{B_{}} &= \frac{ p_{B} }{ 1000 } \\&= \frac{ 61135.92 }{ 1000 } \\&= 61.14 \; \;\textrm{(kPa)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 4 (*)[R]

# %% [markdown]
# Water discharges from a nozzle as a free jet to the atmosphere.
#
# a. If the velocity of the jet is 3 m/s, calculate the velocity head within the jet.
#
# b.Explain why the pressure head within the jet can be neglected

# %% [markdown]
# ```{dropdown} Answer
# $
# a) \; 0.46 \; m
# $
# ```

# %% [markdown]
# **Question 4 (a)**

# %% [markdown]
# ```{Dropdown} Hint
# The velocity head can be calculated with the following equation:
#
# $$
# velocity_m =\frac{V^2}{2g}
# $$
#
# The “m” in velocity_m shows that these are head values expressed in meters.
#
# Estimation Tip:
# Before or after you dive into full calculations, try estimating the velocity head using $2g \approx 20$. It's a useful way to check whether your answer falls within a reasonable range and to gradually build numerical intuition.
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# V= 3#m/s
# velocity_m= V**2/(2*g) #m
# Out:
# \[
# \begin{aligned}
# \mathrm{velocity}_{m} &= \frac{ \left( V \right) ^{ 2 } }{ 2 \cdot g } \\&= \frac{ \left( 3 \right) ^{ 2 } }{ 2 \cdot 9.81 } \\&= 0.46 \; \;\textrm{(m)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# **Question 4 (b)**

# %% [markdown]
# **Solution**

# %% [markdown]
# ```{Dropdown} Show code cell outputs
# Pressure is atmospheric within a free jet.
# ```

# %% [markdown]
# ---
# #### Question 5 (*)

# %% [markdown]
# A pipe containing oil (density = 960 kg/m<sup>3</sup>) has a diameter of 0.1 m.
#
# a. If the discharge within the pipe is 0.06 m<sup>3</sup> /s, calculate the velocity head within the pipe.
#
# b. If the pressure head is 12 m, calculate the pressure within the pipe.

# %% [markdown]
# ```{dropdown} Answer
# $
# a) \; 2.97 \; m
# $
#
# $
# b) \; 11.3 \; kPa
# $
#
# ```

# %% [markdown]
# **Question 5 (a)**

# %% [markdown]
# ```{Dropdown} Hint
# To determine the velocity head, you’ll first need to apply mass conservation to calculate the velocity in the pipe.
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# D= 0.1 #m
# rho= 96 #kg/m3
# Q= 0.06 #m3/s
# V= Q/(pi*D**2/4) #m3/s
# velocity_m= V**2/(2*g) #m
# Out:
# \[
# \begin{aligned}
# D &= 0.10 \; \;\textrm{(m)}
# \\[10pt]
# \rho &= 96 \; \;\textrm{(kg/m3)}
# \\[10pt]
# Q &= 0.06 \; \;\textrm{(m3/s)}
# \\[10pt]
# V &= \frac{ Q }{ \pi \cdot \frac{ \left( D \right) ^{ 2 } }{ 4 } } \\&= \frac{ 0.06 }{ 3.14 \cdot \frac{ \left( 0.10 \right) ^{ 2 } }{ 4 } } \\&= 7.64 \; \;\textrm{(m3/s)}\\[10pt]
# \\[10pt]
# \mathrm{velocity}_{m} &= \frac{ \left( V \right) ^{ 2 } }{ 2 \cdot g } \\&= \frac{ \left( 7.64 \right) ^{ 2 } }{ 2 \cdot 9.81 } \\&= 2.97 \; \;\textrm{(m)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# **Question 5 (b)**

# %% [markdown]
# ```{Dropdown} Hint
# The pressure can be solved from the following equation of the pressure head:
#
# $$pressure_m = \frac{p}{\rho g}$$
#
# The “m” in pressure_m shows that these are head values expressed in meters.
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# pressure_m=12 #m
# p= pressure_m*rho*g #Pa
# p_= p/1000 #kPa
# Out:
# \[
# \begin{aligned}
# \mathrm{pressure}_{m} &= 12 \; \;\textrm{(m)}
# \\[10pt]
# p &= \mathrm{pressure}_{m} \cdot \rho \cdot g \\&= 12 \cdot 96 \cdot 9.81 \\&= 11301.12 \; \;\textrm{(Pa)}\\[10pt]
# \\[10pt]
# p_{} &= \frac{ p }{ 1000 } \\&= \frac{ 11301.12 }{ 1000 } \\&= 11.30 \; \;\textrm{(kPa)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 6 (**)

# %% [markdown]
# A tank has a circular base (diameter = 1.5 m) and is filled with water to a height of 0.8 m. A small drain pipe with a diameter of 20 mm is opened at the base of the  tank, which discharges water as a free jet to the atmosphere.
#
# a. Determine the discharge of water out of the tank.
#
# b. Some time later, the height of water in the tank is 0.3 m. Determine the new discharge of water out of the tank at this time.
#
# c. Both of the above calculations assume that the flow is steady out of the tank, i.e. that the rate at which the water height in the tank changes is very slow compared to the velocity out of the tank. Based on your answer to (a), comment on whether this assumption is reasonable

# %% [markdown]
# ```{dropdown} Answer
# $
# a) \; 0.0012 \; m^3/s
# $
#
# $
# b) \; 0.0008 \; m^3/s
# $
#
# ```

# %% [markdown]
# **Question 6 (a)**

# %% [markdown]
# ```{Dropdown} Hint
# Apply the Bernoulli equation between a point at the surface of the tank and in the free jet. Assume no energy losses.
#
# Consider whether pressure is atmospheric at either of these points.
#
# ```

# %% [markdown]
# **Solution**

# %% [markdown]
# ```{Dropdown} Show code cell outputs
# Considering the jet is free to the atmosphere, the variables in point 2 will be:
#
# $$
# p_{jet}= 0 Pa \\
# z_2= 0 m
# $$
#
# Considering that point 1 is in contact with the atmosphere, we have the following:
#
# $p_{atm}$=0  Pa
#
# $V_1$= is near 0 m/s because the tank is large
#
#
# Using this values you have the following equation:
#
# $$
# z_{1}=\frac{V_{2}^2}{2g}
# $$
#
# This equation is the Torricelli's law:
#
# $$
# V= \sqrt {2gh}
# $$
#
# And the discharge of the tank is
#
# $$
# Q= V*A
# $$
# ```

# %%
# %%render long 4
# D_tank= 1.5 #m
# h= 0.8 #m
# D_small= 20 #mm
# V= sqrt(h*2*g) #m/s
# Q_a= V*pi*(D_small/1000)**2/(4) #m3/s
# Out:
# \[
# \begin{aligned}
# D_{tank} &= 1.5000 \; \;\textrm{(m)}
# \\[10pt]
# h &= 0.8000 \; \;\textrm{(m)}
# \\[10pt]
# D_{small} &= 20 \; \;\textrm{(mm)}
# \\[10pt]
# V &= \sqrt { h \cdot 2 \cdot g } \\&= \sqrt { 0.8000 \cdot 2 \cdot 9.8100 } \\&= 3.9618 \; \;\textrm{(m/s)}\\[10pt]
# \\[10pt]
# Q_{a} &= V \cdot \pi \cdot \frac{ \left( \frac{ D_{small} }{ 1000 } \right) ^{ 2 } }{ 4 } \\&= 3.9618 \cdot 3.1416 \cdot \frac{ \left( \frac{ 20 }{ 1000 } \right) ^{ 2 } }{ 4 } \\&= 0.0012 \; \;\textrm{(m3/s)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# **Question 6 (b)**

# %% [markdown]
# ```{Dropdown} Hint
# Use a similar approach to part a, recognising that the elevation of a point at the free surface will have reduced to 0.3 m.
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 4
# h_b= 0.3 #m
# V= sqrt(h_b*2*g) #m/s
# Q_b= V*pi*(D_small/1000)**2/(4) #m3/s
# Out:
# \[
# \begin{aligned}
# h_{b} &= 0.3000 \; \;\textrm{(m)}
# \\[10pt]
# V &= \sqrt { h_{b} \cdot 2 \cdot g } \\&= \sqrt { 0.3000 \cdot 2 \cdot 9.8100 } \\&= 2.4261 \; \;\textrm{(m/s)}\\[10pt]
# \\[10pt]
# Q_{b} &= V \cdot \pi \cdot \frac{ \left( \frac{ D_{small} }{ 1000 } \right) ^{ 2 } }{ 4 } \\&= 2.4261 \cdot 3.1416 \cdot \frac{ \left( \frac{ 20 }{ 1000 } \right) ^{ 2 } }{ 4 } \\&= 0.0008 \; \;\textrm{(m3/s)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# **Question 6 (c)**

# %% [markdown]
# ```{Dropdown} Hint
#
# To assess whether the steady-flow assumpt
# ion is reasonable, we need to consider whether the water level in the tank decreases slowly relative to the velocity of the outflow. For that reason, the velocity at which the free surface falls needs to be calculated. You can apply the Continuity equation and a suitable control volume to calculate this.
# ```

# %% [markdown]
# **Solution**

# %% [markdown]
# ```{Dropdown} Show code cell outputs
# $$
# Q= V_1*A_1 = V_2*A_2
# $$
#
#
# $$
# A_1= \frac{\pi D^2}{4}
# $$
# ```

# %%
# %%render long 2
# V_1= Q_a*4/(pi*D_tank**2)*1000 #mm/s
# Out:
# \[
# \begin{aligned}
# V_{1} &= Q_{a} \cdot \frac{ 4 }{ \pi \cdot \left( D_{tank} \right) ^{ 2 } } \cdot 1000 \\&= 0.00 \cdot \frac{ 4 }{ 3.14 \cdot \left( 1.50 \right) ^{ 2 } } \cdot 1000 \\&= 0.70 \; \;\textrm{(mm/s)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ```{Dropdown} Show code cell outputs
# The initial change in water level of the tank is 0.7 mm/s, so this is reasonable.
# ```

# %% [markdown]
# ---
# #### Question 7 (*)[R]

# %% [markdown]
# Water flows from a pipe of 1m diameter through a nozzle of 0.2m diameter before exiting as a free jet.
#
# a. If the velocity in the free jet is 3 m/s, calculate the discharge and velocity in the pipe.
#
# b. Calculate the pressure within the pipe.
#
# c. State any assumptions made in the above calculations.

# %% [markdown]
# ```{dropdown} Answer
# $
# a) 0.094 \; m^3/s \; ; 0.120 \; m/s \;
# $
#
# $
# b) \; 4.49 \; kPa
# $
#
# ```

# %% [markdown]
# **Question 7 (a)**

# %% [markdown]
# ```{Dropdown} Hint
# Apply mass conservation to calculate these quantities.
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 3
# D_pipe= 1 #m
# D_nozzle= 0.2 #m
# V_nozzle= 3 #m/s
# A_nozzle= pi*D_nozzle**2/4 #m2
# Q= V_nozzle*A_nozzle #m3/s
# A_pipe= pi*D_pipe**2/4 #m2
# V_pipe=Q/A_pipe #m/s
# Out:
# \[
# \begin{aligned}
# A_{nozzle} &= \pi \cdot \frac{ \left( D_{nozzle} \right) ^{ 2 } }{ 4 } \\&= 3.142 \cdot \frac{ \left( 0.200 \right) ^{ 2 } }{ 4 } \\&= 0.031 \; \;\textrm{(m2)}\\[10pt]
# \\[10pt]
# Q &= V_{nozzle} \cdot A_{nozzle} \\&= 3 \cdot 0.031 \\&= 0.094 \; \;\textrm{(m3/s)}\\[10pt]
# \\[10pt]
# A_{pipe} &= \pi \cdot \frac{ \left( D_{pipe} \right) ^{ 2 } }{ 4 } \\&= 3.142 \cdot \frac{ \left( 1 \right) ^{ 2 } }{ 4 } \\&= 0.785 \; \;\textrm{(m2)}\\[10pt]
# \\[10pt]
# V_{pipe} &= 0.120 \; \;\textrm{(m/s)}
# \end{aligned}
# \]

# %% [markdown]
# **Question 7 (b)**

# %% [markdown]
# ```{Dropdown} Hint
# We can use Bernoulli equation to calculate the pressure within the pipe:
#
# $$
# \frac{p_{pipe}}{\gamma}+\frac{V_{pipe}^2}{2g}+z_{pipe}=\frac{p_{nozzle}}{\gamma}+\frac{V_{nozzle}^2}{2g}+z_{nozzle}
# $$
#
# Consider which (if any) of these terms can be cancelled in your calculations.
# ```

# %% [markdown]
# **Solution**

# %% [markdown]
# ```{Dropdown} Show code cell outputs
# The assumptions for this problem are the following:
#
# $z_{pipe}=z_{nozzle}$ (horizontal pipe)
#
# $p_{nozzle}=0 Pa$ (it is exposed to atmospheric pressure)
#
# ```

# %%
# %%render long 2
# p_pipe= (V_nozzle**2/(2*g)-V_pipe**2/(2*g))*rho_water*g #Pa
# p_pipe_= p_pipe/1000 #kPa
# Out:
# \[
# \begin{aligned}
# p_{pipe} &= \left( \frac{ \left( V_{nozzle} \right) ^{ 2 } }{ 2 \cdot g } - \frac{ \left( V_{pipe} \right) ^{ 2 } }{ 2 \cdot g } \right) \cdot \rho_{water} \cdot g \\&= \left( \frac{ \left( 3 \right) ^{ 2 } }{ 2 \cdot 9.81 } - \frac{ \left( 0.12 \right) ^{ 2 } }{ 2 \cdot 9.81 } \right) \cdot 1000 \cdot 9.81 \\&= 4492.80 \; \;\textrm{(Pa)}\\[10pt]
# \\[10pt]
# p_{pipe_{}} &= \frac{ p_{pipe} }{ 1000 } \\&= \frac{ 4492.80 }{ 1000 } \\&= 4.49 \; \;\textrm{(kPa)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# **Question 7 (c)**

# %% [markdown]
# **Solution**

# %% [markdown]
# ```{Dropdown} Show code cell outputs
# Horizontal pipe, steady flow, incompressible water (and density of 1000 kg/m<sup>3</sup>), no energy losses through nozzle, jet diameter equal to nozzle diameter, uniform flow in both cross sections.
# ```

# %% [markdown]
# ---
# #### Question 8(*)[R]

# %% [markdown]
# Water flows from a large reservoir through a 100 mm pipe before exiting the pipe as a free jet at a location 5 m below the water surface of the reservoir. Calculate the discharge within the pipe.

# %% [markdown]
# ```{dropdown} Answer
# $
# 0.08 \; m^3/s
# $
# ```

# %% [markdown]
# ```{dropdown} Hint
# Apply the Bernoulli equation to determine the velocity. When calculating the discharge, you may assume that the free jet has the same diameter as the pipe.
# ```

# %% [markdown]
# **Solution**

# %% [markdown]
# ```{Dropdown} Show code cell outputs
# The assumptions for this problem are the following:
#
# $p_{atm}$= 0 Pa
# $V_1$= is near 0 m/s because the reservoir is large
# $p_{pipe}$= 0 Pa because it is exposed to atmospheric pressure
#
#
# Considering these simplifications, the Bernoulli equation simplifies to the Toricelli equation
#
# $$
# V= \sqrt {2gh}
# $$
# ```

# %%
# %%render long 2
# D= 100 #mm
# z= 5#m
# V= sqrt(z*2*g) #m/s
# Q_b= V*pi*(D/1000)**2/(4) #m3/s
# Out:
# \[
# \begin{aligned}
# D &= 100 \; \;\textrm{(mm)}
# \\[10pt]
# z &= 5 \; \;\textrm{(m)}
# \\[10pt]
# V &= \sqrt { z \cdot 2 \cdot g } \\&= \sqrt { 5 \cdot 2 \cdot 9.81 } \\&= 9.90 \; \;\textrm{(m/s)}\\[10pt]
# \\[10pt]
# Q_{b} &= V \cdot \pi \cdot \frac{ \left( \frac{ D }{ 1000 } \right) ^{ 2 } }{ 4 } \\&= 9.90 \cdot 3.14 \cdot \frac{ \left( \frac{ 100 }{ 1000 } \right) ^{ 2 } }{ 4 } \\&= 0.08 \; \;\textrm{(m3/s)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 9 (**)[R]

# %% [markdown]
# Oil (density = 940 kg/m<sup>3</sup>) flow through a pipe of diameter 120 mm. At some location in the pipe, the diameter is reduced to 90 mm.
#
# a. If the pressure and velocity in the wider (120 mm) section of the pipe are 280 kPa and 5 m/s respectively, calculate the discharge in the pipe.
#
# b. Calculate the velocity and pressure in the constricted section.

# %% [markdown]
# ```{dropdown} Answer
# $
# a) 0.057 \; m^3/s \;
# $
#
# $
# b) 8.89 \; m/s \; ; 254.61 \; kPa \;
# $
#
# ```

# %% [markdown]
# **Question 9 (a)**

# %% [markdown]
# ```{Dropdown} Hint
# The discharge in the pipe can be calculated as:
#
# $$Q=V_1A_1$$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 3
# rho= 940 #kg/m3
# D_1= 120/1000 #m
# D_2= 90/1000 #m
# p_1= 280*1000 #Pa
# V_1= 5 #m/s
# A_1= pi*D_1**2/4 #m2
# Q= V_1*A_1 #m3/s
# Out:
# \[
# \begin{aligned}
# A_{1} &= \pi \cdot \frac{ \left( D_{1} \right) ^{ 2 } }{ 4 } \\&= 3.142 \cdot \frac{ \left( 0.120 \right) ^{ 2 } }{ 4 } \\&= 0.011 \; \;\textrm{(m2)}\\[10pt]
# \\[10pt]
# Q &= V_{1} \cdot A_{1} \\&= 5 \cdot 0.011 \\&= 0.057 \; \;\textrm{(m3/s)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# **Question 9 (b)**

# %% [markdown]
# ```{Dropdown} Hint
# The velocity can be calculated as:
#
# $$V_2=Q/A_2$$
#
# To calculate the pressure we can use the Bernoulli equation:
#
# $$
# \frac{p_{1}}{\gamma}+\frac{V_{1}^2}{2g}+z_{1}=\frac{p_{2}}{\gamma}+\frac{V_{2}^2}{2g}+z_{2}
# $$
# ```

# %% [markdown]
# **Solution**

# %% [markdown]
# ```{Dropdown} Show code cell outputs
# The assumptions for this problem are:
#
# $z_{1}=z_{2}$ (horizontal pipe)
#
# ```

# %%
# %%render long 2
#
# A_2= pi*D_2**2/4 #m2
# V_2= Q/A_2 #m/s
# p_2= (p_1/(rho*g)+V_1**2/(2*g)-V_2**2/(2*g))*rho*g #Pa
# p_2_= p_2/1000 #kPa
# Out:
# \[
# \begin{aligned}
# A_{2} &= \pi \cdot \frac{ \left( D_{2} \right) ^{ 2 } }{ 4 } \\&= 3.14 \cdot \frac{ \left( 0.09 \right) ^{ 2 } }{ 4 } \\&= 0.01 \; \;\textrm{(m2)}\\[10pt]
# \\[10pt]
# V_{2} &= \frac{ Q }{ A_{2} } \\&= \frac{ 0.06 }{ 0.01 } \\&= 8.89 \; \;\textrm{(m/s)}\\[10pt]
# \\[10pt]
# p_{2} &= \left( \frac{ p_{1} }{ \rho \cdot g } + \frac{ \left( V_{1} \right) ^{ 2 } }{ 2 \cdot g } - \frac{ \left( V_{2} \right) ^{ 2 } }{ 2 \cdot g } \right) \cdot \rho \cdot g \\&= \left( \frac{ 280000 }{ 940 \cdot 9.81 } + \frac{ \left( 5 \right) ^{ 2 } }{ 2 \cdot 9.81 } - \frac{ \left( 8.89 \right) ^{ 2 } }{ 2 \cdot 9.81 } \right) \cdot 940 \cdot 9.81 \\&= 254614.20 \; \;\textrm{(Pa)}\\[10pt]
# \\[10pt]
# p_{2_{}} &= \frac{ p_{2} }{ 1000 } \\&= \frac{ 254614.20 }{ 1000 } \\&= 254.61 \; \;\textrm{(kPa)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 10(***)

# %% [markdown]
# Water flows in an open channel with a constant width of 1.5 m. At some point in the channel A, the depth is 0.5 m and the velocity is 2.5 m/s. The channel then steps down 1.0 m in a smooth transition to point B. Show that the water depth at B, 𝑑𝐵,
# can be expressed as: $d_B= \frac{V_Ad_A}{\sqrt{V_A^2+2g(d_A+1-d_B)}}$ where 𝑣𝐴 is the velocity at point A, 𝑔 is the gravitational acceleration, and 𝑑𝐴 is the water depth at point A.

# %% [markdown]
# ```{Dropdown} Hint
# Use the Continuity equation to relate the velocities at points A and B:
#
# $$V_A * (d_A * b) = V_B * (d_B * b)$$
#
# $$V_A * d_A = V_B * d_B$$
#
# Then use this to substitute into the Bernoulli equation:
#
# $$p_A/γ + V_A^2/(2g) + z_A = p_B/γ + V_B^2/(2g) + z_B$$
#
# Replace the pressure terms using:
#
# $$p_A = ρ * g * d_A\\
# p_B = ρ * g * d_B
# $$
#
# ```

# %% [markdown]
# **Solution**

# %% [markdown]
# ```{Dropdown} Show code cell outputs
#
# We can use Bernoulli equation to show that the water depth can be expressed as the equation showed in the question.
#
# $$
# \frac{p_{A}}{\gamma}+\frac{V_{A}^2}{2g}+z_{A}=\frac{p_{B}}{\gamma}+\frac{V_{B}^2}{2g}+z_{B}
# $$
#
# The assumptions are the following
#
# $$
# z_B= 0 m
# $$
#
# The pressure in point 1 and 2 can be expressed with the following equation
#
# $$
# p_A= \rho gd_A\\
# p_B=\rho gd_B\\
# $$
#
# $$
# d_A +\frac{V_{A}^2}{2g}+z_A= d_B+\frac{V_{B}^2}{2g}\\
# $$
# $$
# z_A= 1 m
# $$
#
# Then we can used the the conservation of mass to calculate the velocity in section B.
#
# $$
# Q_A=Q_B\\
# $$
#
# $$
# V_A*d_A*b= V_B*d_B*b\\
# $$
# $$
# V_B=\frac{V_A*d_A}{d_B}\\
# $$
#
# $$
# d_A +\frac{V_{A}^2}{2g}+z_A= d_B+\frac{V_A^2*d_A^2}{d_B^22g}
# $$
#
# Organizing the equation we have that
#
# $$
# 2g(d_A+1)+V_A^2= \frac {V_A^2d_A^2}{d_B^2}+db*2g\\
# 2g(d_A+1-d_B)+V_A^2= \frac {V_A^2d_A^2}{d_B^2}\\
# d_B^2=V_A^2d_A^2\frac{1}{V_A^2+2g(d_A+1-d_B)}\\
# d_B= \frac{V_Ad_A}{\sqrt{V_A^2+2g(d_A+1-d_B)}}
# $$
# ```

# %% [markdown]
# ## Problems for Lecture 15: Energy Grade Line and Hydraulic Grade Line

# %% [markdown]
# ---
# #### Question 1 (*)[R]

# %% [markdown]
# Water flows within a horizontal pipe of diameter 0.1 m at a velocity of 0.25 m/s. The centreline of the pipe is located 2.5 m above the horizontal datum. If the pressure in the pipe is 120 kPa, calculate the height of the EGL and HGL relative to datum.

# %% [markdown]
# ```{dropdown} Answer
# $
# 14.74 \; m \; , \;14.73 \; m
# $
# ```

# %% [markdown]
# ```{dropdown} Hint
# The energy grade line can be calculated as:
#
# $$EGL=\frac{p}{\gamma}+\frac{V^2}{2g}+z$$
#
#
# The hydraulic grade line can be calculated as:
#
# $$HGL=\frac{p}{\gamma}+z$$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# D= 0.1 #m
# V= 0.25 #m/s
# z= 2.5 #m
# p=120*1000 #Pa
#
# EGL= p/(rho_water*g)+V**2/(2*g)+z #m
# HGL= p/(rho_water*g)+z #m
# Out:
# \[
# \begin{aligned}
# D &= 0.10 \; \;\textrm{(m)}
# \\[10pt]
# V &= 0.25 \; \;\textrm{(m/s)}
# \\[10pt]
# z &= 2.50 \; \;\textrm{(m)}
# \\[10pt]
# p &= 120000 \; \;\textrm{(Pa)}
# \\[10pt]
# \mathrm{EGL} &= \frac{ p }{ \rho_{water} \cdot g } + \frac{ \left( V \right) ^{ 2 } }{ 2 \cdot g } + z \\&= \frac{ 120000 }{ 1000 \cdot 9.81 } + \frac{ \left( 0.25 \right) ^{ 2 } }{ 2 \cdot 9.81 } + 2.50 \\&= 14.74 \; \;\textrm{(m)}\\[10pt]
# \\[10pt]
# \mathrm{HGL} &= \frac{ p }{ \rho_{water} \cdot g } + z \\&= \frac{ 120000 }{ 1000 \cdot 9.81 } + 2.50 \\&= 14.73 \; \;\textrm{(m)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 2 (*)

# %% [markdown]
# Water flows from a large reservoir through a 200 mm pipe before exiting the pipe as a free jet at a location 4.5 m below the water surface of the reservoir.
#
# a. Calculate the discharge within the pipe.
#
# b. Draw the HGL and EGL for this problem.

# %% [markdown]
# ```{dropdown} Answer
# $
# a)\; 0.295 \; m^3/s
# $
# ```

# %% [markdown]
# **Question 2 (a)**

# %% [markdown]
# ```{dropdown} Hint
# The discharge flow within the pipe can the calculated as:
#
# $$
# Q=V*A
# $$
#
# And the velocity can be calculated with the Toricelli Law
#
# $$
# V= \sqrt {2gh}
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 3
# D= 200 #mm
# h= 4.5 #m
# V= sqrt(h*2*g) #m/s
# Q= V*pi*(D/1000)**2/(4) #m3/s
# Out:
# \[
# \begin{aligned}
# D &= 200 \; \;\textrm{(mm)}
# \\[10pt]
# h &= 4.500 \; \;\textrm{(m)}
# \\[10pt]
# V &= \sqrt { h \cdot 2 \cdot g } \\&= \sqrt { 4.500 \cdot 2 \cdot 9.810 } \\&= 9.396 \; \;\textrm{(m/s)}\\[10pt]
# \\[10pt]
# Q &= V \cdot \pi \cdot \frac{ \left( \frac{ D }{ 1000 } \right) ^{ 2 } }{ 4 } \\&= 9.396 \cdot 3.142 \cdot \frac{ \left( \frac{ 200 }{ 1000 } \right) ^{ 2 } }{ 4 } \\&= 0.295 \; \;\textrm{(m3/s)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# **Question 2 (b)**

# %% [markdown]
# ```{dropdown} Hint
# The EGL (Energy Grade Line) is the total energy at each point along the flow. This includes the kinetic energy and the potential energy. Considering there is no friction loss in this exercise, the EGL should be a straight line, strarting from the water surface to the jet exit.
#
# $$
# EGL= \frac{p}{\gamma}+\frac{V^2}{2g} +z
# $$
#
# The HGL (Hydraulic Grade Line) represents the sum of the pressure head and the elevation head. At the reservoir, the HGL will be at the same level of the water surface, but as the water moves down the jet, the HGl will drop. This occured because the pressure head in the free jet is essentially zero as the presurre is atmospheric.
#
# $$
# HGL= \frac{p}{\gamma}+z
# $$
#
# ```

# %% [markdown]
# **Solution**

# %%
from PIL import Image
img = Image.open(r"figures/14.2.png")
img
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 from PIL import Image
# ----> 2 img = Image.open(r"figures/14.2.png")
#       3 img
#
# File C:\ProgramData\anaconda3\Lib\site-packages\PIL\Image.py:3227, in open(fp, mode, formats)
#    3224     filename = fp
#    3226 if filename:
# -> 3227     fp = builtins.open(filename, "rb")
#    3228     exclusive_fp = True
#    3230 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'figures/14.2.png'

# %% [markdown]
# ---
# #### Question 3 (**)[R]

# %% [markdown]
# In the situation illustrated in the figure, the water height h is 200 mm.
#
# a. Calculate the discharge through the pipe.
#
# b. Calculate the pressure in the narrow section.
#
# c. Draw the EGL and HGL for this problem.

# %%
from PIL import Image
img = Image.open(r"figures/14.3.png")
img
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 from PIL import Image
# ----> 2 img = Image.open(r"figures/14.3.png")
#       3 img
#
# File C:\ProgramData\anaconda3\Lib\site-packages\PIL\Image.py:3227, in open(fp, mode, formats)
#    3224     filename = fp
#    3226 if filename:
# -> 3227     fp = builtins.open(filename, "rb")
#    3228     exclusive_fp = True
#    3230 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'figures/14.3.png'

# %% [markdown]
# ```{dropdown} Answer
# $
# a) \;0.0156 \; m^3/s
# $
#
# $
# b) \;-29.4 \; kPa \; (gauge\;pressure)
# $
# ```

# %% [markdown]
# **Question 3 (a)**

# %% [markdown]
# ```{dropdown} Hint
# From the Bernoulli equation we have:
#
# $$V_3= \sqrt{2gh}$$
#
# And the discharge can be calculated as:
#
# $$Q=V_3A_3$$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 4
# h= 200/1000 #m
# D_1= 100/1000 #m
# D_2= 50/1000 #m
# D_3= 100/1000 #m
#
# V_3= sqrt(2*g*h) #m/s
# A_3= pi*D_3**2/4 #m2
# Q= V_3*A_3 #m3/s
# Out:
# \[
# \begin{aligned}
# h &= \frac{ 200 }{ 1000 } &= 0.2000 \; \;\textrm{(m)}
# \\[10pt]
# D_{1} &= \frac{ 100 }{ 1000 } &= 0.1000 \; \;\textrm{(m)}
# \\[10pt]
# D_{2} &= \frac{ 50 }{ 1000 } &= 0.0500 \; \;\textrm{(m)}
# \\[10pt]
# D_{3} &= \frac{ 100 }{ 1000 } &= 0.1000 \; \;\textrm{(m)}
# \\[10pt]
# V_{3} &= \sqrt { 2 \cdot g \cdot h } \\&= \sqrt { 2 \cdot 9.8100 \cdot 0.2000 } \\&= 1.9809 \; \;\textrm{(m/s)}\\[10pt]
# \\[10pt]
# A_{3} &= \pi \cdot \frac{ \left( D_{3} \right) ^{ 2 } }{ 4 } \\&= 3.1416 \cdot \frac{ \left( 0.1000 \right) ^{ 2 } }{ 4 } \\&= 0.0079 \; \;\textrm{(m2)}\\[10pt]
# \\[10pt]
# Q &= V_{3} \cdot A_{3} \\&= 1.9809 \cdot 0.0079 \\&= 0.0156 \; \;\textrm{(m3/s)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# **Question 3 (b)**

# %% [markdown]
# ```{dropdown} Hint
# From the Bernoulli equation we have:
#
# $$
# \frac{p_{1}}{\gamma}+\frac{V_{1}^2}{2g}+z_{1}=\frac{p_{2}}{\gamma}+\frac{V_{2}^2}{2g}+z_{2}
# $$
#
# The assumptions are the following
#
# $p_1=0 Pa$  (atmosferic presure)
#
# $V_1= 0 m/s$ (because it is a reservoir)
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# V_2= Q/(pi*D_2**2/4) #m/s
# z_1=h #m
# p_2= (z_1-V_2**2/(2*g))*rho_water*g #Pa
# p_2_= p_2/1000 #kPa
# Out:
# \[
# \begin{aligned}
# V_{2} &= \frac{ Q }{ \pi \cdot \frac{ \left( D_{2} \right) ^{ 2 } }{ 4 } } \\&= \frac{ 0.02 }{ 3.14 \cdot \frac{ \left( 0.05 \right) ^{ 2 } }{ 4 } } \\&= 7.92 \; \;\textrm{(m/s)}\\[10pt]
# \\[10pt]
# z_{1} &= 0.20 \; \;\textrm{(m)}
# \\[10pt]
# p_{2} &= \left( z_{1} - \frac{ \left( V_{2} \right) ^{ 2 } }{ 2 \cdot g } \right) \cdot \rho_{water} \cdot g \\&= \left( 0.20 - \frac{ \left( 7.92 \right) ^{ 2 } }{ 2 \cdot 9.81 } \right) \cdot 1000 \cdot 9.81 \\&= -29430.00 \; \;\textrm{(Pa)}\\[10pt]
# \\[10pt]
# p_{2_{}} &= \frac{ p_{2} }{ 1000 } \\&= \frac{ -29430.00 }{ 1000 } \\&= -29.43 \; \;\textrm{(kPa)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# **Question 3 (c)**

# %% [markdown]
# ```{dropdown} Hint
# The EGL (Energy Grade Line) is the total energy at each point along the flow. This includes the kinetic energy and the potential energy. Considering there is no friction loss in this exercise, the EGL should be a straight line at the level of the water surface.
#
# $$
# EGL= \frac{p}{\gamma}+\frac{V^2}{2g} +z
# $$
#
# The HGL (Hydraulic Grade Line) represents the sum of the pressure head and the elevation head. At the reservoir, the HGL will be at the same level of the water surface. As the water flows down the pipe, the HGL will drop due to the increasing velocity, but when the diameter is reduced, the HGL decreases due to the increment in velocity. At the pipe exit, the pressure head becomes zero, so the HGL will end at the same level as the exit of the pipeline.
#
# $$
# HGL= \frac{p}{\gamma}+z
# $$
# ```

# %% [markdown]
# **Solution**

# %%
from PIL import Image
img = Image.open(r"figures/14.3S.png")
img

# %% [markdown]
# ---
# #### Question 4 (**)[R]

# %% [markdown]
# Water flows out of a large tank and through the pipeline as shown in Figure 2.
#
# a. Construct the energy grade line and hydraulic grade line for the pipe, labelling the relevant quantities on your diagram.
#
# b. Using your solution to part (a), calculate the pressure and velocity within the 200mm diameter section of the pipe.
#
# c. State any assumptions you have made within your answers to (a) and (b)

# %%
from PIL import Image
img = Image.open(r"figures/14.4.png")
img

# %% [markdown]
# ```{dropdown} Answer
# $
# b) \;43.53 \; kPa \;,\; 3.32 \; m/s \;
# $
# ```

# %% [markdown]
# **Question 4 (a)**

# %% [markdown]
# ```{dropdown} Hint
# The EGL (Energy Grade Line) is the total energy at each point along the flow. This includes the kinetic energy and the potential energy. Considering there is no friction loss in this exercise, the EGL should be a straight line, strarting from the water surface to the exit of the pipeline.
#
# $$
# EGL= \frac{p}{\gamma}+\frac{V^2}{2g} +z
# $$
#
# The HGL (Hydraulic Grade Line) represents the sum of the pressure head and the elevation head. At the reservoir, the HGL will be at the same level of the water surface, but as the water flows down the pipe, the HGL will drp at each point due to the increasing velocity. At the pipe exit, the pressure head becomes zero, so the HGL will end at the same level as the exit of the pipeline
#
# $$
# HGL= \frac{p}{\gamma}+z
# $$
# ```

# %% [markdown]
# **Solution**

# %%
from PIL import Image
img = Image.open(r"figures/14.4S.png")
img

# %% [markdown]
# **Question 4 (b)**

# %% [markdown]
# ```{dropdown} Hint
# The velocity can be calculated with the Toricelli equation in the pipe exit.
#
# $$
# V_3=\sqrt (2gh)
# $$
#
# Once the velocity at the exit is calculated, the discharge can be determined with:
#
# $$
# Q_3=V_3*A_3
# $$
#
# Once the discharge is calculated, the velocity in the 200 mm diameter pipe can be determined by using the conservation of mass
#
# $$
# Q_1=Q_2=Q_3\\
# Q_3=V_2*A_2\\
# V_2=\frac{Q_3}{A_2}\\
# V_2=\frac{Q_34}{\pi D^2}
# $$
#
# Once the velocity in this pipe is calculated, the Bernoulli equation can be determine between the surface of the tank and that pipe
#
# $$
# \frac{p_{atm}}{\gamma}+\frac{V_1^2}{2g} +z_1=\frac{p_2}{\gamma}+\frac{V_2^2}{2g} +z_2
# $$
#
# The following assumptions can be made
#
# $$
# p_{atm}=0 Pa\\
# z_2= 0 m\\
# V_1= 0 m/s
# $$
#
# Using this, the Bernoulli equation for this exercise is:
#
#
# $$
# z_1=\frac{p_2}{\gamma}+\frac{V_2^2}{2g}
# $$
#
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# z_1= 5 #m
# D_1= 200 #mm
# D_2= 100 #mm
# D_3= 100#mm
# z_t= 9 #m
#
# V_3= sqrt (2*g*z_t) #m/s
# Q_3= V_3*pi*(D_3/1000)**2/4 #m3/s
#
# V_2= Q_3*4/(pi*(D_1/1000)**2) #m/s
#
# p_2= ((z_1-V_2**2/(2*g))*rho_water*g)/1000 #kPa
# Out:
# \[
# \begin{aligned}
# z_{1} &= 5 \; \;\textrm{(m)}
# \\[10pt]
# D_{1} &= 200 \; \;\textrm{(mm)}
# \\[10pt]
# D_{2} &= 100 \; \;\textrm{(mm)}
# \\[10pt]
# D_{3} &= 100 \; \;\textrm{(mm)}
# \\[10pt]
# z_{t} &= 9 \; \;\textrm{(m)}
# \\[10pt]
# V_{3} &= \sqrt { 2 \cdot g \cdot z_{t} } \\&= \sqrt { 2 \cdot 9.81 \cdot 9 } \\&= 13.29 \; \;\textrm{(m/s)}\\[10pt]
# \\[10pt]
# Q_{3} &= V_{3} \cdot \pi \cdot \frac{ \left( \frac{ D_{3} }{ 1000 } \right) ^{ 2 } }{ 4 } \\&= 13.29 \cdot 3.14 \cdot \frac{ \left( \frac{ 100 }{ 1000 } \right) ^{ 2 } }{ 4 } \\&= 0.10 \; \;\textrm{(m3/s)}\\[10pt]
# \\[10pt]
# V_{2} &= Q_{3} \cdot \frac{ 4 }{ \pi \cdot \left( \frac{ D_{1} }{ 1000 } \right) ^{ 2 } } \\&= 0.10 \cdot \frac{ 4 }{ 3.14 \cdot \left( \frac{ 200 }{ 1000 } \right) ^{ 2 } } \\&= 3.32 \; \;\textrm{(m/s)}\\[10pt]
# \\[10pt]
# p_{2} &= \frac{ \left( z_{1} - \frac{ \left( V_{2} \right) ^{ 2 } }{ 2 \cdot g } \right) \cdot \rho_{water} \cdot g }{ 1000 } \\&= \frac{ \left( 5 - \frac{ \left( 3.32 \right) ^{ 2 } }{ 2 \cdot 9.81 } \right) \cdot 1000 \cdot 9.81 }{ 1000 } \\&= 43.53 \; \;\textrm{(kPa)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# **Question 4 (c)**

# %% [markdown]
# **Solution**

# %% [markdown]
# ```{Dropdown} Show code cell outputs
#
# ```
# Incompressible fluid, no losses in pipe, diameter of free discharge is equal to pipe diameter.

# %% [markdown]
# ---
# #### Question 5 (**)[R]

# %% [markdown]
# An object is placed in an open channel such that a stagnation point (zero velocity) is created on the leading edge of the object. You may assume that the density of water is equal to 1000 kg/m<sup>3</sup> for this problem.
#
# a. If the water in the channel is flowing at a velocity of 2 m/s, calculate the dynamic pressure at the stagnation point. {2 kPa}
#
# b. If the object is replaced by a pitot tube, which also creates a stagnation point within the same flow, calculate the height to which water would rise in the pitot tube. {h=0.204 m}
#
# c. A short time later, the velocity in the open channel has changed. The water level in the pitot tube is now 150 mm. Calculate the new velocity in the channel. {1.72 m/s}
#
# d. Explain which line is represented by the water level in the pitot tube, and which line is represented by the water level in the channel itself.

# %% [markdown]
# ```{dropdown} Answer
# $
# a) \;2 \; kPa
# $
#
# $
# b) \;h= \; 0.204\; m
# $
#
# $
# c) \;1.72 \; m/s
# $
# ```

# %% [markdown]
# **Question 5 (a)**

# %% [markdown]
# ```{dropdown} Hint
# From Bernoulli equation we have:
#
# $$
# \frac{p_{1}}{\gamma}+\frac{V_1^2}{2g} +z_1=\frac{p_2}{\gamma}+\frac{V_2^2}{2g} +z_2
# $$
#
# Assuming the following we can solve the pressure at the stagnation point:
#
# $p_1=0 Pa$ (atmosferic pressure)
# $z_1=z_2=0 m$ (horizontal channel)
# $V_1=0 Pa$ (given in the question)
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 1
# V_1=0 #m/s
# V_2= 2 #m/s
#
# p_2= ((V_2**2/(2*g))*rho_water*g)/1000 #kPa
# Out:
# \[
# \begin{aligned}
# V_{1} &= 0 \; \;\textrm{(m/s)}
# \\[10pt]
# V_{2} &= 2 \; \;\textrm{(m/s)}
# \\[10pt]
# p_{2} &= \frac{ \left( \frac{ \left( V_{2} \right) ^{ 2 } }{ 2 \cdot g } \right) \cdot \rho_{water} \cdot g }{ 1000 } \\&= \frac{ \left( \frac{ \left( 2 \right) ^{ 2 } }{ 2 \cdot 9.8 } \right) \cdot 1000 \cdot 9.8 }{ 1000 } \\&= 2.0 \; \;\textrm{(kPa)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# **Question 5 (b)**

# %% [markdown]
# ```{dropdown} Hint
# The height to which water would rise in the pitot tube can be solved from the following equation:
#
# $$p=\rho gh$$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 3
# h= p_2*1000/(rho_water*g) #m
# Out:
# \[
# \begin{aligned}
# h &= p_{2} \cdot \frac{ 1000 }{ \rho_{water} \cdot g } \\&= 2.000 \cdot \frac{ 1000 }{ 1000 \cdot 9.810 } \\&= 0.204 \; \;\textrm{(m)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# **Question 5 (c)**

# %% [markdown]
# ```{dropdown} Hint
# The velocity can be calculated using the following equation:
#
# $$V=\sqrt{2gh}$$
#
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# h=150/1000 #m
# V= sqrt(2*g*h) #m/s
# Out:
# \[
# \begin{aligned}
# h &= 0.15 \; \;\textrm{(m)}
# \\[10pt]
# V &= \sqrt { 2 \cdot g \cdot h } \\&= \sqrt { 2 \cdot 9.81 \cdot 0.15 } \\&= 1.72 \; \;\textrm{(m/s)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# **Question 5 (d)**

# %% [markdown]
# **Solution**

# %% [markdown]
# ```{Dropdown} Show code cell outputs
# The water level in the pitot tube represents the EGL, while the water level in the channel represents the HGL.
# ```

# %% [markdown]
# ---
# #### Question 6 (**)[R]

# %% [markdown]
# Water flows through a pipe (diameter of 50 mm). A pitot tube placed in the flow measures a water height of 150 mm relative to the centre of the pipe, and a piezometer at the side of the pipe measures a water height of 90 mm relative to the
# centre of the pipe.
#
# a. Determine the average velocity of the water flowing in the pipe. {1.08 m/s}
#
# b. Calculate the dynamic pressure at the stagnation point of the pitot tube. {589 Pa}
#
# c. Draw the EGL and HGL for this problem.

# %% [markdown]
# ```{dropdown} Answer
# $
# a) \;1.08 \; m/s
# $
#
# $
# b) \;589 \; Pa
# $
#
# ```

# %% [markdown]
# **Question 6 (a)**

# %% [markdown]
# ```{dropdown} Hint
# The piezometer measures the pressure head component of the Bernoulli equation along with the elevation head (𝑧). The Pitot tube measures the pressure head, the velocity head, and the elevation head (z). This means the Pitot tube measures the Energy Grade Line (EGL) while the piezometer measures the Hydraulic Grade Line (HGL).
#
# Considering the equation for HGL:
#
# $$
# HGL= \frac{p}{\gamma} + z
# $$
#
# And the equation for EGL:
#
# $$
# EGL= \frac{p}{\gamma} + \frac{V^2}{2g}+ z
# $$
#
# We know that EGL is 0.15 m, and the HGL is 0.09 m. If we use this values with the equation we have
#
# $$
# 0.09= \frac{p}{\gamma} + z
# $$
#
# And the equation for EGL:
#
# $$
# 0.15= \frac{p}{\gamma} + \frac{V^2}{2g}+ z
# $$
#
# $$
# 0.15 = 0.09 + \frac{V^2}{2g}
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# D= 50 #mm
# h_pit=150#mm
# h_p=90 #mm
#
# V= sqrt (2*g*((h_pit/1000)-h_p/1000)) #m/s
# Out:
# \[
# \begin{aligned}
# D &= 50 \; \;\textrm{(mm)}
# \\[10pt]
# h_{pit} &= 150 \; \;\textrm{(mm)}
# \\[10pt]
# h_{p} &= 90 \; \;\textrm{(mm)}
# \\[10pt]
# V &= \sqrt { 2 \cdot g \cdot \left( \left( \frac{ h_{pit} }{ 1000 } \right) - \frac{ h_{p} }{ 1000 } \right) } \\&= \sqrt { 2 \cdot 9.81 \cdot \left( \left( \frac{ 150 }{ 1000 } \right) - \frac{ 90 }{ 1000 } \right) } \\&= 1.08 \; \;\textrm{(m/s)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# **Question 6 (b)**

# %% [markdown]
# ```{dropdown} Hint
# The dynamic pressure (𝑞) can be calculated using the formula:
#
# $$
# \Delta p= \frac{\rho V^2}{2}
# $$
#
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 0
# Delta_p= rho_water*V**2/2 #Pa
# Out:
# \[
# \begin{aligned}
# \Delta_{p} &= \rho_{water} \cdot \frac{ \left( V \right) ^{ 2 } }{ 2 } \\&= 1000 \cdot \frac{ \left( 1 \right) ^{ 2 } }{ 2 } \\&= 589 \; \;\textrm{(Pa)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# **Question 6 (c)**

# %% [markdown]
# ```{dropdown} Hint
# The piezometer measures the pressure head component of the Bernoulli equation along with the elevation head (𝑧). The Pitot tube measures the pressure head, the velocity head, and the elevation head (z). This means the Pitot tube measures the Energy Grade Line (EGL) while the piezometer measures the Hydraulic Grade Line (HGL).
#
# Considering the equation for HGL:
#
# $$
# HGL= \frac{p}{\gamma} + z
# $$
#
# And the equation for EGL:
#
# $$
# EGL= \frac{p}{\gamma} + \frac{V^2}{2g}+ z
# $$
# We know that the Energy Grade Line (EGL) is 0.15 m and the Hydraulic Grade Line (HGL) is 0.09 m. Assuming there are no friction losses, both lines will be horizontal.
# ```

# %% [markdown]
# **Solution**

# %%
from PIL import Image
img = Image.open(r"figures/14.6.png")
img

# %% [markdown]
# ---
# #### Question 7 (**)

# %% [markdown]
# Water flows through the pipe shown in the figure with a velocity of 3 m/s (in the 200 mm section of the pipe).
#
# a. If the pressure in the 200 mm section of the pipe is 350 kPa, calculate the pressures in the other two sections of pipe.
#
# b. Draw the EGL and HGL for this problem.

# %%
from PIL import Image
img = Image.open(r"figures/14.7.png")
img

# %% [markdown]
# ```{dropdown} Answer
# $
# a) \;319.78 \; kPa\;,\;178.72\; kPa
# $
# ```

# %% [markdown]
# **Question 7 (a)**

# %% [markdown]
# ```{dropdown} Hint
# The pressure in the 120 mm section can be calculated using the Bernoulli equation between the 200 mm and the 120 mm sections:
#
# $$
# \frac{p_{1}}{\gamma}+\frac{V_1^2}{2g} +z_1=\frac{p_2}{\gamma}+\frac{V_2^2}{2g} +z_2
# $$
#
#
# The pressure in the 80 mm section can be calculated using the Bernoulli equation between the 120 mm and the 80 mm sections:
#
# $$
# \frac{p_{2}}{\gamma}+\frac{V_2^2}{2g} +z_2=\frac{p_3}{\gamma}+\frac{V_3^2}{2g} +z_3
# $$
#
#
# As the pipe is horizontal, $z_1=z_2$, and $V_2$ and $V_2$ can be calculated considering conservation of mass:
#
# $$V= \frac{Q}{A}$$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# V_1= 3 #m/s
# D_1= 200/1000 #m
# D_2= 120/1000 #m
# D_3= 80/1000 #m
# p_1=350*1000 #Pa
#
# Q= V_1*(pi*D_1**2/4) #m3/s
# V_2= Q/(pi*D_2**2/4) #m/s
# p_2= (p_1/(rho_water*g)+V_1**2/(2*g)-V_2**2/(2*g))*rho_water*g #Pa
# p_2_= p_2/1000 #kPa
# V_3= Q/(pi*D_3**2/4) #m/s
# p_3= (p_2/(rho_water*g)+V_2**2/(2*g)-V_3**2/(2*g))*rho_water*g #Pa
# p_3_= p_3/1000 #kPa
# Out:
# \[
# \begin{aligned}
# V_{1} &= 3 \; \;\textrm{(m/s)}
# \\[10pt]
# D_{1} &= \frac{ 200 }{ 1000 } &= 0.20 \; \;\textrm{(m)}
# \\[10pt]
# D_{2} &= \frac{ 120 }{ 1000 } &= 0.12 \; \;\textrm{(m)}
# \\[10pt]
# D_{3} &= \frac{ 80 }{ 1000 } &= 0.08 \; \;\textrm{(m)}
# \\[10pt]
# p_{1} &= 350000 \; \;\textrm{(Pa)}
# \\[10pt]
# Q &= V_{1} \cdot \left( \pi \cdot \frac{ \left( D_{1} \right) ^{ 2 } }{ 4 } \right) \\&= 3 \cdot \left( 3.14 \cdot \frac{ \left( 0.20 \right) ^{ 2 } }{ 4 } \right) \\&= 0.09 \; \;\textrm{(m3/s)}\\[10pt]
# \\[10pt]
# V_{2} &= \frac{ Q }{ \pi \cdot \frac{ \left( D_{2} \right) ^{ 2 } }{ 4 } } \\&= \frac{ 0.09 }{ 3.14 \cdot \frac{ \left( 0.12 \right) ^{ 2 } }{ 4 } } \\&= 8.33 \; \;\textrm{(m/s)}\\[10pt]
# \\[10pt]
# p_{2} &= \left( \frac{ p_{1} }{ \rho_{water} \cdot g } + \frac{ \left( V_{1} \right) ^{ 2 } }{ 2 \cdot g } - \frac{ \left( V_{2} \right) ^{ 2 } }{ 2 \cdot g } \right) \cdot \rho_{water} \cdot g \\&= \left( \frac{ 350000 }{ 1000 \cdot 9.81 } + \frac{ \left( 3 \right) ^{ 2 } }{ 2 \cdot 9.81 } - \frac{ \left( 8.33 \right) ^{ 2 } }{ 2 \cdot 9.81 } \right) \cdot 1000 \cdot 9.81 \\&= 319777.78 \; \;\textrm{(Pa)}\\[10pt]
# \\[10pt]
# p_{2_{}} &= \frac{ p_{2} }{ 1000 } \\&= \frac{ 319777.78 }{ 1000 } \\&= 319.78 \; \;\textrm{(kPa)}\\[10pt]
# \\[10pt]
# V_{3} &= \frac{ Q }{ \pi \cdot \frac{ \left( D_{3} \right) ^{ 2 } }{ 4 } } \\&= \frac{ 0.09 }{ 3.14 \cdot \frac{ \left( 0.08 \right) ^{ 2 } }{ 4 } } \\&= 18.75 \; \;\textrm{(m/s)}\\[10pt]
# \\[10pt]
# p_{3} &= \left( \frac{ p_{2} }{ \rho_{water} \cdot g } + \frac{ \left( V_{2} \right) ^{ 2 } }{ 2 \cdot g } - \frac{ \left( V_{3} \right) ^{ 2 } }{ 2 \cdot g } \right) \cdot \rho_{water} \cdot g \\&= \left( \frac{ 319777.78 }{ 1000 \cdot 9.81 } + \frac{ \left( 8.33 \right) ^{ 2 } }{ 2 \cdot 9.81 } - \frac{ \left( 18.75 \right) ^{ 2 } }{ 2 \cdot 9.81 } \right) \cdot 1000 \cdot 9.81 \\&= 178718.75 \; \;\textrm{(Pa)}\\[10pt]
# \\[10pt]
# p_{3_{}} &= \frac{ p_{3} }{ 1000 } \\&= \frac{ 178718.75 }{ 1000 } \\&= 178.72 \; \;\textrm{(kPa)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# **Question 7 (b)**

# %% [markdown]
# ```{dropdown} Hint
# The EGL (Energy Grade Line) is the total energy at each point along the flow. This includes the kinetic energy and the potential energy. Considering there is no friction loss in this exercise, the EGL should be a straight line.
#
# $$
# EGL= \frac{p}{\gamma}+\frac{V^2}{2g} +z
# $$
#
# The HGL (Hydraulic Grade Line) represents the sum of the pressure head and the elevation head.This line will drop with each reduction in diameter due to the increase in velocity.
#
# $$
# HGL= \frac{p}{\gamma}+z
# $$
# ```

# %% [markdown]
# **Solution**

# %%
from PIL import Image
img = Image.open(r"figures/14.7S.png")
img

# %% [markdown]
# ## Problems for Lecture 16: Flow Measurement

# %% [markdown]
# ---
# #### Question 1 (*)

# %% [markdown]
# Using the measurements from a Venturi Meter, you have calculated that the discharge through a pipe system should be 24 litres per second. To check this theoretical discharge, you have captured a volume of 4.0 m<sup>3</sup> from the pipe system. It  took 3 minutes to collect this volume. Calculate the discharge coefficient.

# %% [markdown]
# ```{dropdown} Answer
# $
# 0.926
# $
# ```

# %% [markdown]
# ```{dropdown} Hint
# To calculate the discharge coefficient (𝐶𝑑), we need to compare the actual discharge with the theoretical discharge obtained from the Venturi meter.
# ```

# %% [markdown]
# **Solution**

# %% [markdown]
# ```{dropdown} Show code cell outputs
#
# $$
# C_d= \frac{Q_a}{Q_t}
# $$
#
# The actual discharge flow can be calcualted as
#
# $$
# Q= \frac{Vol}{t}
# $$
#
# ```

# %%
# %%render long 3
# Q_t= 24 #L/s
# V= 4 #m3
# t= 3#min
# Q_a= (V*1000)/(t*60) #L/s
# C_d= Q_a/Q_t
# Out:
# \[
# \begin{aligned}
# Q_{a} &= \frac{ V \cdot 1000 }{ t \cdot 60 } \\&= \frac{ 4 \cdot 1000 }{ 3 \cdot 60 } \\&= 22.222 \; \;\textrm{(L/s)}\\[10pt]
# \\[10pt]
# C_{d} &= \frac{ Q_{a} }{ Q_{t} } \\&= \frac{ 22.222 }{ 24 } \\&= 0.926  \\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 2 (*)

# %% [markdown]
# Using the measurements from an Orifice Meter, you have calculated that the discharge through a pipe system should be 3.0 litres per second. You use a calibration tank with a surface area of 0.4 m<sup>2</sup> to check this discharge. If the water level in the calibration tank rises at a rate of 4 mm/s, calculate the discharge coefficient.

# %% [markdown]
# ```{dropdown} Answer
# $
# 0.533
# $
# ```

# %% [markdown]
# ```{dropdown} Hint
# To calculate the discharge coefficient (𝐶𝑑), we need to compare the actual discharge with the theoretical discharge obtained from the Venturi meter.
# ```

# %% [markdown]
# **Solution**

# %% [markdown]
# ```{dropdown} Show code cell outputs
#
# $$
# C_d= \frac{Q_a}{Q_t}
# $$
#
# The actual discharge flow can be calcualted as
#
# $$
# Q_a= AV
# $$
#
# ```

# %%
# %%render long 3
# Q_t= 3/1000 #m3/s
# A= 0.4 #m2
# V= 4/1000 #m/s
# Q_a= A*V #m3/s
# C_d= Q_a/Q_t
# Out:
# \[
# \begin{aligned}
# Q_{a} &= A \cdot V \\&= 0.400 \cdot 0.004 \\&= 0.002 \; \;\textrm{(m3/s)}\\[10pt]
# \\[10pt]
# C_{d} &= \frac{ Q_{a} }{ Q_{t} } \\&= \frac{ 0.002 }{ 0.003 } \\&= 0.533  \\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 3

# %% [markdown]
# Using the measurements from a Venturi Meter, you have calculated that the discharge through a pipe system should be 13 litres per second. Downstream of the Venturi Meter, you have installed a piezometer and a pitot tube. If the difference in water levels between the piezometer and the pitot tube is 70 mm, and the pipe diameter is 0.1 m, calculate the discharge coefficient.

# %% [markdown]
# ```{dropdown} Answer
# $
# 0.708
# $
# ```

# %% [markdown]
# ```{dropdown} Hint
#
# The water level in the piezometer is the GHL and the water level in the pitot tube is the EGL. The difference between those two water levels (EGL and HGL) is the velocity head.
# ```

# %% [markdown]
# **Solution**

# %% [markdown]
# ```{dropdown} Show code cell outputs
# Calculate the Velocity from the Pitot Tube Measurement:
#
# $$
# V= \sqrt {2g\Delta h}
# $$
#
# An then the actual discharge can be calculated:
#
# $$
# Q_a= VA
# $$
#
# Additionally, the following change of units must be performed:
#
# $$
# h= mm to m \\
# Q_a= L/s to m^3/s
# $$
# ```

# %%
# %%render long 3
# Q_t= 13 #L/s
# h= 70 #mm
# D= 0.1#m
# V= sqrt(2*g*(h/1000)) #m/s
# Q_a= (V)*pi*D**2/4 #m3/s
# Q_a_m= Q_a*1000 #L/s
# C_d= Q_a_m/Q_t
# Out:
# \[
# \begin{aligned}
# V &= \sqrt { 2 \cdot g \cdot \left( \frac{ h }{ 1000 } \right) } \\&= \sqrt { 2 \cdot 9.810 \cdot \left( \frac{ 70 }{ 1000 } \right) } \\&= 1.172 \; \;\textrm{(m/s)}\\[10pt]
# \\[10pt]
# Q_{a} &= V \cdot \pi \cdot \frac{ \left( D \right) ^{ 2 } }{ 4 } \\&= 1.172 \cdot 3.142 \cdot \frac{ \left( 0.100 \right) ^{ 2 } }{ 4 } \\&= 0.009 \; \;\textrm{(m3/s)}\\[10pt]
# \\[10pt]
# Q_{a_{m}} &= Q_{a} \cdot 1000 \\&= 0.009 \cdot 1000 \\&= 9.204 \; \;\textrm{(L/s)}\\[10pt]
# \\[10pt]
# C_{d} &= \frac{ Q_{a_{m}} }{ Q_{t} } \\&= \frac{ 9.204 }{ 13 } \\&= 0.708  \\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 4 (**)[R]

# %% [markdown]
# Water flows in an open channel of 2.0 m width. At some point in the channel, the water flows over a smooth submerged object that is 1.0 m high. If the water depth upstream of the object is 2.5 m and the depth downstream of the object is 0.5 m, calculate the discharge in the channel.

# %% [markdown]
# ```{dropdown} Answer
# $
# 6.4 m^3/s
# $
# ```

# %% [markdown]
# ```{dropdown} Hint
# Use a combination of the Bernoulli equation and the continuity equation. The cross-sectional area is given by the water depth multiplied by the channel width
# ```

# %% [markdown]
# **Solution**

# %% [markdown]
# ```{dropdown} Show code cell outputs
#
# Conservation of energy:
#
# $$E_1=E_2$$
# $$y_1+ \frac{V_1^2}{2g}=y_2+ \frac{V_2^2}{2g}$$
#
# Conservation of mass:
#
# $$Q_1=Q_2$$
# $$V_1 \cdot A_1=V_2 \cdot A_2$$
# $$V_1 \cdot b \cdot y_1=V_2 \cdot b \cdot y_2$$
#
# $$ V= \frac {Q}{A}$$
#
# Reeplace the velocity equation in the Bernoulli eqution:
#
# $$y_1+ \frac{\frac {Q^2}{A_1^2}}{2g}=y_2+ \frac{\frac {Q^2}{A_2^2}}{2g}$$
#
# The area is:
#
# $$
# A= b \cdot y
# $$
#
# Substituting the area and rearranging the equation
#
# $$
# Q= b \cdot \sqrt {2 \cdot g \cdot (y_1 -y_2)} \cdot (\frac {y_1 \cdot y_2}{\sqrt {y_1 ^2 - y_2^2}})
# $$
# ```

# %%
# %%render long
#
# b= 2 #m
# z= 1#m
# y_1= 2.5#m
# y_2= 0.5 #m
#
# A_1= b*y_1 #m2
# A_2= b*y_2#m2
#
# Q_t= b*sqrt(2*g*(y_1-y_2))*((y_1*y_2)/(sqrt(y_1**2-y_2**2)))#m3/s
# Out:
# \[
# \begin{aligned}
# b &= 2 \; \;\textrm{(m)}
# \\[10pt]
# z &= 1 \; \;\textrm{(m)}
# \\[10pt]
# y_{1} &= 2.500 \; \;\textrm{(m)}
# \\[10pt]
# y_{2} &= 0.500 \; \;\textrm{(m)}
# \\[10pt]
# A_{1} &= b \cdot y_{1} \\&= 2 \cdot 2.500 \\&= 5.000 \; \;\textrm{(m2)}\\[10pt]
# \\[10pt]
# A_{2} &= b \cdot y_{2} \\&= 2 \cdot 0.500 \\&= 1.000 \; \;\textrm{(m2)}\\[10pt]
# \\[10pt]
# Q_{t} &= b \cdot \sqrt { 2 \cdot g \cdot \left( y_{1} - y_{2} \right) } \cdot \left( \frac{ y_{1} \cdot y_{2} }{ \sqrt { \left( y_{1} \right) ^{ 2 } - \left( y_{2} \right) ^{ 2 } } } \right) \\&= 2 \cdot \sqrt { 2 \cdot 9.810 \cdot \left( 2.500 - 0.500 \right) } \cdot \left( \frac{ 2.500 \cdot 0.500 }{ \sqrt { \left( 2.500 \right) ^{ 2 } - \left( 0.500 \right) ^{ 2 } } } \right) \\&= 6.393 \; \;\textrm{(m3/s)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 5 (**)

# %% [markdown]
# Water flows in an open channel of 1.2 m width. At some point in the channel, the water flows over a smooth submerged object. If the water depth upstream of the object is 1.2 m and the depth downstream of the object is 0.4 m, and the actual discharge in the channel is 1.6 m<sup>3</sup>/s, calculate the discharge coefficient

# %% [markdown]
# ```{dropdown} Answer
# $
# 0.79
# $
# ```

# %% [markdown]
# ```{dropdown} Hint
# Use a combination of the Bernoulli equation and the continuity equation. The cross-sectional area is given by the water depth multiplied by the channel width
# ```

# %% [markdown]
# **Solution**

# %% [markdown]
# ```{dropdown} Show code cell outputs
#
# $$
# Q= b \cdot \sqrt {2 \cdot g \cdot (y_1 -y_2)} \cdot (\frac {y_1 \cdot y_2}{\sqrt {y_1 ^2 - y_2^2}})
# $$
# ```

# %%
# %%render long 3
# b= 1.2 #m
# y_1= 1.2#m
# y_2= 0.4 #m
# Q_a= 1.6 #m3/s
# Q_t= b*sqrt(2*g*(y_1-y_2))*((y_1*y_2)/(sqrt(y_1**2-y_2**2)))#m3/s
# C_d=Q_a/Q_t
# Out:
# \[
# \begin{aligned}
# Q_{t} &= b \cdot \sqrt { 2 \cdot g \cdot \left( y_{1} - y_{2} \right) } \cdot \left( \frac{ y_{1} \cdot y_{2} }{ \sqrt { \left( y_{1} \right) ^{ 2 } - \left( y_{2} \right) ^{ 2 } } } \right) \\&= 1.200 \cdot \sqrt { 2 \cdot 9.810 \cdot \left( 1.200 - 0.400 \right) } \cdot \left( \frac{ 1.200 \cdot 0.400 }{ \sqrt { \left( 1.200 \right) ^{ 2 } - \left( 0.400 \right) ^{ 2 } } } \right) \\&= 2.017 \; \;\textrm{(m3/s)}\\[10pt]
# \\[10pt]
# C_{d} &= 0.793 \;
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 6 (*)[R]

# %% [markdown]
# A Venturi Meter has a pipe diameter of 120 mm and a throat diameter of 50 mm. When water is flowing through the Venturi Meter, the pressure in the pipe and the throat is recorded using piezometers. If the difference in water height in the two piezometers is 50 mm, calculate the discharge in the Venturi Meter.

# %% [markdown]
# ```{dropdown} Answer
# $
# 1.975 L/s
# $
# ```

# %% [markdown]
# ```{dropdown} Hint
# Use the equation of the theoretical discharge.
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 3
# D_1= 120/1000 #m
# D_2= 50/1000 #m
# h_p=50/1000 #m
# A_1= pi*(D_1)**2/4 #m2
# A_2= pi*(D_2)**2/4#m2
#
# Q= (sqrt(2*g*h_p)*((A_1*A_2)/(sqrt(A_1**2-A_2**2))))*1000 #L/s
# Out:
# \[
# \begin{aligned}
# A_{1} &= \pi \cdot \frac{ \left( D_{1} \right) ^{ 2 } }{ 4 } \\&= 3.142 \cdot \frac{ \left( 0.120 \right) ^{ 2 } }{ 4 } \\&= 0.011 \; \;\textrm{(m2)}\\[10pt]
# \\[10pt]
# A_{2} &= \pi \cdot \frac{ \left( D_{2} \right) ^{ 2 } }{ 4 } \\&= 3.142 \cdot \frac{ \left( 0.050 \right) ^{ 2 } }{ 4 } \\&= 0.002 \; \;\textrm{(m2)}\\[10pt]
# \\[10pt]
# Q &= \left( \sqrt { 2 \cdot g \cdot h_{p} } \cdot \left( \frac{ A_{1} \cdot A_{2} }{ \sqrt { \left( A_{1} \right) ^{ 2 } - \left( A_{2} \right) ^{ 2 } } } \right) \right) \cdot 1000 \\&= \left( \sqrt { 2 \cdot 9.810 \cdot 0.050 } \cdot \left( \frac{ 0.011 \cdot 0.002 }{ \sqrt { \left( 0.011 \right) ^{ 2 } - \left( 0.002 \right) ^{ 2 } } } \right) \right) \cdot 1000 \\&= 1.975 \; \;\textrm{(L/s)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 7 (**)[R]

# %% [markdown]
# A Venturi Meter has a pipe diameter of 120 mm and a throat diameter of 50 mm (i.e. the same as in Question 6). Now, however, the piezometers are replaced with a differential manometer filled with mercury (S.G. = 13.5). If the differential manometer registers a height difference of 20 mm, calculate the discharge passing
# through the Venturi Meter.

# %% [markdown]
# ```{dropdown} Answer
# $
# 0.004 m^3/s
# $
# ```

# %% [markdown]
# ```{dropdown} Hint
# The difference between this and the last exercise is that the last one is with piezometers and this one with differential manometer. For that reason, you can not use $\Delta h$ because that is the height of the mercury. The first step is to change $\Delta h$ to $\Delta p$.
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 3
# D_1= 120 #mm
# D_2= 50 #mm
# SG= 13.5
# Delta_h= 20 #mm
# A_1= pi*(D_1/1000)**2/4 #m2
# A_2= pi*(D_2/1000)**2/4#m2
# rho_Hg= SG*rho_water #kg/m3
# Delta_p= (rho_Hg-rho_water)*g*(Delta_h/1000) #Pa
# Q= sqrt(2*(Delta_p/rho_water))*((A_1*A_2)/(sqrt(A_1**2-A_2**2))) #m3/s
# Out:
# \[
# \begin{aligned}
# A_{1} &= \pi \cdot \frac{ \left( \frac{ D_{1} }{ 1000 } \right) ^{ 2 } }{ 4 } \\&= 3.142 \cdot \frac{ \left( \frac{ 120 }{ 1000 } \right) ^{ 2 } }{ 4 } \\&= 0.011 \; \;\textrm{(m2)}\\[10pt]
# \\[10pt]
# A_{2} &= \pi \cdot \frac{ \left( \frac{ D_{2} }{ 1000 } \right) ^{ 2 } }{ 4 } \\&= 3.142 \cdot \frac{ \left( \frac{ 50 }{ 1000 } \right) ^{ 2 } }{ 4 } \\&= 0.002 \; \;\textrm{(m2)}\\[10pt]
# \\[10pt]
# \rho_{Hg} &= \mathrm{SG} \cdot \rho_{water} \\&= 13.500 \cdot 1000 \\&= 13500.000 \; \;\textrm{(kg/m3)}\\[10pt]
# \\[10pt]
# \Delta_{p} &= \left( \rho_{Hg} - \rho_{water} \right) \cdot g \cdot \left( \frac{ \Delta_{h} }{ 1000 } \right) \\&= \left( 13500.000 - 1000 \right) \cdot 9.810 \cdot \left( \frac{ 20 }{ 1000 } \right) \\&= 2452.500 \; \;\textrm{(Pa)}\\[10pt]
# \\[10pt]
# Q &= \sqrt { 2 \cdot \left( \frac{ \Delta_{p} }{ \rho_{water} } \right) } \cdot \left( \frac{ A_{1} \cdot A_{2} }{ \sqrt { \left( A_{1} \right) ^{ 2 } - \left( A_{2} \right) ^{ 2 } } } \right) \\&= \sqrt { 2 \cdot \left( \frac{ 2452.500 }{ 1000 } \right) } \cdot \left( \frac{ 0.011 \cdot 0.002 }{ \sqrt { \left( 0.011 \right) ^{ 2 } - \left( 0.002 \right) ^{ 2 } } } \right) \\&= 0.004 \; \;\textrm{(m3/s)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 8 (**)[R]

# %% [markdown]
# A Venturi Meter has a pipe diameter of 180 mm and a throat diameter of 60
# mm. When water is flowing through the Venturi Meter, the pressure in the pipe and
# the throat is recorded using piezometers. If the difference in water height in the two
# piezometers is 70 mm, and the discharge coefficient is 0.95, calculate the actual
# discharge in the Venturi Meter.

# %% [markdown]
# ```{dropdown} Answer
# $
# 3.17 L/s
# $
# ```

# %% [markdown]
# ```{dropdown} Hint
# Calculate the theoretical discharge and use the discharge coefficient to calculate the actual discharge.
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# D_1= 180/1000 #m
# D_2= 60/1000 #m
# h= 70/1000 #m
# C_d= 0.95
# A_1= pi*(D_1)**2/4 #m2
# A_2= pi*(D_2)**2/4#m2
# Q_t= (sqrt(2*g*h)*((A_1*A_2)/(sqrt(A_1**2-A_2**2))))*1000 #L/s
# Q_a= C_d*Q_t #L/s
# Out:
# \[
# \begin{aligned}
# A_{1} &= \pi \cdot \frac{ \left( D_{1} \right) ^{ 2 } }{ 4 } \\&= 3.14 \cdot \frac{ \left( 0.18 \right) ^{ 2 } }{ 4 } \\&= 0.03 \; \;\textrm{(m2)}\\[10pt]
# \\[10pt]
# A_{2} &= \pi \cdot \frac{ \left( D_{2} \right) ^{ 2 } }{ 4 } \\&= 3.14 \cdot \frac{ \left( 0.06 \right) ^{ 2 } }{ 4 } \\&= 0.00 \; \;\textrm{(m2)}\\[10pt]
# \\[10pt]
# Q_{t} &= \left( \sqrt { 2 \cdot g \cdot h } \cdot \left( \frac{ A_{1} \cdot A_{2} }{ \sqrt { \left( A_{1} \right) ^{ 2 } - \left( A_{2} \right) ^{ 2 } } } \right) \right) \cdot 1000 \\&= \left( \sqrt { 2 \cdot 9.81 \cdot 0.07 } \cdot \left( \frac{ 0.03 \cdot 0.00 }{ \sqrt { \left( 0.03 \right) ^{ 2 } - \left( 0.00 \right) ^{ 2 } } } \right) \right) \cdot 1000 \\&= 3.33 \; \;\textrm{(L/s)}\\[10pt]
# \\[10pt]
# Q_{a} &= C_{d} \cdot Q_{t} \\&= 0.95 \cdot 3.33 \\&= 3.17 \; \;\textrm{(L/s)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 9 (**)[R]

# %% [markdown]
# An orifice plate (internal diameter of 30 mm) is placed in a pipe with a diameter of 80 mm. With water flowing through the pipe, the pressure difference recorded by two piezometers attached to the orifice plate is 300 mm.
#
# a. If the coefficient of discharge of the orifice plate is equal to 0.6, calculate the actual discharge flowing through the pipe.
#
# b. With the aid of a sketch, show the main source of energy loss associated with water flow through an orifice plate. Include an illustration of the location of the two piezometers, and explain why we can use these measurements to determine the discharge.

# %% [markdown]
# ```{dropdown} Answer
# $
# 0.001 m^3/s
# $
# ```

# %% [markdown]
# **Question 9 (a)**

# %% [markdown]
# ```{dropdown} Hint
# Calculate the theoretical discharge with the Equation for flow rate through an orifice. Then use the discharge coefficient to calculate the actual discharge.
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 4
# D_o= 30 #mm
# D_p= 80 #mm
# Delta_h= 300 #mm
# C_d= 0.6
# A_1= pi*(D_p/1000)**2/4 #m2
# A_2= pi*(D_o/1000)**2/4#m2
# Q_t= sqrt(2*g*Delta_h/1000)*((A_1*A_2)/(sqrt(A_1**2-A_2**2)))#m3/s
# Q_a= C_d*Q_t #m3/s
# Out:
# \[
# \begin{aligned}
# A_{1} &= \pi \cdot \frac{ \left( \frac{ D_{p} }{ 1000 } \right) ^{ 2 } }{ 4 } \\&= 3.1416 \cdot \frac{ \left( \frac{ 80 }{ 1000 } \right) ^{ 2 } }{ 4 } \\&= 0.0050 \; \;\textrm{(m2)}\\[10pt]
# \\[10pt]
# A_{2} &= \pi \cdot \frac{ \left( \frac{ D_{o} }{ 1000 } \right) ^{ 2 } }{ 4 } \\&= 3.1416 \cdot \frac{ \left( \frac{ 30 }{ 1000 } \right) ^{ 2 } }{ 4 } \\&= 0.0007 \; \;\textrm{(m2)}\\[10pt]
# \\[10pt]
# Q_{t} &= \sqrt { 2 \cdot g \cdot \frac{ \Delta_{h} }{ 1000 } } \cdot \left( \frac{ A_{1} \cdot A_{2} }{ \sqrt { \left( A_{1} \right) ^{ 2 } - \left( A_{2} \right) ^{ 2 } } } \right) \\&= \sqrt { 2 \cdot 9.8100 \cdot \frac{ 300 }{ 1000 } } \cdot \left( \frac{ 0.0050 \cdot 0.0007 }{ \sqrt { \left( 0.0050 \right) ^{ 2 } - \left( 0.0007 \right) ^{ 2 } } } \right) \\&= 0.0017 \; \;\textrm{(m3/s)}\\[10pt]
# \\[10pt]
# Q_{a} &= C_{d} \cdot Q_{t} \\&= 0.6000 \cdot 0.0017 \\&= 0.0010 \; \;\textrm{(m3/s)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# **Question 9 (b)**

# %% [markdown]
# ```{dropdown} Hint
# The main source of energy loss when water flows through an orifice plate is due to the sudden contraction and expansion of the flow as it passes through the orifice. This energy loss is associated with flow separation at the edges of the orifice, leading to turbulent eddies and vortex formation.
# ```

# %% [markdown]
# **Solution**

# %% [markdown]
# ```{dropdown} Show code cell outputs
# The main source of the energy loss is the flow separation from the sharp edge of the Orifice Plate. The piezometer locations are shown on the sketch below. Experimental  evidence shows that the pressure in the separation region is the same as the pressure at point 2 (the constriction in the orifice plate itself), which is why we can use these in a similar manner to those in the pipe and throat of a Venturi Meter.
# ```

# %%
from PIL import Image
img = Image.open(r"figures/15.9S.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=553x369>

# %% [markdown]
# ---
# #### Question 10 (***)

# %% [markdown]
# A Venturi Meter has a pipe diameter of 120 mm and a throat diameter of 50 mm. When water is flowing through the Venturi Meter, the pressure in the pipe and the throat is recorded using piezometers. The difference in water height in the two piezometers is 80 mm. Downstream of the Venturi Meter, water passes through a nozzle and exits as a free jet to the atmosphere.
#
# a. If the jet velocity is 3 m/s and the jet diameter is 0.02 m, calculate the discharge coefficient.
#
# b. Calculate the pressure within the pipe.

# %% [markdown]
# ```{dropdown} Answer
# a) $0.37$
#
# b) $4475.61$ Pa
# ```

# %% [markdown]
# **Question 10 (a)**

# %% [markdown]
# ```{dropdown} Hint
# The discharge coefficient is the ratio of actual discharge to theoretical discharge. The former can be calculated using the conservation of mass, while the latter can be determined using the equation for flow rate through an orifice.
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 4
# D_1= 120/1000 #m
# D_2= 50/1000 #m
# Delta_h= 80/1000 #m
# V_jet= 3 #m/s
# D_jet= 0.02 #m
# A_1= pi*(D_1)**2/4 #m2
# A_2= pi*(D_2)**2/4#m2
# Q_t= sqrt(2*g*Delta_h)*((A_1*A_2)/(sqrt(A_1**2-A_2**2)))#m3/s
# A_jet= pi*(D_jet)**2/4#m2
# Q_a= V_jet*A_jet #m3/s
# C_d= Q_a/Q_t
# Out:
# \[
# \begin{aligned}
# A_{1} &= \pi \cdot \frac{ \left( D_{1} \right) ^{ 2 } }{ 4 } \\&= 3.1416 \cdot \frac{ \left( 0.1200 \right) ^{ 2 } }{ 4 } \\&= 0.0113 \; \;\textrm{(m2)}\\[10pt]
# \\[10pt]
# A_{2} &= \pi \cdot \frac{ \left( D_{2} \right) ^{ 2 } }{ 4 } \\&= 3.1416 \cdot \frac{ \left( 0.0500 \right) ^{ 2 } }{ 4 } \\&= 0.0020 \; \;\textrm{(m2)}\\[10pt]
# \\[10pt]
# Q_{t} &= \sqrt { 2 \cdot g \cdot \Delta_{h} } \cdot \left( \frac{ A_{1} \cdot A_{2} }{ \sqrt { \left( A_{1} \right) ^{ 2 } - \left( A_{2} \right) ^{ 2 } } } \right) \\&= \sqrt { 2 \cdot 9.8100 \cdot 0.0800 } \cdot \left( \frac{ 0.0113 \cdot 0.0020 }{ \sqrt { \left( 0.0113 \right) ^{ 2 } - \left( 0.0020 \right) ^{ 2 } } } \right) \\&= 0.0025 \; \;\textrm{(m3/s)}\\[10pt]
# \\[10pt]
# A_{jet} &= \pi \cdot \frac{ \left( D_{jet} \right) ^{ 2 } }{ 4 } \\&= 3.1416 \cdot \frac{ \left( 0.0200 \right) ^{ 2 } }{ 4 } \\&= 0.0003 \; \;\textrm{(m2)}\\[10pt]
# \\[10pt]
# Q_{a} &= V_{jet} \cdot A_{jet} \\&= 3 \cdot 0.0003 \\&= 0.0009 \; \;\textrm{(m3/s)}\\[10pt]
# \\[10pt]
# C_{d} &= \frac{ Q_{a} }{ Q_{t} } \\&= \frac{ 0.0009 }{ 0.0025 } \\&= 0.3773  \\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# **Question 10 (b)**

# %% [markdown]
# ```{dropdown} Hint
# The main source of the energy loss is the flow separation from the sharp edge of the Orifice Plate. Experimental  evidence shows that the pressure in the separation region is the same as the pressure at the constriction in the orifice plate itself, which is why we can use these in a similar manner to those in the pipe and throat of a Venturi Meter.
# ```

# %% [markdown]
# **Solution**

# %% [markdown]
# ```{dropdown} Show code cell outputs
# From the Bernoulli equation we have:
#
# $$\frac{p_2}{\rho g}+\frac{V_2^2}{2 g}=\frac{p_3}{\rho g}+\frac{V_3^2}{2 g}$$
#
# Assuming $p_3=0$ because the pressure is atmosferic, and calculating $V_2$ as $V_2=Q_t/A_2$, we can solve $p_2$.
#
# Finally, the pressure in the pipe can be calculated as $p_1=p_2+\Delta p$, where $\Delta p=\rho g \Delta h$
#
# ```

# %%
# %%render long 3
# V_2= Q_t/(pi*D_2**2/4) #m/s
# p_2= (V_jet**2/(2*g)-V_2**2/(2*g))*rho_water*g #Pa
# Delta_p= rho_water*g*Delta_h #Pa
# p_1= p_2+Delta_p #Pa
# Out:
# \[
# \begin{aligned}
# V_{2} &= \frac{ Q_{t} }{ \pi \cdot \frac{ \left( D_{2} \right) ^{ 2 } }{ 4 } } \\&= \frac{ 0.002 }{ 3.142 \cdot \frac{ \left( 0.050 \right) ^{ 2 } }{ 4 } } \\&= 1.272 \; \;\textrm{(m/s)}\\[10pt]
# \\[10pt]
# p_{2} &= \left( \frac{ \left( V_{jet} \right) ^{ 2 } }{ 2 \cdot g } - \frac{ \left( V_{2} \right) ^{ 2 } }{ 2 \cdot g } \right) \cdot \rho_{water} \cdot g \\&= \left( \frac{ \left( 3 \right) ^{ 2 } }{ 2 \cdot 9.810 } - \frac{ \left( 1.272 \right) ^{ 2 } }{ 2 \cdot 9.810 } \right) \cdot 1000 \cdot 9.810 \\&= 3690.810 \; \;\textrm{(Pa)}\\[10pt]
# \\[10pt]
# \Delta_{p} &= \rho_{water} \cdot g \cdot \Delta_{h} \\&= 1000 \cdot 9.810 \cdot 0.080 \\&= 784.800 \; \;\textrm{(Pa)}\\[10pt]
# \\[10pt]
# p_{1} &= p_{2} + \Delta_{p} \\&= 3690.810 + 784.800 \\&= 4475.610 \; \;\textrm{(Pa)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ## Problems for Lecture 18: Energy Equation

# %% [markdown]
# ### Energy equation

# %% [markdown]
# ---
# #### Question 1 (*)

# %% [markdown]
# Water flows up pipe AB (5 m long, 40 mm diameter) and along BC (3 m long, 30 mm diameter) at 1.75 L/s. If the measured pressure at A is 250 kPa, and the pipe friction loss between A and C is 1.45 m, find the pressure at C. Neglect local energy losses caused by the diameter change and bend at B.

# %%
from PIL import Image
img = Image.open(r"figures/85.png")
img

# %% [markdown]
# ```{dropdown} Answer
# $
# \;184.63 \; kPa
# $
# ```

# %% [markdown]
# ```{dropdown} Hint
# The pressure in point C can be calculated using the Bernoulli equation between points A and C
#
# $$
# \frac{p_A}{\gamma}+\frac{V_A^2}{2g}+z_A=\frac{p_C}{\gamma}+\frac{V_C^2}{2g}+z_C+h_f\\
# p_C=(\frac{p_A}{\gamma}+z_A+\frac{V_A^2}{2g}-z_C-\frac{V_C^2}{2g}-h_f)* \rho_{water}*g
# $$
#
# The units of the Bernoulli equation are:
#
# $$
# p= [Pa]\\
# \gamma= [N/m^3]\\
# V= [m/s]\\
# z= [m]
# $$
#
# and velocity is
#
# $$
# V= Q/A
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 3
# D_AB= 40 #mm
# L_AB= 5#m
# D_BC= 30 #mm
# L_BC= 3#m
# Q=1.75 #L/s
# p_A= 250 #kPa
# h_f_AC= 1.45 #m
#
# Q_m=Q/1000 #m3/s
# D_AB_m=D_AB/1000 #m
# D_BC_m=D_BC/1000 #m
# A_AB= pi*D_AB_m**2/4 #m2
# V_A= Q_m/A_AB #m/s
# A_BC= pi*D_BC_m**2/4 #m2
# V_C= Q_m/A_BC #m/s
#
# p_C= (p_A*1000/(rho_water*g)+V_A**2/(2*g)-h_f_AC-V_C**2/(2*g)-L_AB)*rho_water*g #Pa
# p_C_= p_C/1000 #kPa
# Out:
# \[
# \begin{aligned}
# D_{AB} &= 40 \; \;\textrm{(mm)}
# \\[10pt]
# L_{AB} &= 5 \; \;\textrm{(m)}
# \\[10pt]
# D_{BC} &= 30 \; \;\textrm{(mm)}
# \\[10pt]
# L_{BC} &= 3 \; \;\textrm{(m)}
# \\[10pt]
# Q &= 1.750 \; \;\textrm{(L/s)}
# \\[10pt]
# p_{A} &= 250 \; \;\textrm{(kPa)}
# \\[10pt]
# h_{f_{AC}} &= 1.450 \; \;\textrm{(m)}
# \\[10pt]
# Q_{m} &= 0.002 \; \;\textrm{(m3/s)}
# \\[10pt]
# D_{AB_{m}} &= 0.040 \; \;\textrm{(m)}
# \\[10pt]
# D_{BC_{m}} &= 0.030 \; \;\textrm{(m)}
# \\[10pt]
# A_{AB} &= \pi \cdot \frac{ \left( D_{AB_{m}} \right) ^{ 2 } }{ 4 } \\&= 3.142 \cdot \frac{ \left( 0.040 \right) ^{ 2 } }{ 4 } \\&= 0.001 \; \;\textrm{(m2)}\\[10pt]
# \\[10pt]
# V_{A} &= \frac{ Q_{m} }{ A_{AB} } \\&= \frac{ 0.002 }{ 0.001 } \\&= 1.393 \; \;\textrm{(m/s)}\\[10pt]
# \\[10pt]
# A_{BC} &= \pi \cdot \frac{ \left( D_{BC_{m}} \right) ^{ 2 } }{ 4 } \\&= 3.142 \cdot \frac{ \left( 0.030 \right) ^{ 2 } }{ 4 } \\&= 0.001 \; \;\textrm{(m2)}\\[10pt]
# \\[10pt]
# V_{C} &= \frac{ Q_{m} }{ A_{BC} } \\&= \frac{ 0.002 }{ 0.001 } \\&= 2.476 \; \;\textrm{(m/s)}\\[10pt]
# \\[10pt]
# p_{C} &= \left( p_{A} \cdot \frac{ 1000 }{ \rho_{water} \cdot g } + \frac{ \left( V_{A} \right) ^{ 2 } }{ 2 \cdot g } - h_{f_{AC}} - \frac{ \left( V_{C} \right) ^{ 2 } }{ 2 \cdot g } - L_{AB} \right) \cdot \rho_{water} \cdot g \\&= \left( 250 \cdot \frac{ 1000 }{ 1000 \cdot 9.810 } + \frac{ \left( 1.393 \right) ^{ 2 } }{ 2 \cdot 9.810 } - 1.450 - \frac{ \left( 2.476 \right) ^{ 2 } }{ 2 \cdot 9.810 } - 5 \right) \cdot 1000 \cdot 9.810 \\&= 184630.522 \; \;\textrm{(Pa)}\\[10pt]
# \\[10pt]
# p_{C_{}} &= \frac{ p_{C} }{ 1000 } \\&= \frac{ 184630.522 }{ 1000 } \\&= 184.631 \; \;\textrm{(kPa)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 2 (*)[R]

# %% [markdown]
# Water flows within a horizontal pipe of diameter 0.1 m at a velocity of 0.2 m/s. The centreline of the pipe is located at the horizontal datum. If the pressure in the pipe is 120 kPa, calculate the pressure and velocity head within the pipe. {12.232 m, 0.002 m}

# %% [markdown]
# ```{dropdown} Answer
# $
# \;12.232 \; m \;,\;0.002\; m
# $
# ```

# %% [markdown]
# ```{dropdown} Hint
# The pressure head can be calculated with the following equation:
#
# $$
# \frac{p}{\gamma}
# $$
#
# The velocity head can be calculated with the following equation:
#
# $$
# \frac{V^2}{2g}
# $$
#
# You can assume the density of water is 1000 kg/m<sup>3</sup>
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 3
# D= 0.1 #m
# V= 0.2 #m/s
# p= 120 #kPa
#
# pressure_m = (p*1000)/(rho_water*g) #m
# velocity_m = V**2/(2*g) #m
# Out:
# \[
# \begin{aligned}
# D &= 0.100 \; \;\textrm{(m)}
# \\[10pt]
# V &= 0.200 \; \;\textrm{(m/s)}
# \\[10pt]
# p &= 120 \; \;\textrm{(kPa)}
# \\[10pt]
# \mathrm{pressure}_{m} &= \frac{ p \cdot 1000 }{ \rho_{water} \cdot g } \\&= \frac{ 120 \cdot 1000 }{ 1000 \cdot 9.810 } \\&= 12.232 \; \;\textrm{(m)}\\[10pt]
# \\[10pt]
# \mathrm{velocity}_{m} &= \frac{ \left( V \right) ^{ 2 } }{ 2 \cdot g } \\&= \frac{ \left( 0.200 \right) ^{ 2 } }{ 2 \cdot 9.810 } \\&= 0.002 \; \;\textrm{(m)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 3 (**)[R]

# %% [markdown]
# For the pipe flow described in question 2, a section of the pipe was elevated by 6 m to avoid an obstruction. Calculate the change in pressure and velocity within the pipe, and justify your answer.

# %% [markdown]
# ```{dropdown} Answer
# $
#  \;61.14 \;kPa \;,\,
# $
# the velocity doesn't change
# ```

# %% [markdown]
# ```{dropdown} Hint
# From the Bernoulli equation we have:
#
# $$
# \frac{p_A}{\rho g}+\frac{V_{A}^2}{2g}+z_{A}=\frac{p_B}{\rho g}+\frac{V_{B}^2}{2g}+z_{B}\\
# $$
#
# Considering that $z_A=0$ and solving for $p_B$:
#
# $$
# p_B=(\frac{p_A}{\rho g}+\frac{V_{A}^2}{2g}-\frac{V_{B}^2}{2g}-z_{B})\rho g
# $$
# ```

# %% [markdown]
# **Solution**

# %% [markdown]
# ```{Dropdown} Show code cell outputs
# The velocity doesn’t change, as this would require a change in discharge and would violate
# the conservation of mass.
#
# The pressure will reduce due to the increase in elevation
# ```

# %%
# %%render long 2
# pressure_m=12.232 #m
# velocity_m=0.002 #m
# z_B=6 #m
#
# p_B= (pressure_m-z_B)*rho_water*g #Pa
# p_B_= p_B/1000 #kPa
# Out:
# \[
# \begin{aligned}
# \mathrm{pressure}_{m} &= 12.23 \; \;\textrm{(m)}
# \\[10pt]
# \mathrm{velocity}_{m} &= 0.00 \; \;\textrm{(m)}
# \\[10pt]
# z_{B} &= 6 \; \;\textrm{(m)}
# \\[10pt]
# p_{B} &= \left( \mathrm{pressure}_{m} - z_{B} \right) \cdot \rho_{water} \cdot g \\&= \left( 12.23 - 6 \right) \cdot 1000 \cdot 9.81 \\&= 61135.92 \; \;\textrm{(Pa)}\\[10pt]
# \\[10pt]
# p_{B_{}} &= \frac{ p_{B} }{ 1000 } \\&= \frac{ 61135.92 }{ 1000 } \\&= 61.14 \; \;\textrm{(kPa)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 4 (*)[R]

# %% [markdown]
# Water discharges from a nozzle as a free jet to the atmosphere.
#
# a. If the velocity of the jet is 3 m/s, calculate the velocity head within the jet.
#
# b.Explain why the pressure head within the jet can be neglected

# %% [markdown]
# ```{dropdown} Answer
# $
# a) \;0.46 \; m
# $
#
# b) Pressure is atmospheric within a free jet.
# ```

# %% [markdown]
# **Question 4 (a)**

# %% [markdown]
# ```{dropdown} Hint
# The velocity head can be calculated with the following equation:
#
# $$
# \frac{V^2}{2g}
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# V= 3#m/s
# velocity_m= V**2/(2*g) #m
# Out:
# \[
# \begin{aligned}
# V &= 3 \; \;\textrm{(m/s)}
# \\[10pt]
# \mathrm{velocity}_{m} &= \frac{ \left( V \right) ^{ 2 } }{ 2 \cdot g } \\&= \frac{ \left( 3 \right) ^{ 2 } }{ 2 \cdot 9.81 } \\&= 0.46 \; \;\textrm{(m)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# **Question 4 (b)**

# %% [markdown]
# **Solution**

# %% [markdown]
# ```{Dropdown} Show code cell outputs
# Pressure is atmospheric within a free jet.
# ```

# %% [markdown]
# ---
# #### Question 5 (*)

# %% [markdown]
# A pipe containing oil (density = 960 kg/m<sup>3</sup>) has a diameter of 0.1 m.
#
# a. If the discharge within the pipe is 0.06 m<sup>3</sup> /s, calculate the velocity head within the pipe.
#
# b. If the pressure head is 12 m, calculate the pressure within the pipe.

# %% [markdown]
# ```{dropdown} Answer
# $
# a) \;2.97 \; m
# $
#
# $
# b) \;11.3 \; kPa
# $
# ```

# %% [markdown]
# **Question 5 (a)**

# %% [markdown]
# ```{dropdown} Hint
# Consider the following equations:
#
# $$
# V=\frac{Q}{A}\\
# velocity_{head}=\frac{V^2}{2g}
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# D= 0.1 #m
# rho= 96 #kg/m3
# Q= 0.06 #m3/s
#
# V= Q/(pi*D**2/4) #m3/s
# velocity_head= V**2/(2*g) #m
# Out:
# \[
# \begin{aligned}
# D &= 0.10 \; \;\textrm{(m)}
# \\[10pt]
# \rho &= 96 \; \;\textrm{(kg/m3)}
# \\[10pt]
# Q &= 0.06 \; \;\textrm{(m3/s)}
# \\[10pt]
# V &= \frac{ Q }{ \pi \cdot \frac{ \left( D \right) ^{ 2 } }{ 4 } } \\&= \frac{ 0.06 }{ 3.14 \cdot \frac{ \left( 0.10 \right) ^{ 2 } }{ 4 } } \\&= 7.64 \; \;\textrm{(m3/s)}\\[10pt]
# \\[10pt]
# \mathrm{velocity}_{head} &= \frac{ \left( V \right) ^{ 2 } }{ 2 \cdot g } \\&= \frac{ \left( 7.64 \right) ^{ 2 } }{ 2 \cdot 9.81 } \\&= 2.97 \; \;\textrm{(m)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# **Question 5 (b)**

# %% [markdown]
# ```{dropdown} Hint
# The pressure can be solved from the following equation of the pressure head:
#
# $$\frac{p}{\rho g}$$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# pressure_head=12 #m
# p= pressure_head*rho*g #Pa
# p_= p/1000 #kPa
# Out:
# \[
# \begin{aligned}
# \mathrm{pressure}_{head} &= 12 \; \;\textrm{(m)}
# \\[10pt]
# p &= \mathrm{pressure}_{head} \cdot \rho \cdot g \\&= 12 \cdot 96 \cdot 9.81 \\&= 11301.12 \; \;\textrm{(Pa)}\\[10pt]
# \\[10pt]
# p_{} &= \frac{ p }{ 1000 } \\&= \frac{ 11301.12 }{ 1000 } \\&= 11.30 \; \;\textrm{(kPa)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 6 (**)

# %% [markdown]
# A tank has a circular base (diameter = 1.5 m) and is filled with water to a height of 0.8 m. A small drain pipe with a diameter of 20 mm is opened at the base of the  tank, which discharges water as a free jet to the atmosphere.
#
# a. Determine the discharge of water out of the tank.
#
# b. Some time later, the height of water in the tank is 0.3 m. Determine the new discharge of water out of the tank at this time.
#
# c. Both of the above calculations assume that the flow is steady out of the tank, i.e. that the rate at which the water height in the tank changes is very slow compared to the velocity out of the tank. Based on your answer to (a), comment on whether this assumption is reasonable

# %% [markdown]
# ```{dropdown} Answer
# $
# a) \;0.0012 \; m^3/s
# $
#
# $
# b) \;0.0008 \;  m^3/s
# $
# ```

# %% [markdown]
# **Question 6 (a)**

# %% [markdown]
# ```{dropdown} Hint
# The Bernoulli equation can be used between the water in the surface and the free jet.
#
# $$
# \frac{p_{atm}}{\gamma}+\frac{V_{1}^2}{2g}+z_{1}=\frac{p_{jet}}{\gamma}+\frac{V_{2}^2}{2g}+z_{2}
# $$
#
# Considering the jet is free to the atmosphere, the variables in point 2 will be:
#
# $$
# p_{jet}= 0 Pa \\
# z_2= 0 m
# $$
#
# Considering that point 1 is in contact with the atmosphere, we have the following:
#
# $p_{atm}$=0  Pa
#
# $V_1$= is near 0 m/s because the tank is large
#
#
# Using this values you have the following equation:
#
# $$
# z_{1}=\frac{V_{2}^2}{2g}
# $$
#
# This equation is the Torricelli's law:
#
# $$
# V= \sqrt {2gh}
# $$
#
# And the discharge of the tank is
#
# $$
# Q= V*A
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 4
# D_tank= 1.5 #m
# h= 0.8 #m
# D_small= 20 #mm
#
# V= sqrt(h*2*g) #m/s
# Q_a= V*pi*(D_small/1000)**2/(4) #m3/s
# Out:
# \[
# \begin{aligned}
# D_{tank} &= 1.5000 \; \;\textrm{(m)}
# \\[10pt]
# h &= 0.8000 \; \;\textrm{(m)}
# \\[10pt]
# D_{small} &= 20 \; \;\textrm{(mm)}
# \\[10pt]
# V &= \sqrt { h \cdot 2 \cdot g } \\&= \sqrt { 0.8000 \cdot 2 \cdot 9.8100 } \\&= 3.9618 \; \;\textrm{(m/s)}\\[10pt]
# \\[10pt]
# Q_{a} &= V \cdot \pi \cdot \frac{ \left( \frac{ D_{small} }{ 1000 } \right) ^{ 2 } }{ 4 } \\&= 3.9618 \cdot 3.1416 \cdot \frac{ \left( \frac{ 20 }{ 1000 } \right) ^{ 2 } }{ 4 } \\&= 0.0012 \; \;\textrm{(m3/s)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# **Question 6 (b)**

# %% [markdown]
# ```{dropdown} Hint
# The Torricelli equation can be used:
#
# $$
# V= \sqrt {2gh}
# $$
#
# And the discharge of the tank is
#
# $$
# Q= V*A
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 4
# h_b= 0.3 #m
# V= sqrt(h_b*2*g) #m/s
# Q_b= V*pi*(D_small/1000)**2/(4) #m3/s
# Out:
# \[
# \begin{aligned}
# h_{b} &= 0.3000 \; \;\textrm{(m)}
# \\[10pt]
# V &= \sqrt { h_{b} \cdot 2 \cdot g } \\&= \sqrt { 0.3000 \cdot 2 \cdot 9.8100 } \\&= 2.4261 \; \;\textrm{(m/s)}\\[10pt]
# \\[10pt]
# Q_{b} &= V \cdot \pi \cdot \frac{ \left( \frac{ D_{small} }{ 1000 } \right) ^{ 2 } }{ 4 } \\&= 2.4261 \cdot 3.1416 \cdot \frac{ \left( \frac{ 20 }{ 1000 } \right) ^{ 2 } }{ 4 } \\&= 0.0008 \; \;\textrm{(m3/s)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# **Question 6 (c)**

# %% [markdown]
# ```{dropdown} Hint
# To assess whether the steady-flow assumption is reasonable, we need to consider whether the water level in the tank decreases slowly relative to the velocity of the outflow. For that reason, the velocity of the tank should be calculated.
#
# $$
# Q= V_1*A_1\\
# A_1= \frac{\pi D^2}{4}
# $$
#
# If the rate of change in water height is low, this confirms that the steady-flow assumption is valid
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# V_1= Q_a*4/(pi*D_tank**2)*1000 #mm/s
# Out:
# \[
# \begin{aligned}
# V_{1} &= Q_{a} \cdot \frac{ 4 }{ \pi \cdot \left( D_{tank} \right) ^{ 2 } } \cdot 1000 \\&= 0.00 \cdot \frac{ 4 }{ 3.14 \cdot \left( 1.50 \right) ^{ 2 } } \cdot 1000 \\&= 0.70 \; \;\textrm{(mm/s)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ```{Dropdown} Show code cell outputs
# The initial change in water level of the tank is 0.7 mm/s, so this is reasonable.
# ```

# %% [markdown]
# ---
# #### Question 7 (*)[R]

# %% [markdown]
# Water flows from a pipe of 1m diameter through a nozzle of 0.2m diameter before exiting as a free jet.
#
# a. If the velocity in the free jet is 3 m/s, calculate the discharge and velocity in the pipe.
#
# b. Calculate the pressure within the pipe.
#
# c. State any assumptions made in the above calculations.

# %% [markdown]
# ```{dropdown} Answer
# $
# a) \;0.094 \; m^3/s \;,\;0.120\; m/s
# $
#
# $
# b) \;4.49 \; kPa
# $
#
# ```

# %% [markdown]
# **Question 7 (a)**

# %% [markdown]
# ```{dropdown} Hint
# The discharge can be calculated using:
#
# $$Q=V_{nozzle} A_{nozzle}$$
#
#
# And the velicity of the pipe is equal to:
#
# $$V_{pipe}= Q/A_{pipe}$$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 3
# D_pipe= 1 #m
# D_nozzle= 0.2 #m
# V_nozzle= 3 #m/s
#
# A_nozzle= pi*D_nozzle**2/4 #m2
# Q= V_nozzle*A_nozzle #m3/s
# A_pipe= pi*D_pipe**2/4 #m2
# V_pipe=Q/A_pipe #m/s
# Out:
# \[
# \begin{aligned}
# D_{pipe} &= 1 \; \;\textrm{(m)}
# \\[10pt]
# D_{nozzle} &= 0.200 \; \;\textrm{(m)}
# \\[10pt]
# V_{nozzle} &= 3 \; \;\textrm{(m/s)}
# \\[10pt]
# A_{nozzle} &= \pi \cdot \frac{ \left( D_{nozzle} \right) ^{ 2 } }{ 4 } \\&= 3.142 \cdot \frac{ \left( 0.200 \right) ^{ 2 } }{ 4 } \\&= 0.031 \; \;\textrm{(m2)}\\[10pt]
# \\[10pt]
# Q &= V_{nozzle} \cdot A_{nozzle} \\&= 3 \cdot 0.031 \\&= 0.094 \; \;\textrm{(m3/s)}\\[10pt]
# \\[10pt]
# A_{pipe} &= \pi \cdot \frac{ \left( D_{pipe} \right) ^{ 2 } }{ 4 } \\&= 3.142 \cdot \frac{ \left( 1 \right) ^{ 2 } }{ 4 } \\&= 0.785 \; \;\textrm{(m2)}\\[10pt]
# \\[10pt]
# V_{pipe} &= 0.120 \; \;\textrm{(m/s)}
# \end{aligned}
# \]

# %% [markdown]
# **Question 7 (b)**

# %% [markdown]
# ```{dropdown} Hint
# We can use Bernoulli equation to calculate the pressure within the pipe:
#
# $$
# \frac{p_{pipe}}{\gamma}+\frac{V_{pipe}^2}{2g}+z_{pipe}=\frac{p_{nozzle}}{\gamma}+\frac{V_{nozzle}^2}{2g}+z_{nozzle}
# $$
#
# The assumptions are the following:
#
# $z_{pipe}=z_{nozzle}$ (horizontal pipe)
#
# $p_{nozzle}=0 Pa$ (it is exposed to atmospheric pressure)
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# p_pipe= (V_nozzle**2/(2*g)-V_pipe**2/(2*g))*rho_water*g #Pa
# p_pipe_= p_pipe/1000 #kPa
# Out:
# \[
# \begin{aligned}
# p_{pipe} &= \left( \frac{ \left( V_{nozzle} \right) ^{ 2 } }{ 2 \cdot g } - \frac{ \left( V_{pipe} \right) ^{ 2 } }{ 2 \cdot g } \right) \cdot \rho_{water} \cdot g \\&= \left( \frac{ \left( 3 \right) ^{ 2 } }{ 2 \cdot 9.81 } - \frac{ \left( 0.12 \right) ^{ 2 } }{ 2 \cdot 9.81 } \right) \cdot 1000 \cdot 9.81 \\&= 4492.80 \; \;\textrm{(Pa)}\\[10pt]
# \\[10pt]
# p_{pipe_{}} &= \frac{ p_{pipe} }{ 1000 } \\&= \frac{ 4492.80 }{ 1000 } \\&= 4.49 \; \;\textrm{(kPa)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# **Question 7 (c)**

# %% [markdown]
# **Solution**

# %% [markdown]
# ```{Dropdown} Show code cell outputs
# Horizontal pipe, steady flow, incompressible water (and density of 1000 kg/m<sup>3</sup>), no energy losses through nozzle, jet diameter equal to nozzle diameter, uniform flow in both crosssections.
# ```

# %% [markdown]
# ---
# #### Question 8(*)[R]

# %% [markdown]
# Water flows from a large reservoir through a 100 mm pipe before exiting the pipe as a free jet at a location 5 m below the water surface of the reservoir. Calculate the discharge within the pipe.

# %% [markdown]
# ```{dropdown} Answer
# $
# \;0.08 \; m^3/s
# $
# ```

# %% [markdown]
# ```{dropdown} Hint
# We can use Bernoulli equation to calculate the discharge within the pipe:
#
# $$
# \frac{p_{atm}}{\gamma}+\frac{V_{1}^2}{2g}+z_{1}=\frac{p_{pipe}}{\gamma}+\frac{V_{2}^2}{2g}+z_{2}
# $$
#
# The assumptions are the following
#
# $p_{atm}$= 0 Pa
# $V_1$= is near 0 m/s because the reservoir is large
# $p_{pipe}$= 0 Pa because it is exposed to atmospheric pressure
#
#
# Considering this assumptions, the Toricelli equation can be used
#
# $$
# V= \sqrt {2gh}
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# D= 100 #mm
# z= 5#m
#
# V= sqrt(z*2*g) #m/s
# Q_b= V*pi*(D/1000)**2/(4) #m3/s
# Out:
# \[
# \begin{aligned}
# D &= 100 \; \;\textrm{(mm)}
# \\[10pt]
# z &= 5 \; \;\textrm{(m)}
# \\[10pt]
# V &= \sqrt { z \cdot 2 \cdot g } \\&= \sqrt { 5 \cdot 2 \cdot 9.81 } \\&= 9.90 \; \;\textrm{(m/s)}\\[10pt]
# \\[10pt]
# Q_{b} &= V \cdot \pi \cdot \frac{ \left( \frac{ D }{ 1000 } \right) ^{ 2 } }{ 4 } \\&= 9.90 \cdot 3.14 \cdot \frac{ \left( \frac{ 100 }{ 1000 } \right) ^{ 2 } }{ 4 } \\&= 0.08 \; \;\textrm{(m3/s)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 9 (**)[R]

# %% [markdown]
# Oil (density = 940 kg/m<sup>3</sup>) flow through a pipe of diameter 120 mm. At some location in the pipe, the diameter is reduced to 90 mm.
#
# a. If the pressure and velocity in the wider (120 mm) section of the pipe are 280 kPa and 5 m/s respectively, calculate the discharge in the pipe.
#
# b. Calculate the velocity and pressure in the constricted section.

# %% [markdown]
# ```{dropdown} Answer
# $
# a) \;0.57 \; m^3/s
# $
#
# $
# b) \;8.89 \; m/s\;,\; 254.61 \;kPa
# $
#
# ```

# %% [markdown]
# **Question 9 (a)**

# %% [markdown]
# ```{dropdown} Hint
# The discharge in the pipe can be calculated as:
#
# $$Q=V_1A_1$$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 3
# rho= 940 #kg/m3
# D_1= 120/1000 #m
# D_2= 90/1000 #m
# p_1= 280*1000 #Pa
# V_1= 5 #m/s
#
# A_1= pi*D_1**2/4 #m2
# Q= V_1*A_1 #m3/s
# Out:
# \[
# \begin{aligned}
# \rho &= 940 \; \;\textrm{(kg/m3)}
# \\[10pt]
# D_{1} &= \frac{ 120 }{ 1000 } &= 0.120 \; \;\textrm{(m)}
# \\[10pt]
# D_{2} &= \frac{ 90 }{ 1000 } &= 0.090 \; \;\textrm{(m)}
# \\[10pt]
# p_{1} &= 280 \cdot 1000 &= 280000 \; \;\textrm{(Pa)}
# \\[10pt]
# V_{1} &= 5 \; \;\textrm{(m/s)}
# \\[10pt]
# A_{1} &= \pi \cdot \frac{ \left( D_{1} \right) ^{ 2 } }{ 4 } \\&= 3.142 \cdot \frac{ \left( 0.120 \right) ^{ 2 } }{ 4 } \\&= 0.011 \; \;\textrm{(m2)}\\[10pt]
# \\[10pt]
# Q &= V_{1} \cdot A_{1} \\&= 5 \cdot 0.011 \\&= 0.057 \; \;\textrm{(m3/s)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# **Question 9 (b)**

# %% [markdown]
# ```{dropdown} Hint
# The velocity can be calculated as:
#
# $$V_2=Q/A_2$$
#
# To calculate the pressure we can use the Bernoulli equation:
#
# $$
# \frac{p_{1}}{\gamma}+\frac{V_{1}^2}{2g}+z_{1}=\frac{p_{2}}{\gamma}+\frac{V_{2}^2}{2g}+z_{2}
# $$
#
# Where the assumptions are:
#
# $z_{1}=z_{2}$ (horizontal pipe)
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
#
# A_2= pi*D_2**2/4 #m2
# V_2= Q/A_2 #m/s
# p_2= (p_1/(rho*g)+V_1**2/(2*g)-V_2**2/(2*g))*rho*g #Pa
# p_2_= p_2/1000 #kPa
# Out:
# \[
# \begin{aligned}
# A_{2} &= \pi \cdot \frac{ \left( D_{2} \right) ^{ 2 } }{ 4 } \\&= 3.14 \cdot \frac{ \left( 0.09 \right) ^{ 2 } }{ 4 } \\&= 0.01 \; \;\textrm{(m2)}\\[10pt]
# \\[10pt]
# V_{2} &= \frac{ Q }{ A_{2} } \\&= \frac{ 0.06 }{ 0.01 } \\&= 8.89 \; \;\textrm{(m/s)}\\[10pt]
# \\[10pt]
# p_{2} &= \left( \frac{ p_{1} }{ \rho \cdot g } + \frac{ \left( V_{1} \right) ^{ 2 } }{ 2 \cdot g } - \frac{ \left( V_{2} \right) ^{ 2 } }{ 2 \cdot g } \right) \cdot \rho \cdot g \\&= \left( \frac{ 280000 }{ 940 \cdot 9.81 } + \frac{ \left( 5 \right) ^{ 2 } }{ 2 \cdot 9.81 } - \frac{ \left( 8.89 \right) ^{ 2 } }{ 2 \cdot 9.81 } \right) \cdot 940 \cdot 9.81 \\&= 254614.20 \; \;\textrm{(Pa)}\\[10pt]
# \\[10pt]
# p_{2_{}} &= \frac{ p_{2} }{ 1000 } \\&= \frac{ 254614.20 }{ 1000 } \\&= 254.61 \; \;\textrm{(kPa)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 10(***)

# %% [markdown]
# Water flows in an open channel with a constant width of 1.5 m. At some point in the channel A, the depth is 0.5 m and the velocity is 2.5 m/s. The channel then steps down 1.0 m in a smooth transition to point B. Show that the water depth at B, 𝑑𝐵,
# can be expressed as: $d_B= \frac{V_Ad_A}{\sqrt{V_A^2+2g(d_A+1-d_B)}}$ where 𝑣𝐴 is the velocity at point A, 𝑔 is the gravitational acceleration, and 𝑑𝐴 is the water depth at point A.

# %% [markdown]
# ```{dropdown} Hint
# We can use Bernoulli equation to show that the water depth can be expressed as the equation showed in the question.
#
# $$
# \frac{p_{A}}{\gamma}+\frac{V_{A}^2}{2g}+z_{A}=\frac{p_{B}}{\gamma}+\frac{V_{B}^2}{2g}+z_{B}
# $$
#
# The assumptions are the following
#
# $$
# z_B= 0 m
# $$
#
# The pressure in point 1 and 2 can be expressed with the following equation
#
# $$
# p_A= \rho gd_A\\
# p_B=\rho gd_B\\
# $$
# ```

# %% [markdown]
# **Solution**

# %% [markdown]
# ```{Dropdown} Show code cell outputs
# We can use Bernoulli equation to show that the water depth can be expressed as the equation showed in the question.
#
# $$
# \frac{p_{A}}{\gamma}+\frac{V_{A}^2}{2g}+z_{A}=\frac{p_{B}}{\gamma}+\frac{V_{B}^2}{2g}+z_{B}
# $$
#
# The assumptions are the following
#
# $$
# z_B= 0 m
# $$
#
# The pressure in point 1 and 2 can be expressed with the following equation
#
# $$
# p_A= \rho gd_A\\
# p_B=\rho gd_B\\
# $$
#
# $$
# d_A +\frac{V_{A}^2}{2g}+z_A= d_B+\frac{V_{B}^2}{2g}\\
# $$
# $$
# z_A= 1 m
# $$
#
# Then we can used the the conservation of mass to calculate the velocity in section B.
#
# $$
# Q_A=Q_B\\
# $$
#
# $$
# V_A*d_A*b= V_B*d_B*b\\
# $$
# $$
# V_B=\frac{V_A*d_A}{d_B}\\
# $$
#
# $$
# d_A +\frac{V_{A}^2}{2g}+z_A= d_B+\frac{V_A^2*d_A^2}{d_B^22g}
# $$
#
# Organizing the equation we have that
#
# $$
# 2g(d_A+1)+V_A^2= \frac {V_A^2d_A^2}{d_B^2}+db*2g\\
# 2g(d_A+1-d_B)+V_A^2= \frac {V_A^2d_A^2}{d_B^2}\\
# d_B^2=V_A^2d_A^2\frac{1}{V_A^2+2g(d_A+1-d_B)}
# $$
# ```

# %% [markdown]
# ## Problems for Lecture 19: Laminar flow in pipes

# %% [markdown]
# ### Reynolds number

# %% [markdown]
# ---
# #### Question 1 (*)

# %% [markdown]
# Crude oil with a kinematic viscosity of 1 x 10-3 m<sup>2</sup>/s flows through a 100 mm pipe at 5 m/s. Calculate the Reynolds number of the flow. Will the flow be laminar or turbulent?

# %% [markdown]
# ```{dropdown} Answer
# $
# \;500 \;;\;laminar
# $
# ```

# %% [markdown]
# ```{dropdown} Hint
# The reynolds number can be calculated as:
#
# $$
# Re= \frac{VD}{\nu}
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 1
# nu= 1*10**-3 #m2/s
# D= 100 #mm
# V= 5 #m/s
#
# D_m=(D/1000)
# Re= V*D_m/nu #Laminar
# Out:
# \[
# \begin{aligned}
# \nu &= 1 \cdot \left( 10 \right) ^{ -3 } &= 0.0 \; \;\textrm{(m2/s)}
# \\[10pt]
# D &= 100 \; \;\textrm{(mm)}
# \\[10pt]
# V &= 5 \; \;\textrm{(m/s)}
# \\[10pt]
# D_{m} &= 0.1 \;
# \\[10pt]
# \mathrm{Re} &= V \cdot \frac{ D_{m} }{ \nu } \\&= 5 \cdot \frac{ 0.1 }{ 0.0 } \\&= 500.0 \; \;\textrm{(Laminar)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 2 (*)

# %% [markdown]
# Water at 15 °C flows through a 100 mm pipe at 5 m/s. Calculate the Reynolds number of the flow. Will the flow be laminar or turbulent?

# %% [markdown]
# ```{dropdown} Answer
# $
#  \;438 \;, \; 596 \;;\;turbulent
# $
# ```

# %% [markdown]
# ```{dropdown} Hint
# In Table A.1 the viscosity of water at 15 °C is 1.14 x10<sup>-6</sup> m<sup>2</sup>/s
#
# $$
# Re= \frac{VD}{\nu}
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 0
# D= 100/1000 #m
# V= 5 #m/s
# T=15 #°C
#
# nu= 1.14*10**-6 #m2/s
# Re= V*D/nu
# Out:
# \[
# \begin{aligned}
# D &= \frac{ 100 }{ 1000 } &= 0 \; \;\textrm{(m)}
# \\[10pt]
# V &= 5 \; \;\textrm{(m/s)}
# \\[10pt]
# T &= 15 \; \;\textrm{(°C)}
# \\[10pt]
# \nu &= 1.14 \cdot \left( 10 \right) ^{ -6 } &= 0 \; \;\textrm{(m2/s)}
# \\[10pt]
# \mathrm{Re} &= V \cdot \frac{ D }{ \nu } \\&= 5 \cdot \frac{ 0 }{ 0 } \\&= 438596  \\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ```{Dropdown} Show code cell outputs
# As Re is > 4000, the flow is turbulent.
# ```

# %% [markdown]
# ---
# #### Question 3 (*)[R]

# %% [markdown]
# Water at 15 °C flows through a 100 mm pipe. What is the maximum velocity and flow rate for the flow to be laminar?

# %% [markdown]
# ```{dropdown} Answer
# $
#  \;0.023 \; m/s \; ; \; 0.179 \;L/s
# $
# ```

# %% [markdown]
# ```{dropdown} Hint
# In Table A.1 the viscosity of water at 15 °C is 1.14 x10<sup>-6</sup> m<sup>2</sup>/s
#
# $$
# Re= \frac{VD}{\nu}
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 3
# nu=1.14*10**-6
# D=100 #mm
# Re_max = 2000
#
# V= nu*Re_max/(D/1000) #m/s
# A= pi*(D/1000)**2/4 #m2
# Q= V*A*1000 #L/s
# Out:
# \[
# \begin{aligned}
# \nu &= 0.000 \;
# \\[10pt]
# D &= 100 \; \;\textrm{(mm)}
# \\[10pt]
# \mathrm{Re}_{max} &= 2000 \;
# \\[10pt]
# V &= \nu \cdot \frac{ \mathrm{Re}_{max} }{ \frac{ D }{ 1000 } } \\&= 0.000 \cdot \frac{ 2000 }{ \frac{ 100 }{ 1000 } } \\&= 0.023 \; \;\textrm{(m/s)}\\[10pt]
# \\[10pt]
# A &= \pi \cdot \frac{ \left( \frac{ D }{ 1000 } \right) ^{ 2 } }{ 4 } \\&= 3.142 \cdot \frac{ \left( \frac{ 100 }{ 1000 } \right) ^{ 2 } }{ 4 } \\&= 0.008 \; \;\textrm{(m2)}\\[10pt]
# \\[10pt]
# Q &= V \cdot A \cdot 1000 \\&= 0.023 \cdot 0.008 \cdot 1000 \\&= 0.179 \; \;\textrm{(L/s)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ### Laminar pipe friction losses

# %% [markdown]
# ---
# #### Question 4 (*)

# %% [markdown]
# A pipe with diameter 100 mm and length 1000 m carries water at 15 °C. Calculate:
#
# a. The maximum flow rate to which laminar flow will occur in the pipe.
#
# b. The head loss in the pipe at this flowrate.

# %% [markdown]
# ```{dropdown} Answer
# $
# a) \;0.18 \; L/s
# $
#
# $
# b) \;0.0085 \; m
# $
# ```

# %% [markdown]
# **Question 4 (a)**

# %% [markdown]
# ```{dropdown} Hint
# In Table A.1 the viscosity of water at 15 °C is 1.14 x10<sup>-6</sup> m<sup>2</sup>/s
#
# To calculate the maximum flow rate consider the following equations:
#
# $$
# Re= \frac{VD}{\nu}\\
# V=\frac{Re*\nu}{D}\\
# Q=VA
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# D= 100/1000 #m
# L= 1000 #m
#
# V= 2000*nu/(D) #m/s
# A= pi*(D)**2/4 #m2
# Q= V*A #M3/s
# Q_= Q*1000 #L/s
# Out:
# \[
# \begin{aligned}
# D &= \frac{ 100 }{ 1000 } &= 0.10 \; \;\textrm{(m)}
# \\[10pt]
# L &= 1000 \; \;\textrm{(m)}
# \\[10pt]
# V &= 2000 \cdot \frac{ \nu }{ D } \\&= 2000 \cdot \frac{ 0.00 }{ 0.10 } \\&= 0.02 \; \;\textrm{(m/s)}\\[10pt]
# \\[10pt]
# A &= \pi \cdot \frac{ \left( D \right) ^{ 2 } }{ 4 } \\&= 3.14 \cdot \frac{ \left( 0.10 \right) ^{ 2 } }{ 4 } \\&= 0.01 \; \;\textrm{(m2)}\\[10pt]
# \\[10pt]
# Q &= V \cdot A \\&= 0.02 \cdot 0.01 \\&= 0.00 \; \;\textrm{(M3/s)}\\[10pt]
# \\[10pt]
# Q_{} &= Q \cdot 1000 \\&= 0.00 \cdot 1000 \\&= 0.18 \; \;\textrm{(L/s)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# **Question 4 (b)**

# %% [markdown]
# ```{dropdown} Hint
# As it is laminar flow we can calculate the head loss with following equation:
#
#
# $$
# h_f = 32  \nu  V  \frac{L}{g  \left(\frac{D}{1000}\right)^2}
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 4
# h_f= 32*nu*V*L/(g*(D)**2) #m
# Out:
# \[
# \begin{aligned}
# h_{f} &= 32 \cdot \nu \cdot V \cdot \frac{ L }{ g \cdot \left( D \right) ^{ 2 } } \\&= 32 \cdot 0.0000 \cdot 0.0228 \cdot \frac{ 1000 }{ 9.8100 \cdot \left( 0.1000 \right) ^{ 2 } } \\&= 0.0085 \; \;\textrm{(m)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 5 $\text{(*)(***)}$

# %% [markdown]
#  Oil with μ = 4.8 x 10-2 kg/ m and ρ = 800 kg/m<sup>3</sup> flows through a 25 mm diameter pipe with a mean velocity of 0.3 m/s. Check that the flow in the pipe is laminar and then calculate (a) the head loss in a pipe with a length of 45 m, and (b) the maximum velocity in the pipe cross section. {4.23 m of oil; 0.6 m/s}

# %% [markdown]
# ```{dropdown} Answer
# $
# a) \;4.23 \; m \;of \;oil
# $
#
# $
# b) \; 0.6 \;m/s
# $
# ```

# %% [markdown]
# **Question 5 (a)**$\text{(*)}$

# %% [markdown]
# ```{dropdown} Hint
# To determine the head loss and maximum velocity, it is essential to first identify the type of flow using the Reynolds equation
#
# $$
# Re= \frac{VD}{\nu}
# $$
#
# For laminar flow: Re < 2000
#
# $$
# f=\frac {64}{Re}
# $$
#
# For turbulent flow Re > 4000
#
# $$
# \frac{1}{\sqrt {f}}= -2 log (\frac{5.74}{Re^{0.9}} + \frac {e}{3.7D})
# $$
#
# The head loss is
#
# $$
# h_f= fL \frac {V^2}{2gD}
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# mu=4.8*10**-2 #kg/3
# rho=800 #kg/m3
# D=25/1000
# V=0.3 #m/s
# L=45 #m
#
# Re= rho*D*V/mu
# h_f= (32*mu*L*V)/(rho*g*D**2) #m
# Out:
# \[
# \begin{aligned}
# \mu &= 0.05 \; \;\textrm{(kg/3)}
# \\[10pt]
# \rho &= 800 \; \;\textrm{(kg/m3)}
# \\[10pt]
# D &= 0.03 \;
# \\[10pt]
# V &= 0.30 \; \;\textrm{(m/s)}
# \\[10pt]
# L &= 45 \; \;\textrm{(m)}
# \\[10pt]
# \mathrm{Re} &= \rho \cdot D \cdot \frac{ V }{ \mu } \\&= 800 \cdot 0.03 \cdot \frac{ 0.30 }{ 0.05 } \\&= 125.00  \\[10pt]
# \\[10pt]
# h_{f} &= \frac{ 32 \cdot \mu \cdot L \cdot V }{ \rho \cdot g \cdot \left( D \right) ^{ 2 } } \\&= \frac{ 32 \cdot 0.05 \cdot 45 \cdot 0.30 }{ 800 \cdot 9.81 \cdot \left( 0.03 \right) ^{ 2 } } \\&= 4.23 \; \;\textrm{(m)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# **Question 5 (b)**$\text{(***)}$

# %% [markdown]
# ```{dropdown} Hint
# To find the maximum velocity the following equation is used:
#
# $$
# u_r=-\frac{1}{4\mu}\frac{dp*}{dL}(R^{2}-r^{2})
# $$
#
# As the maximum velocity ocurrs at the pipe centreline:
#
# $$
# r=0
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# r=0
# dp= -rho*g*h_f #N/m2
# dL= L #m
# R= D/2 #m
# U_max= -1/(4*mu)*(dp/dL)*R**2 #m/s
# Out:
# \[
# \begin{aligned}
# r &= 0 \;
# \\[10pt]
# \mathrm{dp} &= \left( - \rho \right) \cdot g \cdot h_{f} \\&= \left( - 800 \right) \cdot 9.81 \cdot 4.23 \\&= -33177.60 \; \;\textrm{(N/m2)}\\[10pt]
# \\[10pt]
# \mathrm{dL} &= 45 \; \;\textrm{(m)}
# \\[10pt]
# R &= \frac{ D }{ 2 } \\&= \frac{ 0.03 }{ 2 } \\&= 0.01 \; \;\textrm{(m)}\\[10pt]
# \\[10pt]
# U_{max} &= \frac{ \left( - 1 \right) }{ 4 \cdot \mu } \cdot \left( \frac{ \mathrm{dp} }{ \mathrm{dL} } \right) \cdot \left( R \right) ^{ 2 } \\&= \frac{ \left( - 1 \right) }{ 4 \cdot 0.05 } \cdot \left( \frac{ -33177.60 }{ 45 } \right) \cdot \left( 0.01 \right) ^{ 2 } \\&= 0.60 \; \;\textrm{(m/s)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ## Problems for Lecture 20: Turbulent flow in pipes

# %% [markdown]
# ### Turbulent pipe friction losses

# %% [markdown]
# ---
# #### Question 1 (*)

# %% [markdown]
# Calculate the head loss in the pipes below for Reynolds numbers of 1 500 and 150 000
#
#
#  a)	A 100 mm internal diameter pipe with a length of 1000 m and an absolute roughness of 0.01 mm.
#
#  b)	A 200 mm internal diameter pipe with a length of 1000 m and an absolute roughness of 0.1 mm.
#
#  c)	A 150 mm internal diameter pipe with a length of 2000 m and an absolute roughness of 0.01 mm.

# %% [markdown]
# ```{dropdown} Answer
# $
# a) \;6.36 \; × \; 10^{-3} \;m \; ; \; 25.60 \; m
# $
#
# $
# b) \;0.8 \; × \; 10^{-3} \;m \; ; \; 3.63 \; m
# $
#
# $
# c) \;3.77 \; × \; 10^{-3} \;m \; ; \; 14.96 \; m
# $
#
# ```

# %% [markdown]
# ```{dropdown} Hint
# A Reynolds number of 1500 means the flow is laminar, while a Reynolds number of 150000 is for turbulent flow. For that reason, for each question two answers must be provided.
#
# The first step is to calculate the flow velocity with Reynolds equation:
#
# $$
# Re= \frac{VD}{\nu}\\
# V= \frac {Re\nu}{D}
# $$
#
# Once the flow velocity is determined, the friction factor and head loss can be calculated using the following equations, depending on the type of flow.
#
# The equation for laminar flow is:
#
# $$
# f=\frac {64}{Re}
# $$
#
# The equation for turbulent flow is:
#
# $$
# \frac{1}{\sqrt {f}}= -2 log (\frac{5.74}{Re^{0.9}} + \frac {e}{3.7D})
# $$
#
# The head loss is
#
# $$
# h_f= fL \frac {V^2}{2gD}
# $$
# ```

# %% [markdown]
# **Question 1 (a)**

# %% [markdown]
# **Solution**

# %% [markdown]
# 1. For Re<sub>L</sub> = 1500 (Laminar)

# %%
# %%render long 3
# D =100/1000 #m
# L= 1000 #m
# e= 0.01/1000 #m
# Re_L= 1500 #Laminar
# Re_T=150000 #Turbulent
# nu= 1.14 *10**-6 #m/s2
#
# V= Re_L*nu/D #m/s
# f=64/ Re_L
# h_f= f*L*V**2/(2*g*D) #m
# Out:
# \[
# \begin{aligned}
# D &= \frac{ 100 }{ 1000 } &= 0.100 \; \;\textrm{(m)}
# \\[10pt]
# L &= 1000 \; \;\textrm{(m)}
# \\[10pt]
# e &= \frac{ 0.01 }{ 1000 } &= 0.000 \; \;\textrm{(m)}
# \\[10pt]
# \mathrm{Re}_{L} &= 1500 \; \;\textrm{(Laminar)}
# \\[10pt]
# \mathrm{Re}_{T} &= 150000 \; \;\textrm{(Turbulent)}
# \\[10pt]
# \nu &= 1.14 \cdot \left( 10 \right) ^{ -6 } &= 0.000 \; \;\textrm{(m/s2)}
# \\[10pt]
# V &= \mathrm{Re}_{L} \cdot \frac{ \nu }{ D } \\&= 1500 \cdot \frac{ 0.000 }{ 0.100 } \\&= 0.017 \; \;\textrm{(m/s)}\\[10pt]
# \\[10pt]
# f &= \frac{ 64 }{ \mathrm{Re}_{L} } \\&= \frac{ 64 }{ 1500 } \\&= 0.043  \\[10pt]
# \\[10pt]
# h_{f} &= f \cdot L \cdot \frac{ \left( V \right) ^{ 2 } }{ 2 \cdot g \cdot D } \\&= 0.043 \cdot 1000 \cdot \frac{ \left( 0.017 \right) ^{ 2 } }{ 2 \cdot 9.810 \cdot 0.100 } \\&= 0.006 \; \;\textrm{(m)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# 2. For Re<sub>T</sub> = 15000 (Turbulent)

# %%
# %%render long 3
# f= (1/(-2*log10(5.74/(Re_T**0.9)+(e/(3.7*D)))))**2
# V= Re_T*nu/D #m/s
# h_f= f*L*V**2/(2*g*D) #m
# Out:
# \[
# \begin{aligned}
# f &= \left( \frac{ 1 }{ \left( - 2 \right) \cdot \log_{10} \left( \frac{ 5.74 }{ \left( \mathrm{Re}_{T} \right) ^{ 0.9 } } + \left( \frac{ e }{ 3.7 \cdot D } \right) \right) } \right) ^{ 2 } \\&= \left( \frac{ 1 }{ \left( - 2 \right) \cdot \log_{10} \left( \frac{ 5.74 }{ \left( 150000 \right) ^{ 0.9 } } + \left( \frac{ 0.000 }{ 3.7 \cdot 0.100 } \right) \right) } \right) ^{ 2 } \\&= 0.017  \\[10pt]
# \\[10pt]
# V &= \mathrm{Re}_{T} \cdot \frac{ \nu }{ D } \\&= 150000 \cdot \frac{ 0.000 }{ 0.100 } \\&= 1.710 \; \;\textrm{(m/s)}\\[10pt]
# \\[10pt]
# h_{f} &= f \cdot L \cdot \frac{ \left( V \right) ^{ 2 } }{ 2 \cdot g \cdot D } \\&= 0.017 \cdot 1000 \cdot \frac{ \left( 1.710 \right) ^{ 2 } }{ 2 \cdot 9.810 \cdot 0.100 } \\&= 25.598 \; \;\textrm{(m)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# **Question 1 (b)**

# %% [markdown]
# **Solution**

# %% [markdown]
# 1. For Re<sub>L</sub> = 1500 (Laminar)

# %%
# %%render long 5
# D =200/1000 #m
# L= 1000 #m
# e= 0.1/1000 #m
# Re_L= 1500 #Laminar
# Re_T=150000 #Turbulent
# nu= 1.14 *10**-6 #m/s2
#
# V= Re_L*nu/D #m/s
# f=64/ Re_L
# h_f= f*L*V**2/(2*g*D) #m
# Out:
# \[
# \begin{aligned}
# D &= \frac{ 200 }{ 1000 } &= 0.20000 \; \;\textrm{(m)}
# \\[10pt]
# L &= 1000 \; \;\textrm{(m)}
# \\[10pt]
# e &= \frac{ 0.1 }{ 1000 } &= 0.00010 \; \;\textrm{(m)}
# \\[10pt]
# \mathrm{Re}_{L} &= 1500 \; \;\textrm{(Laminar)}
# \\[10pt]
# \mathrm{Re}_{T} &= 150000 \; \;\textrm{(Turbulent)}
# \\[10pt]
# \nu &= 1.14 \cdot \left( 10 \right) ^{ -6 } &= 0.00000 \; \;\textrm{(m/s2)}
# \\[10pt]
# V &= \mathrm{Re}_{L} \cdot \frac{ \nu }{ D } \\&= 1500 \cdot \frac{ 0.00000 }{ 0.20000 } \\&= 0.00855 \; \;\textrm{(m/s)}\\[10pt]
# \\[10pt]
# f &= \frac{ 64 }{ \mathrm{Re}_{L} } \\&= \frac{ 64 }{ 1500 } \\&= 0.04267  \\[10pt]
# \\[10pt]
# h_{f} &= f \cdot L \cdot \frac{ \left( V \right) ^{ 2 } }{ 2 \cdot g \cdot D } \\&= 0.04267 \cdot 1000 \cdot \frac{ \left( 0.00855 \right) ^{ 2 } }{ 2 \cdot 9.81000 \cdot 0.20000 } \\&= 0.00079 \; \;\textrm{(m)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# 2. For Re<sub>T</sub> = 15000 (Turbulent)

# %%
# %%render long
# f= (1/(-2*log10(5.74/(Re_T**0.9)+(e/(3.7*D)))))**2
# V= Re_T*nu/D #m/s
# h_f= f*L*V**2/(2*g*D) #m
# Out:
# \[
# \begin{aligned}
# f &= \left( \frac{ 1 }{ \left( - 2 \right) \cdot \log_{10} \left( \frac{ 5.74 }{ \left( \mathrm{Re}_{T} \right) ^{ 0.9 } } + \left( \frac{ e }{ 3.7 \cdot D } \right) \right) } \right) ^{ 2 } \\&= \left( \frac{ 1 }{ \left( - 2 \right) \cdot \log_{10} \left( \frac{ 5.74 }{ \left( 150000 \right) ^{ 0.9 } } + \left( \frac{ 0.000 }{ 3.7 \cdot 0.200 } \right) \right) } \right) ^{ 2 } \\&= 0.019  \\[10pt]
# \\[10pt]
# V &= \mathrm{Re}_{T} \cdot \frac{ \nu }{ D } \\&= 150000 \cdot \frac{ 0.000 }{ 0.200 } \\&= 0.855 \; \;\textrm{(m/s)}\\[10pt]
# \\[10pt]
# h_{f} &= f \cdot L \cdot \frac{ \left( V \right) ^{ 2 } }{ 2 \cdot g \cdot D } \\&= 0.019 \cdot 1000 \cdot \frac{ \left( 0.855 \right) ^{ 2 } }{ 2 \cdot 9.810 \cdot 0.200 } \\&= 3.628 \; \;\textrm{(m)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# **Question 1 (c)**

# %% [markdown]
# **Solution**

# %% [markdown]
# 1. For Re<sub>L</sub> = 1500 (Laminar)

# %%
# %%render long 5
# D =150/1000 #m
# L= 2000 #m
# e= 0.01/1000 #m
# Re_L= 1500 #Laminar
# Re_T=150000 #Turbulent
# nu= 1.14 *10**-6 #m/s2
#
# V= Re_L*nu/D #m/s
# f=64/ Re_L
# h_f= f*L*V**2/(2*g*D) #m
# Out:
# \[
# \begin{aligned}
# D &= \frac{ 150 }{ 1000 } &= 0.15000 \; \;\textrm{(m)}
# \\[10pt]
# L &= 2000 \; \;\textrm{(m)}
# \\[10pt]
# e &= \frac{ 0.01 }{ 1000 } &= 0.00001 \; \;\textrm{(m)}
# \\[10pt]
# \mathrm{Re}_{L} &= 1500 \; \;\textrm{(Laminar)}
# \\[10pt]
# \mathrm{Re}_{T} &= 150000 \; \;\textrm{(Turbulent)}
# \\[10pt]
# \nu &= 1.14 \cdot \left( 10 \right) ^{ -6 } &= 0.00000 \; \;\textrm{(m/s2)}
# \\[10pt]
# V &= \mathrm{Re}_{L} \cdot \frac{ \nu }{ D } \\&= 1500 \cdot \frac{ 0.00000 }{ 0.15000 } \\&= 0.01140 \; \;\textrm{(m/s)}\\[10pt]
# \\[10pt]
# f &= \frac{ 64 }{ \mathrm{Re}_{L} } \\&= \frac{ 64 }{ 1500 } \\&= 0.04267  \\[10pt]
# \\[10pt]
# h_{f} &= f \cdot L \cdot \frac{ \left( V \right) ^{ 2 } }{ 2 \cdot g \cdot D } \\&= 0.04267 \cdot 2000 \cdot \frac{ \left( 0.01140 \right) ^{ 2 } }{ 2 \cdot 9.81000 \cdot 0.15000 } \\&= 0.00377 \; \;\textrm{(m)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# 2. For Re<sub>T</sub> = 15000 (Turbulent)

# %%
# %%render long
# f= (1/(-2*log10(5.74/(Re_T**0.9)+(e/(3.7*D)))))**2
# V= Re_T*nu/D #m/s
# h_f= f*L*V**2/(2*g*D) #m
# Out:
# \[
# \begin{aligned}
# f &= \left( \frac{ 1 }{ \left( - 2 \right) \cdot \log_{10} \left( \frac{ 5.74 }{ \left( \mathrm{Re}_{T} \right) ^{ 0.9 } } + \left( \frac{ e }{ 3.7 \cdot D } \right) \right) } \right) ^{ 2 } \\&= \left( \frac{ 1 }{ \left( - 2 \right) \cdot \log_{10} \left( \frac{ 5.74 }{ \left( 150000 \right) ^{ 0.9 } } + \left( \frac{ 0.000 }{ 3.7 \cdot 0.150 } \right) \right) } \right) ^{ 2 } \\&= 0.017  \\[10pt]
# \\[10pt]
# V &= \mathrm{Re}_{T} \cdot \frac{ \nu }{ D } \\&= 150000 \cdot \frac{ 0.000 }{ 0.150 } \\&= 1.140 \; \;\textrm{(m/s)}\\[10pt]
# \\[10pt]
# h_{f} &= f \cdot L \cdot \frac{ \left( V \right) ^{ 2 } }{ 2 \cdot g \cdot D } \\&= 0.017 \cdot 2000 \cdot \frac{ \left( 1.140 \right) ^{ 2 } }{ 2 \cdot 9.810 \cdot 0.150 } \\&= 14.962 \; \;\textrm{(m)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 2 (**)

# %% [markdown]
# Determine i) the flow regime (laminar, transitional, smooth turbulent, transitional turbulent or rough turbulent) and ii) the headloss for each of the systems described below:
#
# a. A pipe with diameter 200 mm carries water at 10 °C with a velocity of 0.01 m/s. The pipe has an absolute roughness of 0.2 mm and a length of 1000 m.
#
# b. A pipe with diameter 200 mm carries water at 10 °C with a velocity of 0.1 m/s. The pipe has an absolute roughness of 0.2 mm and a length of 1000 m.
#
# c. A pipe with diameter 200 mm carries water at 10 °C with a velocity of 10 m/s. The pipe has an absolute roughness of 0.2 mm and a length of 1000 m.

# %% [markdown]
# ```{dropdown} Answer
# $
# a) \;laminar \;0.0011 \; m
# $
#
# $
# b) \;transitional\; turbulent \;0.074 \; m
# $
#
# $
# c) \;505.86 \; m
# $
# ```

# %% [markdown]
# ```{dropdown} Hint
# The flow regime can be determined with the Reynolds number and the Moody diagram considering:
#
# $$
# Re= \frac{VD}{\nu}\\
# Relative Roughness= \frac{e}{D}\\
# $$
#
# where $e$ is the pipe absolute roughness and $\nu$ can be found in Table A.1.
#
# If the flow regime is laminar the head loss can be calculated using the following equation:
#
# $$
# h_f = 32  \nu  V  \frac{L}{g  \left(\frac{D}{1000}\right)^2}
# $$
#
# for the others flow regimes the head loss can be calculated as:
#
# $$
# h_f = f  L  \frac{V^2}{2  g  D}
# $$
#
#
# where:
#
# $$
# f = \left( \frac{1}{-1.8  \log_{10} \left( \left( \frac{\varepsilon}{3.7  D} \right)^{1.11} + \frac{6.9}{Re} \right)} \right)^2
# $$
# ```

# %% [markdown]
# **Question 2 (a)**

# %% [markdown]
# **Solution**

# %%
# %%render long 7
# D=200/1000 #m
# T=10 #°C
# V=0.01 #m/s
# e=0.2/1000 #m
# L=1000 #m
#
# nu=1.306*10**-6 #m2/s
# Re= V*D/nu #laminar
# h_f= (32*nu*V*L)/(g*D**2) #m
# Out:
# \[
# \begin{aligned}
# D &= 0.2000000 \; \;\textrm{(m)}
# \\[10pt]
# T &= 10 \; \;\textrm{(°C)}
# \\[10pt]
# V &= 0.0100000 \; \;\textrm{(m/s)}
# \\[10pt]
# e &= 0.0002000 \; \;\textrm{(m)}
# \\[10pt]
# L &= 1000 \; \;\textrm{(m)}
# \\[10pt]
# \nu &= 0.0000013 \; \;\textrm{(m2/s)}
# \\[10pt]
# \mathrm{Re} &= V \cdot \frac{ D }{ \nu } \\&= 0.0100000 \cdot \frac{ 0.2000000 }{ 0.0000013 } \\&= 1531.3935681 \; \;\textrm{(laminar)}\\[10pt]
# \\[10pt]
# h_{f} &= \frac{ 32 \cdot \nu \cdot V \cdot L }{ g \cdot \left( D \right) ^{ 2 } } \\&= \frac{ 32 \cdot 0.0000013 \cdot 0.0100000 \cdot 1000 }{ 9.8100000 \cdot \left( 0.2000000 \right) ^{ 2 } } \\&= 0.0010650 \; \;\textrm{(m)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# **Question 2 (b)**

# %% [markdown]
# **Solution**

# %%
# %%render long 3
# D=200/1000 #m
# T=10 #°C
# V=0.1 #m/s
# e=0.2/1000 #m
# L=1000 #m
#
# Re= V*D/nu
# RelativeRoughness= e/D
# f= (1/(-1.8*log10((e/(3.7*D))**1.11+(6.9/Re))))**2
# h_f= f*L*V**2/(2*g*D) #m
# Out:
# \[
# \begin{aligned}
# D &= 0.200 \; \;\textrm{(m)}
# \\[10pt]
# T &= 10 \; \;\textrm{(°C)}
# \\[10pt]
# V &= 0.100 \; \;\textrm{(m/s)}
# \\[10pt]
# e &= 0.000 \; \;\textrm{(m)}
# \\[10pt]
# L &= 1000 \; \;\textrm{(m)}
# \\[10pt]
# \mathrm{Re} &= V \cdot \frac{ D }{ \nu } \\&= 0.100 \cdot \frac{ 0.200 }{ 0.000 } \\&= 15313.936  \\[10pt]
# \\[10pt]
# \mathrm{RelativeRoughness} &= \frac{ e }{ D } \\&= \frac{ 0.000 }{ 0.200 } \\&= 0.001  \\[10pt]
# \\[10pt]
# f &= \left( \frac{ 1 }{ \left( - 1.8 \right) \cdot \log_{10} \left( \left( \frac{ e }{ 3.7 \cdot D } \right) ^{ 1.11 } + \left( \frac{ 6.9 }{ \mathrm{Re} } \right) \right) } \right) ^{ 2 } \\&= \left( \frac{ 1 }{ \left( - 1.8 \right) \cdot \log_{10} \left( \left( \frac{ 0.000 }{ 3.7 \cdot 0.200 } \right) ^{ 1.11 } + \left( \frac{ 6.9 }{ 15313.936 } \right) \right) } \right) ^{ 2 } \\&= 0.029  \\[10pt]
# \\[10pt]
# h_{f} &= f \cdot L \cdot \frac{ \left( V \right) ^{ 2 } }{ 2 \cdot g \cdot D } \\&= 0.029 \cdot 1000 \cdot \frac{ \left( 0.100 \right) ^{ 2 } }{ 2 \cdot 9.810 \cdot 0.200 } \\&= 0.074 \; \;\textrm{(m)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# **Question 2 (c)**

# %% [markdown]
# **Solution**

# %%
# %%render long 3
# D=200/1000 #m
# T=10 #°C
# V=10 #m/s
# e=0.2/1000 #m
# L=1000 #m
#
# Re= V*D/nu #turbulent
# f= (1/(-1.8*log10((e/(3.7*D))**1.11+(6.9/Re))))**2
# h_f= f*L*V**2/(2*g*D) #m
# Out:
# \[
# \begin{aligned}
# D &= 0.200 \; \;\textrm{(m)}
# \\[10pt]
# T &= 10 \; \;\textrm{(°C)}
# \\[10pt]
# V &= 10 \; \;\textrm{(m/s)}
# \\[10pt]
# e &= 0.000 \; \;\textrm{(m)}
# \\[10pt]
# L &= 1000 \; \;\textrm{(m)}
# \\[10pt]
# \mathrm{Re} &= V \cdot \frac{ D }{ \nu } \\&= 10 \cdot \frac{ 0.200 }{ 0.000 } \\&= 1531393.568 \; \;\textrm{(turbulent)}\\[10pt]
# \\[10pt]
# f &= \left( \frac{ 1 }{ \left( - 1.8 \right) \cdot \log_{10} \left( \left( \frac{ e }{ 3.7 \cdot D } \right) ^{ 1.11 } + \left( \frac{ 6.9 }{ \mathrm{Re} } \right) \right) } \right) ^{ 2 } \\&= \left( \frac{ 1 }{ \left( - 1.8 \right) \cdot \log_{10} \left( \left( \frac{ 0.000 }{ 3.7 \cdot 0.200 } \right) ^{ 1.11 } + \left( \frac{ 6.9 }{ 1531393.568 } \right) \right) } \right) ^{ 2 } \\&= 0.020  \\[10pt]
# \\[10pt]
# h_{f} &= f \cdot L \cdot \frac{ \left( V \right) ^{ 2 } }{ 2 \cdot g \cdot D } \\&= 0.020 \cdot 1000 \cdot \frac{ \left( 10 \right) ^{ 2 } }{ 2 \cdot 9.810 \cdot 0.200 } \\&= 505.861 \; \;\textrm{(m)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 3 (*)(**)[R]

# %% [markdown]
# A pipe with diameter 150 mm has an absolute roughness of 0.2 mm and a length of 500 m carries water at 15 °C.
#
# a)	*What is the maximum flow rate at which the water flow in the pipe will be laminar, and what will the head loss through the pipe be at this flow rate?
#
# b)	*If the velocity of water in the pipe is 2 m/s, what will the head loss in the pipe be?
#
# c)	**If the Reynolds number of the flow in the pipe is 100 000, what will the head loss of the pipe be per kilometer of pipe?

# %% [markdown]
# ```{dropdown} Answer
# $
# a) \;0.27 \; L/s \; ; \; 0.001 \;m
# $
#
# $
# b) \;15 \; m
# $
#
# $
# b) \;2.3 \; m
# $
#
# ```

# %% [markdown]
# **Question 3 (a)**$\; \text{Laminar Re= 2000}$

# %% [markdown]
# ```{dropdown} Hint
# The first step is calculated the flow velocity using Reynolds equation:
#
# $$
# V= \frac {Re\nu}{D}
# $$
#
# The flow rate is
#
# $$Q=V*A$$
#
#
# And the head loss in laminar flow is:
#
# $$
# h_f= 32vV \frac {L}{gD^2}
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long
# D= 150/1000 #m
# e= 0.2/1000 #m
# L= 500 #m
# nu=1.14*10**-6 #m/s2
#
# Re=2000
# V= Re*nu/D #m/s
# A= pi*D**2/4 #m2
# Q= V*A #m3/s
# Q_L= Q*1000 #L/s
# h_f= 32*nu*V*L/(g*D**2) #m
# Out:
# \[
# \begin{aligned}
# D &= \frac{ 150 }{ 1000 } &= 0.150 \; \;\textrm{(m)}
# \\[10pt]
# e &= \frac{ 0.2 }{ 1000 } &= 0.000 \; \;\textrm{(m)}
# \\[10pt]
# L &= 500 \; \;\textrm{(m)}
# \\[10pt]
# \nu &= 0.000 \; \;\textrm{(m/s2)}
# \\[10pt]
# \mathrm{Re} &= 2000 \;
# \\[10pt]
# V &= \mathrm{Re} \cdot \frac{ \nu }{ D } \\&= 2000 \cdot \frac{ 0.000 }{ 0.150 } \\&= 0.015 \; \;\textrm{(m/s)}\\[10pt]
# \\[10pt]
# A &= \pi \cdot \frac{ \left( D \right) ^{ 2 } }{ 4 } \\&= 3.142 \cdot \frac{ \left( 0.150 \right) ^{ 2 } }{ 4 } \\&= 0.018 \; \;\textrm{(m2)}\\[10pt]
# \\[10pt]
# Q &= V \cdot A \\&= 0.015 \cdot 0.018 \\&= 0.000 \; \;\textrm{(m3/s)}\\[10pt]
# \\[10pt]
# Q_{L} &= Q \cdot 1000 \\&= 0.000 \cdot 1000 \\&= 0.269 \; \;\textrm{(L/s)}\\[10pt]
# \\[10pt]
# h_{f} &= 32 \cdot \nu \cdot V \cdot \frac{ L }{ g \cdot \left( D \right) ^{ 2 } } \\&= 32 \cdot 0.000 \cdot 0.015 \cdot \frac{ 500 }{ 9.810 \cdot \left( 0.150 \right) ^{ 2 } } \\&= 0.001 \; \;\textrm{(m)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# **Question 3 (b)**

# %% [markdown]
# ```{dropdown} Hint
# The friction loss for turbulent flow is
#
# $$
# f=(\frac {1}{-2log_{10}(\frac {5.47}{Re^{0.9}}+ \frac {e}{3.7D})})^2
# $$
#
# The head loss is
#
# $$
# h_f= fL\frac {V^2}{2gD}
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long
# V= 2 #m/s
# Re = V*D/nu #Turbulent
# f= (1/(-2*log10(5.74/(Re**0.9)+(e/(3.7*D)))))**2
# h_f= f*L*V**2/(2*g*D) #m
# Out:
# \[
# \begin{aligned}
# V &= 2 \; \;\textrm{(m/s)}
# \\[10pt]
# \mathrm{Re} &= V \cdot \frac{ D }{ \nu } \\&= 2 \cdot \frac{ 0.150 }{ 0.000 } \\&= 263157.895 \; \;\textrm{(Turbulent)}\\[10pt]
# \\[10pt]
# f &= \left( \frac{ 1 }{ \left( - 2 \right) \cdot \log_{10} \left( \frac{ 5.74 }{ \left( \mathrm{Re} \right) ^{ 0.9 } } + \left( \frac{ e }{ 3.7 \cdot D } \right) \right) } \right) ^{ 2 } \\&= \left( \frac{ 1 }{ \left( - 2 \right) \cdot \log_{10} \left( \frac{ 5.74 }{ \left( 263157.895 \right) ^{ 0.9 } } + \left( \frac{ 0.000 }{ 3.7 \cdot 0.150 } \right) \right) } \right) ^{ 2 } \\&= 0.022  \\[10pt]
# \\[10pt]
# h_{f} &= f \cdot L \cdot \frac{ \left( V \right) ^{ 2 } }{ 2 \cdot g \cdot D } \\&= 0.022 \cdot 500 \cdot \frac{ \left( 2 \right) ^{ 2 } }{ 2 \cdot 9.810 \cdot 0.150 } \\&= 15.047 \; \;\textrm{(m)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# **Question 3 (c)**

# %% [markdown]
# ```{dropdown} Hint
# The first step is calculate the flow velocity with the Reynolds number
#
# $$ V=\frac {Re\nu}{D}$$
#
# Once the velocity is calculated, the friction factor and head loss can be determined using the following equations applicable to turbulent flow
#
#
# $$
# f=(\frac {1}{-2log_{10}(\frac {5.47}{Re^{0.9}}+ \frac {e}{3.7D})})^2
# $$
#
# The head loss is
#
# $$
# h_f= fL\frac {V^2}{2gD}
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long
# Re = 100000
# V= Re*nu/D #m/s
# f= (1/(-2*log10(5.74/(Re**0.9)+(e/(3.7*D)))))**2
# h_f= f*L*V**2/(2*g*D) #m
# Out:
# \[
# \begin{aligned}
# \mathrm{Re} &= 100000 \;
# \\[10pt]
# V &= \mathrm{Re} \cdot \frac{ \nu }{ D } \\&= 100000 \cdot \frac{ 0.000 }{ 0.150 } \\&= 0.760 \; \;\textrm{(m/s)}\\[10pt]
# \\[10pt]
# f &= \left( \frac{ 1 }{ \left( - 2 \right) \cdot \log_{10} \left( \frac{ 5.74 }{ \left( \mathrm{Re} \right) ^{ 0.9 } } + \left( \frac{ e }{ 3.7 \cdot D } \right) \right) } \right) ^{ 2 } \\&= \left( \frac{ 1 }{ \left( - 2 \right) \cdot \log_{10} \left( \frac{ 5.74 }{ \left( 100000 \right) ^{ 0.9 } } + \left( \frac{ 0.000 }{ 3.7 \cdot 0.150 } \right) \right) } \right) ^{ 2 } \\&= 0.023  \\[10pt]
# \\[10pt]
# h_{f} &= f \cdot L \cdot \frac{ \left( V \right) ^{ 2 } }{ 2 \cdot g \cdot D } \\&= 0.023 \cdot 500 \cdot \frac{ \left( 0.760 \right) ^{ 2 } }{ 2 \cdot 9.810 \cdot 0.150 } \\&= 2.300 \; \;\textrm{(m)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 4 (**)

# %% [markdown]
# Select any pipe diameter between 20 and 500 mm. Assume a pipe roughness of 0.2 mm
# and a length of 1 km. Ensure that you cover the full range from laminar to rough turbulent
# flow and calculate both laminar and turbulent head loss in the transitional zone. Plot the
# following parameters as a function of the Reynolds number:
# • Velocity
# • Flow rate
# • Darcy-Weisbach friction factor f (for turbulent flow only - plot it on a copy of the
# Moody diagram)
# • Pipe head loss
#
# Indicate the following areas on your graphs:
# • Laminar, transitional and turbulent flow
# • Smooth turbulent, transitional turbulent and rough turbulent flow

# %% [markdown]
# ```{dropdown} Hint
# We can assum $\nu=1.14*10^{-6} (m/s^2)$, select different diameters within the given range and then calculate the parameters using the following equations:
#
# $$
# Q=V*A\\
# $$
#
# for laminar flow:
#
# $$
# f=64/Re\\
# $$
#
# $$
# h_f= \frac{fLV^2}{2gD}\\
# $$
#
# for turbulent flow:
#
# $$
# f=(\frac{1}{-2 log (\frac{5.74}{Re^{0.9}} + \frac {e}{3.7D})})^2\\
# $$
#
# Alternatively $f$ can be estimated using the Moody diagram.
#
# $$
# h_f= \frac{fLV^2}{2gD}\\
# $$
# ```

# %% [markdown]
# ---
# #### Question 5 (**)

# %% [markdown]
# A 200 mm diameter reinforced siphon is drawing water at 20°C from the reservoir as shown below. The friction factor of the siphon f = 0.023 and its length from the inlet to Point 2 is equal to 3 m. Assume standard sea level atmospheric conditions and that the siphon between points 2 and 3 hangs vertically down. Calculate the minimum value of z at which cavitation in the system will occur. What will the system flow rate be?

# %% [markdown]
# ```{dropdown} Answer
# $
#  \;30.86 \; m \; ;\; 342.4 \; L/s
# $
# ```

# %% [markdown]
# ```{dropdown} Hint for Velocity 2
# To calculate the minimum value of z and the flow rate the Bernoulli equation needs to be used for points 1 and 2 and then point one and three.
#
# $$
# \frac{p_1}{\gamma}+z_1+\frac{V_1^2}{2g}=\frac{p_2}{\gamma}+z_2+\frac{V_2^2}{2g}+h_f
# $$
#
# In the reservoir it can be considered that there is atmospheric pressure and that the velocity is zero.
#
# $$
# \frac{p_{atm}}{\gamma}=\frac{p_{vap}}{\gamma}+z_2+\frac{V_2^2}{2g}+\frac{f*V_2^2*L}{2*g*D}
# $$
#
# $$
# \frac{p_{atm}}{\gamma}=\frac{p_{vap}}{\gamma}+z_2+\frac{V_2^2}{2*9.81}+\frac{0.023*V_2^2*3}{2*9.81*0.2}
# $$
#
# $$
# \frac{p_{atm}}{\gamma}=\frac{p_{vap}}{\gamma}+z_2+ 0.0510V_2^2+0.0176V_2^2
# $$
# ```

# %% [markdown]
# **Solution V2**

# %%
# %%render long 4
# D= 200/1000 #m
# f=0.023
# L= 3 #m
# z_2= 2 #m
# p_vap = 2.34*1000 #Pa
#
# V_2= ((((p_atm /(rho_water*g))- p_vap /(rho_water*g)-z_2))/0.0681)**0.5 #m/s
# Out:
# \[
# \begin{aligned}
# D &= \frac{ 200 }{ 1000 } &= 0.2000 \; \;\textrm{(m)}
# \\[10pt]
# f &= 0.0230 \;
# \\[10pt]
# L &= 3 \; \;\textrm{(m)}
# \\[10pt]
# z_{2} &= 2 \; \;\textrm{(m)}
# \\[10pt]
# p_{vap} &= 2.34 \cdot 1000 &= 2340.0000 \; \;\textrm{(Pa)}
# \\[10pt]
# V_{2} &= \left( \frac{ \left( \frac{ p_{atm} }{ \rho_{water} \cdot g } \right) - \frac{ p_{vap} }{ \rho_{water} \cdot g } - z_{2} }{ 0.0681 } \right) ^{ 0.5 } \\&= \left( \frac{ \left( \frac{ 101325 }{ 1000 \cdot 9.8100 } \right) - \frac{ 2340.0000 }{ 1000 \cdot 9.8100 } - 2 }{ 0.0681 } \right) ^{ 0.5 } \\&= 10.8995 \; \;\textrm{(m/s)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ```{dropdown} Hint
# Bernoulli between points one and three
#
# $$
# \frac{p_{atm}}{\gamma}+z_1+\frac{V_1^2}{2g}=\frac{P_{3}}{\gamma}+z_3+\frac{V_3^2}{2g}+h_f
# $$
#
# At the end of the pipe there is also atmospheric pressure. Velocity in point two and three is the same.
#
# $$
# 0=z_3+\frac{V_3^2}{2g}+\frac{0.023*V_3^2*L_T}{2*9.81*0.2}
# $$
#
# $$
# L_T = 3+2+z_3\\
# $$
#
# $$
# 0=z_3+\frac{V_3^2}{2*9.81}+\frac{0.023*V_3^2*(5+z_3)}{2*9.81*0.2}\\
# $$
#
# Doing every term separately:
#
# $$
# \frac{V_3^2}{2*9.81}= \frac{10.89^2}{2*9.81} =6.055
# $$
#
# $$
# \frac{0.023*V_3^2*(5+z_3)}{2*9.81*0.2}=\frac{0.023*10.89^2*(5)}{2*9.81*0.2}= 3.482
# $$
#
# $$
# \frac{0.023*V_3^2*(5+z_3)}{2*9.81*0.2}=\frac{0.023*10.89^2*(z_3)}{2*9.81*0.2}= 0.692*z_3\\
# $$
#
# At the end we have
#
# $$
# -z+6.055 + 3.482+ 0.296*z=0\\
# z= \frac {9.537}{0.309}
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long
# terms= V_2**2/(2*g)+f*V_2**2*5/(2*g*D)
# Z= terms / 0.309 #m
# A= pi*D**2/4 #m2
# Q= V_2*A #m3/s
# Q_= Q*1000 #L/s
# Out:
# \[
# \begin{aligned}
# \mathrm{terms} &= \frac{ \left( V_{2} \right) ^{ 2 } }{ 2 \cdot g } + f \cdot \left( V_{2} \right) ^{ 2 } \cdot \frac{ 5 }{ 2 \cdot g \cdot D } \\&= \frac{ \left( 10.899 \right) ^{ 2 } }{ 2 \cdot 9.810 } + 0.023 \cdot \left( 10.899 \right) ^{ 2 } \cdot \frac{ 5 }{ 2 \cdot 9.810 \cdot 0.200 } \\&= 9.537  \\[10pt]
# \\[10pt]
# Z &= \frac{ \mathrm{terms} }{ 0.309 } \\&= \frac{ 9.537 }{ 0.309 } \\&= 30.863 \; \;\textrm{(m)}\\[10pt]
# \\[10pt]
# A &= \pi \cdot \frac{ \left( D \right) ^{ 2 } }{ 4 } \\&= 3.142 \cdot \frac{ \left( 0.200 \right) ^{ 2 } }{ 4 } \\&= 0.031 \; \;\textrm{(m2)}\\[10pt]
# \\[10pt]
# Q &= V_{2} \cdot A \\&= 10.899 \cdot 0.031 \\&= 0.342 \; \;\textrm{(m3/s)}\\[10pt]
# \\[10pt]
# Q_{} &= Q \cdot 1000 \\&= 0.342 \cdot 1000 \\&= 342.418 \; \;\textrm{(L/s)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
#
# #### Question 6(***)[R]

# %% [markdown]
# If the diameter of a pipe is doubled, what effect does this have on the flow rate
# for a given headloss if the flow is
#
# a) laminar and
# b) rough turbulent.

# %% [markdown]
# ```{dropdown} Answer
# $
# a) \;increase \;flow \; by \; a \; ratio \; of\;16
# $
#
# $
# b) \;5.7
# $
#
# ```

# %% [markdown]
# ```{dropdown} Hint
# To see the effect of diameter on the flow rate given a headloss, we must write the headloss in terms of the diameter and flow rate, i.e., replacing velocity with:
#
# $$V=\frac{Q}{\frac{\pi D^2}{4}}$$
#
#
# For laminar flow:
#
# $$
# h_f= \frac{32\nu VL}{gD^2}
# $$
#
# For turbulent flow:
#
# $$
# h_f= \frac{fLV^2}{2gD}
# $$
# ```

# %% [markdown]
# **Question 6 (a)**

# %% [markdown]
# **Solution**

# %% [markdown]
# ```{Dropdown} Show code cell outputs
# $$
# h_f= \frac{32\nu VL}{gD^2}\\
# = \frac{32\nu (\frac{Q}{A})L}{gD^2}\\
# = \frac{32\nu (\frac{Q}{\frac{\pi D^2}{4}})L}{gD^2}\\
# = \frac{32\nu 4QL}{\pi gD^4}\\
# $$
#
# If the head loss is given, the flow rate is proportonial to:
#
# $$
# Q \propto D^4
# $$
#
# If the diameter is double, the flow rate will increase by a ratio of 16
#
# $$
# Q \propto 2^4=16
# $$
# ```

# %% [markdown]
# **Question 6 (b)**

# %% [markdown]
# **Solution**

# %% [markdown]
# ```{Dropdown} Show code cell outputs
# $$
# h_f= \frac{fLV^2}{2gD}\\
# = \frac{fL(\frac{Q}{A})^2}{2gD}\\
# = \frac{fL(\frac{Q}{\frac{\pi D^2}{4}})^2}{2gD}\\
# = \frac{fLQ^2}{2gD(\frac{\pi D^2}{4})^2}\\
# = \frac{fLQ^2}{2gD^5\frac{\pi^2}{16}}\\
# $$
#
# If the head loss is given, the flow rate is proportonial to:
#
# $$
# Q \propto \sqrt{D^5}
# $$
#
# If the diameter is double, the flow rate will increase by a ratio of 5.7
#
# $$
# Q \propto \sqrt{2^5}=5.6568
# $$
# ```

# %% [markdown]
# ### Turbulent flow rate

# %% [markdown]
# ---
#
# #### Question 7(***)

# %% [markdown]
# The system shown below has a pipe diameter of 350 mm, a friction coefficient f = 0.016. The distances BC is 12 m, DE is 920 m and $ \Delta z$ is 48 m. Find the maximum theoretical flow rate if water at 15 °C is pumped in the system at an altitude of 1000 m above sea level. Point C is 6 m above the lower water surface. Work from basic principles and assume f remains constant.

# %%
img = Image.open(r"figures/110.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=725x446>

# %% [markdown]
# ```{dropdown} Answer
# $
# \;0.59 \; m^3/s
# $
# ```

# %% [markdown]
# ```{dropdown} Hint
# Table A.1, water in 15°C the $\frac{p_v}{\gamma}$= 0.17 m
#
# Table A.3 for 1000 m elevation $p_{atm}$= 89.876 kPa abs
#
# $$
# \frac{p_{atm}}{\gamma}=89.9 /9.81= 9.16 m
# $$
#
# Using Bernoulli equation between water surface A to pump intake C using absolute pressure heads when $p_C=p_v$
#
# $$
# \frac{p_{atm}}{\gamma}+z_1+\frac{V_1^2}{2g}=\frac{p_{3}}{\gamma}+z_c+\frac{V_3^2}{2g}+h_f
# $$
#
# The velocity in those to points is the same:
#
# $$
# \frac{p_{atm}}{\gamma}+\frac{V^2}{2g}=\frac{p_{v}}{\gamma}+z_c+\frac{V^2}{2g}+\frac {fLV^2}{2gD}
# $$
#
# $$
# 9.16=0.17+6+\frac{V^2}{2g}+\frac {0.016*12V^2}{2*9.81*0.35}
# $$
#
# $$
# 9.16-6-0.17 =\frac{V^2}{2g}(0.549+1)\\
# $$
#
# $$
# 2.99= 1.549\frac{V^2}{2g}
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render long 2
# D= 350/1000 #m
# f= 0.016
# L_BC= 12 #m
# L_DE= 920 #m
# Delta_z= 48 #m
# H= 1000 #m
# z_c= 6 #m
#
# V= ((2.99/1.549)*2*g)**0.5 #m/s
# A= pi*D**2/4 #m2
# Q= V*A #m3/s
# Out:
# \[
# \begin{aligned}
# D &= \frac{ 350 }{ 1000 } &= 0.35 \; \;\textrm{(m)}
# \\[10pt]
# f &= 0.02 \;
# \\[10pt]
# L_{BC} &= 12 \; \;\textrm{(m)}
# \\[10pt]
# L_{DE} &= 920 \; \;\textrm{(m)}
# \\[10pt]
# \Delta_{z} &= 48 \; \;\textrm{(m)}
# \\[10pt]
# H &= 1000 \; \;\textrm{(m)}
# \\[10pt]
# z_{c} &= 6 \; \;\textrm{(m)}
# \\[10pt]
# V &= \left( \left( \frac{ 2.99 }{ 1.549 } \right) \cdot 2 \cdot g \right) ^{ 0.5 } \\&= \left( \left( \frac{ 2.99 }{ 1.549 } \right) \cdot 2 \cdot 9.81 \right) ^{ 0.5 } \\&= 6.15 \; \;\textrm{(m/s)}\\[10pt]
# \\[10pt]
# A &= \pi \cdot \frac{ \left( D \right) ^{ 2 } }{ 4 } \\&= 3.14 \cdot \frac{ \left( 0.35 \right) ^{ 2 } }{ 4 } \\&= 0.10 \; \;\textrm{(m2)}\\[10pt]
# \\[10pt]
# Q &= V \cdot A \\&= 6.15 \cdot 0.10 \\&= 0.59 \; \;\textrm{(m3/s)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ### Pipe diameter

# %% [markdown]
# ---
# #### Question 8 (****)

# %% [markdown]
# Calculate the flow rate through a 160 mm diameter pipe with length 2000 m and absolute roughness 0.01 mm if the head loss in the pipe is 35 m. In what turbulent flow zone will this flow fall? Use water at 15°C {38.0 l/s, transitional turbulent}

# %% [markdown]
# ```{dropdown} Answer
# $
#  \;38.0 \; l/s \;, \;transitional \;turbulent
# $
# ```

# %% [markdown]
# ```{dropdown} Hint
# As the relative roughness is:
#
# $$
# \frac{e}{D}=\frac{0.00001 m}{0.16 m}=6.25*10^{-5}
# $$
#
# From the Moddy diagram,
#
# $$
# 0.011<f<0.04
# $$
#
# We select one value of f from the range, then we calculate the following until f doesn't change:
#
# $$
# V_1= (\frac{2gDh_f}{fL})^{0.5}\\
# Re_1=\frac{VD}{\nu}\\
# f_2=(\frac{1}{-2 log (\frac{5.74}{Re^{0.9}} + \frac {e}{3.7D})})^2\\
# $$
#
# Once we have found f, we can calculate the flow rate as $Q=VA$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render param 5
# D=160/1000 #m
# L=2000 #m
# e=0.01/1000 #m
# h_f=35 #m
# T=15 #°C
# Out:
# \[
# \begin{aligned}
# D &= 0.16000 \; \;\textrm{(m)}
#  &L &= 2000 \; \;\textrm{(m)}
#  &e &= 0.00001 \; \;\textrm{(m)}
# \\[10pt]
#  h_{f} &= 35 \; \;\textrm{(m)}
#  &T &= 15 \; \;\textrm{(°C)}
# \end{aligned}
# \]

# %%
#Iteration process
df=1000
f_1=0.011 #It could be any f from 0.011 to 0.04
iteration=1
while df>=0.00000001:
    V_1=((2*g*D*h_f)/(f_1*L))**0.5
    Re_1=((V_1*D)/1)/(1.14*10**-6)
    f_2=(1/(-2*log10((5.74/Re_1**0.9)+(e/(3.7*D)))))**2
    V_2=((2*g*D*h_f)/(f_2*L))**0.5
    Re_2=((V_2*D)/1)/(1.14*10**-6)
    f_3=(1/(-2*log10((5.74/Re_2**0.9)+(e/(3.7*D)))))**2
    df=abs(f_3-f_2)
    f_1=f_3
    print("iteration:",iteration,", f1:",round(f_1,4),", V1:",round(V_1,3),", Re1:",round(Re_1,1),", f2:",round(f_2,4),", V2:",round(V_2,3),", Re2:",round(Re_2,1),", f3:",round(f_3,7),", df:",round(df,10))
    iteration=iteration+1
# Out:
# iteration: 1 , f1: 0.0153 , V1: 2.235 , Re1: 313651.5 , f2: 0.015 , V2: 1.916 , Re2: 268918.4 , f3: 0.0153246 , df: 0.000360659
# iteration: 2 , f1: 0.0154 , V1: 1.893 , Re1: 265735.1 , f2: 0.0154 , V2: 1.892 , Re2: 265485.2 , f3: 0.0153558 , df: 2.2861e-06
# iteration: 3 , f1: 0.0154 , V1: 1.891 , Re1: 265465.4 , f2: 0.0154 , V2: 1.891 , Re2: 265463.9 , f3: 0.015356 , df: 1.43e-08
# iteration: 4 , f1: 0.0154 , V1: 1.891 , Re1: 265463.8 , f2: 0.0154 , V2: 1.891 , Re2: 265463.7 , f3: 0.015356 , df: 1e-10

# %%
# %%render long 2
# A= pi*D**2/4 #m2
# Q= V_2*A #m3/s
# Q_= Q*1000 #L/s
# Out:
# \[
# \begin{aligned}
# A &= \pi \cdot \frac{ \left( D \right) ^{ 2 } }{ 4 } \\&= 3.14 \cdot \frac{ \left( 0.16 \right) ^{ 2 } }{ 4 } \\&= 0.02 \; \;\textrm{(m2)}\\[10pt]
# \\[10pt]
# Q &= V_{2} \cdot A \\&= 1.89 \cdot 0.02 \\&= 0.04 \; \;\textrm{(m3/s)}\\[10pt]
# \\[10pt]
# Q_{} &= Q \cdot 1000 \\&= 0.04 \cdot 1000 \\&= 38.03 \; \;\textrm{(L/s)}\\[10pt]
# \end{aligned}
# \]

# %% [markdown]
# ---
# #### Question 9 (***)

# %% [markdown]
# A steel pipe (e = 0.065 mm) is 4 200 m long and is to convey oil (ν = 5.2 x 10-5 m2/s) at 300 L/s from a reservoir with a surface elevation of 247 m to one with a surface elevation of 156 m. What pipe diameter is required? {392 mm}

# %% [markdown]
# ```{dropdown} Answer
# $
# \;392 \; mm
# $
# ```

# %% [markdown]
# ```{dropdown} Hint
# This is an iterative process to find D. Using the following equations:
#
# For turbulent flow
#
# $$
# \frac{1}{\sqrt {f}}= -2 log (\frac{5.74}{Re^{0.9}} + \frac {e}{3.7D})
# $$
#
# $$
# h_f= \frac {fLV^2}{2gD}
# $$
# ```

# %% [markdown]
# **Solution**

# %%
# %%render param 5
# e= 0.065/1000 #m
# L = 4200 #m
# nu = 5.2*10**-5 #m/s2
# Q= 300/1000 #m3/s
# H_0= 247 #m
# H_1= 156 #m
# Out:
# \[
# \begin{aligned}
# e &= 0.00007 \; \;\textrm{(m)}
#  &L &= 4200 \; \;\textrm{(m)}
#  &\nu &= 0.00005 \; \;\textrm{(m/s2)}
# \\[10pt]
#  Q &= 0.30000 \; \;\textrm{(m3/s)}
#  &H_{0} &= 247 \; \;\textrm{(m)}
#  &H_{1} &= 156 \; \;\textrm{(m)}
# \\[10pt]
# \end{aligned}
# \]

# %%
#Iteration process
hf= H_0-H_1
D=0.2
tolerancia= 0.01
iteration=1
while True:
    V= Q*4/(pi*D**2)
    Re=((V*D)/1)/(nu)
    f=(1/(-2*log10((5.74/Re**0.9)+(e/(3.7*D)))))**2
    hf1=f*L*V**2/(2*9.81*D)
    df= abs (hf-hf1)
    print("iteration:", iteration, ", hf:", round(hf1, 4), ", V:", round(V, 3), ", Re:", round(Re, 1), ", f:", round(f, 4), ", df:", round(df, 10),", D:", round(D, 4))
    if df< tolerancia:
        break 
    hf1=hf
    D=D+0.001
    iteration=iteration+1
# Out:
# iteration: 1 , hf: 2279.6018 , V: 9.549 , Re: 36728.1 , f: 0.0234 , df: 2188.6018068739 , D: 0.2
# iteration: 2 , hf: 2225.1926 , V: 9.455 , Re: 36545.3 , f: 0.0234 , df: 2134.1925976828 , D: 0.201
# iteration: 3 , hf: 2172.3501 , V: 9.361 , Re: 36364.4 , f: 0.0234 , df: 2081.3501139858 , D: 0.202
# iteration: 4 , hf: 2121.0216 , V: 9.269 , Re: 36185.3 , f: 0.0234 , df: 2030.0216036326 , D: 0.203
# iteration: 5 , hf: 2071.1563 , V: 9.178 , Re: 36007.9 , f: 0.0234 , df: 1980.1563450593 , D: 0.204
# iteration: 6 , hf: 2022.7056 , V: 9.089 , Re: 35832.3 , f: 0.0234 , df: 1931.7055594395 , D: 0.205
# iteration: 7 , hf: 1975.6223 , V: 9.001 , Re: 35658.3 , f: 0.0235 , df: 1884.622327051 , D: 0.206
# iteration: 8 , hf: 1929.8615 , V: 8.914 , Re: 35486.1 , f: 0.0235 , df: 1838.8615076344 , D: 0.207
# iteration: 9 , hf: 1885.3797 , V: 8.829 , Re: 35315.4 , f: 0.0235 , df: 1794.3796645365 , D: 0.208
# iteration: 10 , hf: 1842.135 , V: 8.745 , Re: 35146.5 , f: 0.0235 , df: 1751.1349924399 , D: 0.209
# iteration: 11 , hf: 1800.0872 , V: 8.661 , Re: 34979.1 , f: 0.0235 , df: 1709.0872484932 , D: 0.21
# iteration: 12 , hf: 1759.1977 , V: 8.58 , Re: 34813.3 , f: 0.0236 , df: 1668.1976866663 , D: 0.211
# iteration: 13 , hf: 1719.429 , V: 8.499 , Re: 34649.1 , f: 0.0236 , df: 1628.4289951647 , D: 0.212
# iteration: 14 , hf: 1680.7452 , V: 8.419 , Re: 34486.4 , f: 0.0236 , df: 1589.7452367463 , D: 0.213
# iteration: 15 , hf: 1643.1118 , V: 8.341 , Re: 34325.3 , f: 0.0236 , df: 1552.1117917942 , D: 0.214
# iteration: 16 , hf: 1606.4953 , V: 8.263 , Re: 34165.6 , f: 0.0236 , df: 1515.495304004 , D: 0.215
# iteration: 17 , hf: 1570.8636 , V: 8.187 , Re: 34007.5 , f: 0.0236 , df: 1479.863628555 , D: 0.216
# iteration: 18 , hf: 1536.1858 , V: 8.112 , Re: 33850.8 , f: 0.0237 , df: 1445.1857826401 , D: 0.217
# iteration: 19 , hf: 1502.4319 , V: 8.037 , Re: 33695.5 , f: 0.0237 , df: 1411.4318982375 , D: 0.218
# iteration: 20 , hf: 1469.5732 , V: 7.964 , Re: 33541.6 , f: 0.0237 , df: 1378.5731770113 , D: 0.219
# iteration: 21 , hf: 1437.5818 , V: 7.892 , Re: 33389.1 , f: 0.0237 , df: 1346.5818472367 , D: 0.22
# iteration: 22 , hf: 1406.4311 , V: 7.821 , Re: 33238.1 , f: 0.0237 , df: 1315.4311226492 , D: 0.221
# iteration: 23 , hf: 1376.0952 , V: 7.75 , Re: 33088.3 , f: 0.0238 , df: 1285.0951631253 , D: 0.222
# iteration: 24 , hf: 1346.549 , V: 7.681 , Re: 32940.0 , f: 0.0238 , df: 1255.5490371021 , D: 0.223
# iteration: 25 , hf: 1317.7687 , V: 7.613 , Re: 32792.9 , f: 0.0238 , df: 1226.7686856544 , D: 0.224
# iteration: 26 , hf: 1289.7309 , V: 7.545 , Re: 32647.2 , f: 0.0238 , df: 1198.7308881479 , D: 0.225
# iteration: 27 , hf: 1262.4132 , V: 7.478 , Re: 32502.7 , f: 0.0238 , df: 1171.4132293915 , D: 0.226
# iteration: 28 , hf: 1235.7941 , V: 7.413 , Re: 32359.5 , f: 0.0238 , df: 1144.7940682189 , D: 0.227
# iteration: 29 , hf: 1209.8525 , V: 7.348 , Re: 32217.6 , f: 0.0239 , df: 1118.8525074295 , D: 0.228
# iteration: 30 , hf: 1184.5684 , V: 7.284 , Re: 32076.9 , f: 0.0239 , df: 1093.5683650255 , D: 0.229
# iteration: 31 , hf: 1159.9221 , V: 7.221 , Re: 31937.4 , f: 0.0239 , df: 1068.9221466821 , D: 0.23
# iteration: 32 , hf: 1135.895 , V: 7.158 , Re: 31799.2 , f: 0.0239 , df: 1044.8950193946 , D: 0.231
# iteration: 33 , hf: 1112.4688 , V: 7.097 , Re: 31662.1 , f: 0.0239 , df: 1021.4687862457 , D: 0.232
# iteration: 34 , hf: 1089.6259 , V: 7.036 , Re: 31526.2 , f: 0.024 , df: 998.6258622418 , D: 0.233
# iteration: 35 , hf: 1067.3493 , V: 6.976 , Re: 31391.5 , f: 0.024 , df: 976.3492511673 , D: 0.234
# iteration: 36 , hf: 1045.6225 , V: 6.917 , Re: 31257.9 , f: 0.024 , df: 954.6225234118 , D: 0.235
# iteration: 37 , hf: 1024.4298 , V: 6.858 , Re: 31125.5 , f: 0.024 , df: 933.4297947227 , D: 0.236
# iteration: 38 , hf: 1003.7557 , V: 6.8 , Re: 30994.1 , f: 0.024 , df: 912.7557058432 , D: 0.237
# iteration: 39 , hf: 983.5854 , V: 6.743 , Re: 30863.9 , f: 0.024 , df: 892.5854029938 , D: 0.238
# iteration: 40 , hf: 963.9045 , V: 6.687 , Re: 30734.8 , f: 0.0241 , df: 872.904519159 , D: 0.239
# iteration: 41 , hf: 944.6992 , V: 6.631 , Re: 30606.7 , f: 0.0241 , df: 853.6991561436 , D: 0.24
# iteration: 42 , hf: 925.9559 , V: 6.577 , Re: 30479.7 , f: 0.0241 , df: 834.9558673627 , D: 0.241
# iteration: 43 , hf: 907.6616 , V: 6.522 , Re: 30353.8 , f: 0.0241 , df: 816.6616413332 , D: 0.242
# iteration: 44 , hf: 889.8039 , V: 6.469 , Re: 30228.9 , f: 0.0241 , df: 798.8038858354 , D: 0.243
# iteration: 45 , hf: 872.3704 , V: 6.416 , Re: 30105.0 , f: 0.0242 , df: 781.3704127142 , D: 0.244
# iteration: 46 , hf: 855.3494 , V: 6.364 , Re: 29982.1 , f: 0.0242 , df: 764.3494232924 , D: 0.245
# iteration: 47 , hf: 838.7295 , V: 6.312 , Re: 29860.2 , f: 0.0242 , df: 747.7294943682 , D: 0.246
# iteration: 48 , hf: 822.4996 , V: 6.261 , Re: 29739.3 , f: 0.0242 , df: 731.4995647717 , D: 0.247
# iteration: 49 , hf: 806.6489 , V: 6.211 , Re: 29619.4 , f: 0.0242 , df: 715.6489224562 , D: 0.248
# iteration: 50 , hf: 791.1672 , V: 6.161 , Re: 29500.5 , f: 0.0242 , df: 700.1671920996 , D: 0.249
# iteration: 51 , hf: 776.0443 , V: 6.112 , Re: 29382.5 , f: 0.0243 , df: 685.0443231955 , D: 0.25
# iteration: 52 , hf: 761.2706 , V: 6.063 , Re: 29265.4 , f: 0.0243 , df: 670.2705786115 , D: 0.251
# iteration: 53 , hf: 746.8365 , V: 6.015 , Re: 29149.3 , f: 0.0243 , df: 655.8365235953 , D: 0.252
# iteration: 54 , hf: 732.733 , V: 5.967 , Re: 29034.0 , f: 0.0243 , df: 641.7330152084 , D: 0.253
# iteration: 55 , hf: 718.9512 , V: 5.921 , Re: 28919.7 , f: 0.0243 , df: 627.9511921707 , D: 0.254
# iteration: 56 , hf: 705.4825 , V: 5.874 , Re: 28806.3 , f: 0.0244 , df: 614.4824650963 , D: 0.255
# iteration: 57 , hf: 692.3185 , V: 5.828 , Re: 28693.8 , f: 0.0244 , df: 601.3185071067 , D: 0.256
# iteration: 58 , hf: 679.4512 , V: 5.783 , Re: 28582.2 , f: 0.0244 , df: 588.4512448023 , D: 0.257
# iteration: 59 , hf: 666.8728 , V: 5.738 , Re: 28471.4 , f: 0.0244 , df: 575.8728495798 , D: 0.258
# iteration: 60 , hf: 654.5757 , V: 5.694 , Re: 28361.4 , f: 0.0244 , df: 563.5757292793 , D: 0.259
# iteration: 61 , hf: 642.5525 , V: 5.65 , Re: 28252.4 , f: 0.0244 , df: 551.5525201479 , D: 0.26
# iteration: 62 , hf: 630.7961 , V: 5.607 , Re: 28144.1 , f: 0.0245 , df: 539.796079107 , D: 0.261
# iteration: 63 , hf: 619.2995 , V: 5.565 , Re: 28036.7 , f: 0.0245 , df: 528.29947631 , D: 0.262
# iteration: 64 , hf: 608.056 , V: 5.522 , Re: 27930.1 , f: 0.0245 , df: 517.0559879787 , D: 0.263
# iteration: 65 , hf: 597.0591 , V: 5.481 , Re: 27824.3 , f: 0.0245 , df: 506.0590895072 , D: 0.264
# iteration: 66 , hf: 586.3024 , V: 5.439 , Re: 27719.3 , f: 0.0245 , df: 495.302448822 , D: 0.265
# iteration: 67 , hf: 575.7799 , V: 5.398 , Re: 27615.1 , f: 0.0246 , df: 484.7799199875 , D: 0.266
# iteration: 68 , hf: 565.4855 , V: 5.358 , Re: 27511.7 , f: 0.0246 , df: 474.4855370484 , D: 0.267
# iteration: 69 , hf: 555.4135 , V: 5.318 , Re: 27409.0 , f: 0.0246 , df: 464.4135080969 , D: 0.268
# iteration: 70 , hf: 545.5582 , V: 5.279 , Re: 27307.1 , f: 0.0246 , df: 454.5582095587 , D: 0.269
# iteration: 71 , hf: 535.9142 , V: 5.24 , Re: 27206.0 , f: 0.0246 , df: 444.9141806858 , D: 0.27
# iteration: 72 , hf: 526.4761 , V: 5.201 , Re: 27105.6 , f: 0.0246 , df: 435.4761182506 , D: 0.271
# iteration: 73 , hf: 517.2389 , V: 5.163 , Re: 27005.9 , f: 0.0247 , df: 426.2388714312 , D: 0.272
# iteration: 74 , hf: 508.1974 , V: 5.125 , Re: 26907.0 , f: 0.0247 , df: 417.1974368819 , D: 0.273
# iteration: 75 , hf: 499.347 , V: 5.088 , Re: 26808.8 , f: 0.0247 , df: 408.3469539802 , D: 0.274
# iteration: 76 , hf: 490.6827 , V: 5.051 , Re: 26711.3 , f: 0.0247 , df: 399.682700244 , D: 0.275
# iteration: 77 , hf: 482.2001 , V: 5.014 , Re: 26614.5 , f: 0.0247 , df: 391.2000869128 , D: 0.276
# iteration: 78 , hf: 473.8947 , V: 4.978 , Re: 26518.5 , f: 0.0247 , df: 382.8946546851 , D: 0.277
# iteration: 79 , hf: 465.7621 , V: 4.942 , Re: 26423.1 , f: 0.0248 , df: 374.7620696074 , D: 0.278
# iteration: 80 , hf: 457.7981 , V: 4.907 , Re: 26328.4 , f: 0.0248 , df: 366.798119108 , D: 0.279
# iteration: 81 , hf: 449.9987 , V: 4.872 , Re: 26234.3 , f: 0.0248 , df: 358.9987081697 , D: 0.28
# iteration: 82 , hf: 442.3599 , V: 4.837 , Re: 26141.0 , f: 0.0248 , df: 351.3598556376 , D: 0.281
# iteration: 83 , hf: 434.8777 , V: 4.803 , Re: 26048.3 , f: 0.0248 , df: 343.8776906547 , D: 0.282
# iteration: 84 , hf: 427.5484 , V: 4.769 , Re: 25956.2 , f: 0.0248 , df: 336.548449222 , D: 0.283
# iteration: 85 , hf: 420.3685 , V: 4.736 , Re: 25864.8 , f: 0.0249 , df: 329.3684708776 , D: 0.284
# iteration: 86 , hf: 413.3342 , V: 4.703 , Re: 25774.1 , f: 0.0249 , df: 322.3341954906 , D: 0.285
# iteration: 87 , hf: 406.4422 , V: 4.67 , Re: 25684.0 , f: 0.0249 , df: 315.4421601649 , D: 0.286
# iteration: 88 , hf: 399.689 , V: 4.637 , Re: 25594.5 , f: 0.0249 , df: 308.68899625 , D: 0.287
# iteration: 89 , hf: 393.0714 , V: 4.605 , Re: 25505.6 , f: 0.0249 , df: 302.0714264527 , D: 0.288
# iteration: 90 , hf: 386.5863 , V: 4.573 , Re: 25417.3 , f: 0.025 , df: 295.5862620479 , D: 0.289
# iteration: 91 , hf: 380.2304 , V: 4.542 , Re: 25329.7 , f: 0.025 , df: 289.2304001842 , D: 0.29
# iteration: 92 , hf: 374.0008 , V: 4.511 , Re: 25242.7 , f: 0.025 , df: 283.0008212799 , D: 0.291
# iteration: 93 , hf: 367.8946 , V: 4.48 , Re: 25156.2 , f: 0.025 , df: 276.8945865071 , D: 0.292
# iteration: 94 , hf: 361.9088 , V: 4.449 , Re: 25070.4 , f: 0.025 , df: 270.9088353602 , D: 0.293
# iteration: 95 , hf: 356.0408 , V: 4.419 , Re: 24985.1 , f: 0.025 , df: 265.0407833058 , D: 0.294
# iteration: 96 , hf: 350.2877 , V: 4.389 , Re: 24900.4 , f: 0.0251 , df: 259.2877195108 , D: 0.295
# iteration: 97 , hf: 344.647 , V: 4.36 , Re: 24816.3 , f: 0.0251 , df: 253.6470046463 , D: 0.296
# iteration: 98 , hf: 339.1161 , V: 4.33 , Re: 24732.7 , f: 0.0251 , df: 248.1160687636 , D: 0.297
# iteration: 99 , hf: 333.6924 , V: 4.301 , Re: 24649.7 , f: 0.0251 , df: 242.692409241 , D: 0.298
# iteration: 100 , hf: 328.3736 , V: 4.273 , Re: 24567.3 , f: 0.0251 , df: 237.3735887977 , D: 0.299
# iteration: 101 , hf: 323.1572 , V: 4.244 , Re: 24485.4 , f: 0.0251 , df: 232.1572335727 , D: 0.3
# iteration: 102 , hf: 318.041 , V: 4.216 , Re: 24404.0 , f: 0.0252 , df: 227.0410312669 , D: 0.301
# iteration: 103 , hf: 313.0227 , V: 4.188 , Re: 24323.2 , f: 0.0252 , df: 222.0227293455 , D: 0.302
# iteration: 104 , hf: 308.1001 , V: 4.161 , Re: 24242.9 , f: 0.0252 , df: 217.1001332981 , D: 0.303
# iteration: 105 , hf: 303.2711 , V: 4.133 , Re: 24163.2 , f: 0.0252 , df: 212.2711049563 , D: 0.304
# iteration: 106 , hf: 298.5336 , V: 4.106 , Re: 24084.0 , f: 0.0252 , df: 207.5335608645 , D: 0.305
# iteration: 107 , hf: 293.8855 , V: 4.079 , Re: 24005.3 , f: 0.0252 , df: 202.8854707033 , D: 0.306
# iteration: 108 , hf: 289.3249 , V: 4.053 , Re: 23927.1 , f: 0.0253 , df: 198.3248557636 , D: 0.307
# iteration: 109 , hf: 284.8498 , V: 4.027 , Re: 23849.4 , f: 0.0253 , df: 193.8497874694 , D: 0.308
# iteration: 110 , hf: 280.4584 , V: 4.001 , Re: 23772.2 , f: 0.0253 , df: 189.4583859471 , D: 0.309
# iteration: 111 , hf: 276.1488 , V: 3.975 , Re: 23695.5 , f: 0.0253 , df: 185.1488186406 , D: 0.31
# iteration: 112 , hf: 271.9193 , V: 3.949 , Re: 23619.3 , f: 0.0253 , df: 180.9192989705 , D: 0.311
# iteration: 113 , hf: 267.7681 , V: 3.924 , Re: 23543.6 , f: 0.0253 , df: 176.7680850345 , D: 0.312
# iteration: 114 , hf: 263.6935 , V: 3.899 , Re: 23468.4 , f: 0.0254 , df: 172.6934783494 , D: 0.313
# iteration: 115 , hf: 259.6938 , V: 3.874 , Re: 23393.7 , f: 0.0254 , df: 168.6938226326 , D: 0.314
# iteration: 116 , hf: 255.7675 , V: 3.85 , Re: 23319.4 , f: 0.0254 , df: 164.7675026208 , D: 0.315
# iteration: 117 , hf: 251.9129 , V: 3.825 , Re: 23245.6 , f: 0.0254 , df: 160.9129429263 , D: 0.316
# iteration: 118 , hf: 248.1286 , V: 3.801 , Re: 23172.3 , f: 0.0254 , df: 157.1286069282 , D: 0.317
# iteration: 119 , hf: 244.413 , V: 3.777 , Re: 23099.4 , f: 0.0254 , df: 153.4129956979 , D: 0.318
# iteration: 120 , hf: 240.7646 , V: 3.754 , Re: 23027.0 , f: 0.0255 , df: 149.7646469581 , D: 0.319
# iteration: 121 , hf: 237.1821 , V: 3.73 , Re: 22955.0 , f: 0.0255 , df: 146.1821340736 , D: 0.32
# iteration: 122 , hf: 233.6641 , V: 3.707 , Re: 22883.5 , f: 0.0255 , df: 142.6640650722 , D: 0.321
# iteration: 123 , hf: 230.2091 , V: 3.684 , Re: 22812.5 , f: 0.0255 , df: 139.2090816968 , D: 0.322
# iteration: 124 , hf: 226.8159 , V: 3.661 , Re: 22741.8 , f: 0.0255 , df: 135.8158584856 , D: 0.323
# iteration: 125 , hf: 223.4831 , V: 3.639 , Re: 22671.6 , f: 0.0255 , df: 132.48310188 , D: 0.324
# iteration: 126 , hf: 220.2095 , V: 3.616 , Re: 22601.9 , f: 0.0256 , df: 129.2095493597 , D: 0.325
# iteration: 127 , hf: 216.994 , V: 3.594 , Re: 22532.6 , f: 0.0256 , df: 125.9939686042 , D: 0.326
# iteration: 128 , hf: 213.8352 , V: 3.572 , Re: 22463.6 , f: 0.0256 , df: 122.8351566789 , D: 0.327
# iteration: 129 , hf: 210.7319 , V: 3.55 , Re: 22395.2 , f: 0.0256 , df: 119.7319392461 , D: 0.328
# iteration: 130 , hf: 207.6832 , V: 3.529 , Re: 22327.1 , f: 0.0256 , df: 116.6831697988 , D: 0.329
# iteration: 131 , hf: 204.6877 , V: 3.508 , Re: 22259.4 , f: 0.0256 , df: 113.6877289185 , D: 0.33
# iteration: 132 , hf: 201.7445 , V: 3.486 , Re: 22192.2 , f: 0.0257 , df: 110.7445235537 , D: 0.331
# iteration: 133 , hf: 198.8525 , V: 3.465 , Re: 22125.3 , f: 0.0257 , df: 107.8524863207 , D: 0.332
# iteration: 134 , hf: 196.0106 , V: 3.445 , Re: 22058.9 , f: 0.0257 , df: 105.0105748245 , D: 0.333
# iteration: 135 , hf: 193.2178 , V: 3.424 , Re: 21992.9 , f: 0.0257 , df: 102.2177709999 , D: 0.334
# iteration: 136 , hf: 190.4731 , V: 3.404 , Re: 21927.2 , f: 0.0257 , df: 99.4730804719 , D: 0.335
# iteration: 137 , hf: 187.7755 , V: 3.383 , Re: 21861.9 , f: 0.0257 , df: 96.7755319348 , D: 0.336
# iteration: 138 , hf: 185.1242 , V: 3.363 , Re: 21797.1 , f: 0.0258 , df: 94.1241765491 , D: 0.337
# iteration: 139 , hf: 182.5181 , V: 3.343 , Re: 21732.6 , f: 0.0258 , df: 91.5180873565 , D: 0.338
# iteration: 140 , hf: 179.9564 , V: 3.324 , Re: 21668.5 , f: 0.0258 , df: 88.9563587112 , D: 0.339
# iteration: 141 , hf: 177.4381 , V: 3.304 , Re: 21604.7 , f: 0.0258 , df: 86.4381057279 , D: 0.34
# iteration: 142 , hf: 174.9625 , V: 3.285 , Re: 21541.4 , f: 0.0258 , df: 83.962463746 , D: 0.341
# iteration: 143 , hf: 172.5286 , V: 3.266 , Re: 21478.4 , f: 0.0258 , df: 81.5285878088 , D: 0.342
# iteration: 144 , hf: 170.1357 , V: 3.247 , Re: 21415.8 , f: 0.0259 , df: 79.1356521573 , D: 0.343
# iteration: 145 , hf: 167.7828 , V: 3.228 , Re: 21353.5 , f: 0.0259 , df: 76.7828497396 , D: 0.344
# iteration: 146 , hf: 165.4694 , V: 3.209 , Re: 21291.6 , f: 0.0259 , df: 74.4693917326 , D: 0.345
# iteration: 147 , hf: 163.1945 , V: 3.191 , Re: 21230.1 , f: 0.0259 , df: 72.1945070791 , D: 0.346
# iteration: 148 , hf: 160.9574 , V: 3.172 , Re: 21168.9 , f: 0.0259 , df: 69.9574420361 , D: 0.347
# iteration: 149 , hf: 158.7575 , V: 3.154 , Re: 21108.1 , f: 0.0259 , df: 67.7574597377 , D: 0.348
# iteration: 150 , hf: 156.5938 , V: 3.136 , Re: 21047.6 , f: 0.026 , df: 65.5938397688 , D: 0.349
# iteration: 151 , hf: 154.4659 , V: 3.118 , Re: 20987.5 , f: 0.026 , df: 63.4658777515 , D: 0.35
# iteration: 152 , hf: 152.3729 , V: 3.1 , Re: 20927.7 , f: 0.026 , df: 61.372884943 , D: 0.351
# iteration: 153 , hf: 150.3142 , V: 3.083 , Re: 20868.2 , f: 0.026 , df: 59.3141878446 , D: 0.352
# iteration: 154 , hf: 148.2891 , V: 3.065 , Re: 20809.1 , f: 0.026 , df: 57.2891278214 , D: 0.353
# iteration: 155 , hf: 146.2971 , V: 3.048 , Re: 20750.3 , f: 0.026 , df: 55.297060733 , D: 0.354
# iteration: 156 , hf: 144.3374 , V: 3.031 , Re: 20691.9 , f: 0.0261 , df: 53.3373565741 , D: 0.355
# iteration: 157 , hf: 142.4094 , V: 3.014 , Re: 20633.7 , f: 0.0261 , df: 51.4093991249 , D: 0.356
# iteration: 158 , hf: 140.5126 , V: 2.997 , Re: 20575.9 , f: 0.0261 , df: 49.5125856112 , D: 0.357
# iteration: 159 , hf: 138.6463 , V: 2.98 , Re: 20518.5 , f: 0.0261 , df: 47.6463263742 , D: 0.358
# iteration: 160 , hf: 136.81 , V: 2.964 , Re: 20461.3 , f: 0.0261 , df: 45.8100445487 , D: 0.359
# iteration: 161 , hf: 135.0032 , V: 2.947 , Re: 20404.5 , f: 0.0261 , df: 44.0031757505 , D: 0.36
# iteration: 162 , hf: 133.2252 , V: 2.931 , Re: 20348.0 , f: 0.0262 , df: 42.225167772 , D: 0.361
# iteration: 163 , hf: 131.4755 , V: 2.915 , Re: 20291.7 , f: 0.0262 , df: 40.4754802865 , D: 0.362
# iteration: 164 , hf: 129.7536 , V: 2.899 , Re: 20235.8 , f: 0.0262 , df: 38.75358456 , D: 0.363
# iteration: 165 , hf: 128.059 , V: 2.883 , Re: 20180.3 , f: 0.0262 , df: 37.058963171 , D: 0.364
# iteration: 166 , hf: 126.3911 , V: 2.867 , Re: 20125.0 , f: 0.0262 , df: 35.3911097377 , D: 0.365
# iteration: 167 , hf: 124.7495 , V: 2.851 , Re: 20070.0 , f: 0.0262 , df: 33.7495286528 , D: 0.366
# iteration: 168 , hf: 123.1337 , V: 2.836 , Re: 20015.3 , f: 0.0262 , df: 32.1337348253 , D: 0.367
# iteration: 169 , hf: 121.5433 , V: 2.821 , Re: 19960.9 , f: 0.0263 , df: 30.5432534285 , D: 0.368
# iteration: 170 , hf: 119.9776 , V: 2.805 , Re: 19906.8 , f: 0.0263 , df: 28.9776196561 , D: 0.369
# iteration: 171 , hf: 118.4364 , V: 2.79 , Re: 19853.0 , f: 0.0263 , df: 27.4363784833 , D: 0.37
# iteration: 172 , hf: 116.9191 , V: 2.775 , Re: 19799.5 , f: 0.0263 , df: 25.919084435 , D: 0.371
# iteration: 173 , hf: 115.4253 , V: 2.76 , Re: 19746.3 , f: 0.0263 , df: 24.4253013604 , D: 0.372
# iteration: 174 , hf: 113.9546 , V: 2.745 , Re: 19693.3 , f: 0.0263 , df: 22.9546022124 , D: 0.373
# iteration: 175 , hf: 112.5066 , V: 2.731 , Re: 19640.7 , f: 0.0264 , df: 21.506568834 , D: 0.374
# iteration: 176 , hf: 111.0808 , V: 2.716 , Re: 19588.3 , f: 0.0264 , df: 20.0807917497 , D: 0.375
# iteration: 177 , hf: 109.6769 , V: 2.702 , Re: 19536.2 , f: 0.0264 , df: 18.6768699623 , D: 0.376
# iteration: 178 , hf: 108.2944 , V: 2.688 , Re: 19484.4 , f: 0.0264 , df: 17.2944107549 , D: 0.377
# iteration: 179 , hf: 106.933 , V: 2.673 , Re: 19432.8 , f: 0.0264 , df: 15.9330294988 , D: 0.378
# iteration: 180 , hf: 105.5923 , V: 2.659 , Re: 19381.6 , f: 0.0264 , df: 14.5923494652 , D: 0.379
# iteration: 181 , hf: 104.272 , V: 2.645 , Re: 19330.6 , f: 0.0265 , df: 13.2720016427 , D: 0.38
# iteration: 182 , hf: 102.9716 , V: 2.631 , Re: 19279.8 , f: 0.0265 , df: 11.9716245592 , D: 0.381
# iteration: 183 , hf: 101.6909 , V: 2.618 , Re: 19229.4 , f: 0.0265 , df: 10.690864108 , D: 0.382
# iteration: 184 , hf: 100.4294 , V: 2.604 , Re: 19179.1 , f: 0.0265 , df: 9.4293733791 , D: 0.383
# iteration: 185 , hf: 99.1868 , V: 2.59 , Re: 19129.2 , f: 0.0265 , df: 8.186812494 , D: 0.384
# iteration: 186 , hf: 97.9628 , V: 2.577 , Re: 19079.5 , f: 0.0265 , df: 6.9628484453 , D: 0.385
# iteration: 187 , hf: 96.7572 , V: 2.564 , Re: 19030.1 , f: 0.0265 , df: 5.7571549403 , D: 0.386
# iteration: 188 , hf: 95.5694 , V: 2.55 , Re: 18980.9 , f: 0.0266 , df: 4.5694122482 , D: 0.387
# iteration: 189 , hf: 94.3993 , V: 2.537 , Re: 18932.0 , f: 0.0266 , df: 3.3993070513 , D: 0.388
# iteration: 190 , hf: 93.2465 , V: 2.524 , Re: 18883.3 , f: 0.0266 , df: 2.2465323005 , D: 0.389
# iteration: 191 , hf: 92.1108 , V: 2.511 , Re: 18834.9 , f: 0.0266 , df: 1.1107870736 , D: 0.39
# iteration: 192 , hf: 90.9918 , V: 2.498 , Re: 18786.7 , f: 0.0266 , df: 0.0082235627 , D: 0.391
